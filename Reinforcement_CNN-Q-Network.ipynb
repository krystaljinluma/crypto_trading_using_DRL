# %%
def calculate_loss(gamma, reward, Q_t, Q_next, loss_func):
  """ Method header to calculate the loss.
  NOTE: THIS CODE SNIPPET WILL NOT WORK RIGHT NOW, BUT SHOULD ONCE YOU HAVE
  EVERYTHING ELSE IMPLEMENTED

  Args:
      gamma  (float) : Discount for rewards
      reward (int)   : Reward for action taken
      Q_t    (tensor): Tensor of Q-Values for each action at time t
      Q_next (tensor): Tensor of Q-Values for each action at time t+1
  """
  
  # TODO: Insert your code here
  
  loss_func = torch.nn.MSELoss()
  loss = loss_func(Q_t, (reward + gamma* Q_next))
  return loss

# %% [markdown]
# ## HAOQI'S ARCHITECTURE

# %%
import torch
import torch.nn as nn

class DQNetwork(nn.Module):
    """ Template class for your DQN. Please feel free to modify headers as needed.
    """
    def __init__(self, states, actions): 
      super(DQNetwork, self).__init__()
      
      self.fc1 = torch.nn.Linear(states, 128)
      self.fc2 = torch.nn.Linear(128, actions)

    def forward(self, x):
      
      x = torch.nn.functional.relu(self.fc1(x))
      x = self.fc2(x)

      return x

# %%
# Install dependency
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision.datasets import FashionMNIST 
from torchvision.transforms import ToTensor 
import random
import numpy as np
import matplotlib
import pandas as pd
import dill

# %%
# RNN model simulate Q function
# input: Batch_size*timestamp*feature_size
# output: Q value of each action
class RNN_Q_Network(nn.Module):
  # feature_size is the number of feature, in our environment it should be 9
  # hidden_size is the hidden size of LSTM
  # output_size is the number of action. In our case, it should be 2(3)
  # FC_hidden_size is the hidden_size of the fully connected layer
  def __init__(self, feature_size = 9, hidden_size = 256, FC_hidden_size = 256, output_size = 3):
    super(RNN_Q_Network, self).__init__()
    self.output_size = output_size
    self.hidden_size = hidden_size
    self.feature_size = feature_size
    self.FC_hidden_size = FC_hidden_size
 
    self.recurrent = nn.LSTM(self.feature_size, self.hidden_size)
    
    #fully-Connected Layer
    self.fc1 = nn.Linear(self.hidden_size, self.FC_hidden_size)
    self.fc2 = nn.Linear(self.FC_hidden_size, self.output_size)

    self.fc3 = nn.ReLU()

  def forward(self, x):
    # TODO
    outputn, (hidden_n, cell_n) = self.recurrent(x)
    hidden_n = hidden_n.squeeze(0)
    temp_layer = self.fc3(self.fc1(hidden_n))
    Q_val = self.fc2(temp_layer)   
    return Q_val

# %%
# RNN model + self attention simulate Q function
# input: Batch_size*timestamp*feature_size
# output: Q value of each action
# Attention model: generate a list of weight
# Follow the discussion in HW#4
class Attention(nn.Module):
  def __init__(self, hidden_size):
    super(Attention, self).__init__()
    self.fc1 = nn.Linear(2*hidden_size, 1)
  # encoder_outputs is the output_n of the LSTM
  def forward(self, hidden, encoder_outputs):
    num = len(encoder_outputs)
    weights = []
    # For each timestamp generate a weight with shape (batch_size)
    for idx, data in enumerate(encoder_outputs):
      weight = self.fc1(torch.cat((data, hidden[0]), dim = 1))

      weights.append(weight.tolist())
    # weights shape(timestamp*batch_size)
    weights = torch.Tensor(weights).squeeze(2)
    weights = torch.transpose(weights, 0 ,1)
    # weights shape(batch_size*timestamp)
    weights = F.softmax(weights, dim = 1)
    return weights

class RNN_Attention_Q_Network(nn.Module):
  # feature_size is the number of feature, in our environment it should be 9
  # hidden_size is the hidden size of LSTM
  # output_size is the number of action. In our case, it should be 2(3)
  # FC_hidden_size is the hidden_size of the fully connected layer
  def __init__(self, feature_size = 9, hidden_size = 256, FC_hidden_size = 256, output_size = 3):
    super(RNN_Attention_Q_Network, self).__init__()
    self.output_size = output_size
    self.hidden_size = hidden_size
    self.feature_size = feature_size
    self.FC_hidden_size = FC_hidden_size
    self.attention = Attention(self.hidden_size)
 
    self.recurrent = nn.LSTM(self.feature_size, self.hidden_size)
    #fully-Connected Layer
    self.fc1 = nn.Linear(self.hidden_size, self.FC_hidden_size)
    self.fc2 = nn.Linear(self.FC_hidden_size, self.output_size)

    self.fc3 = nn.ReLU()

  def forward(self, x):
    outputn, (hidden_n, cell_n) = self.recurrent(x)
    # generate the weights
    weights = self.attention.forward(hidden_n, outputn).to(device)
    # generate the weights-averaged sequence
    context = torch.bmm(weights.unsqueeze(1), torch.transpose(outputn, 0 ,1))
    context = context.squeeze(1)
    hidden_n = hidden_n.squeeze(0)
    # concatenate context and hidden
    newinput = torch.cat((context,hidden_n), dim = 1)
    # generate Q function
    temp_layer = self.fc3(self.fc1(newinput))
    Q_val = self.fc2(temp_layer)
    return Q_val

# %%
# CNN model simulate Q function
# input: Batch_size*timestamp*feature_size
# output: Q value of each action
class CNN_Q_Network(nn.Module):
  # timestamp: the number of input time stamp 
  # feature_size: the numebr of input feature
  # channel_size 1 and 2: the number of channel_size of 2 convolutional layer
  # kernel_size 1 and 2: the number of 2 kernel size of 2 convolutional layer
  # hidden_size: the size of a fully connected hidden layer 
  # output_size: the number of actions
  def __init__(self, timestamp, feature_size, channel_size_1 = 1, channel_size_2 = 1, kernel_size_1 = 3, kernel_size_2 = 3, hidden_size = 256, output_size = 3):
    super(CNN_Q_Network, self).__init__()
    self.timestamp = timestamp
    self.feature_size = feature_size
    self.channel_size_1 = channel_size_1
    self.channel_size_2 = channel_size_2
    self.kernel_size_1 = kernel_size_1
    self.kernel_size_2 = kernel_size_2
    self.hidden_size = hidden_size
    # 2 convolutional layer
    self.features = nn.Sequential(
        nn.Conv2d(1, self.channel_size_1, self.kernel_size_1, stride = 1, padding = 1),
        nn.ReLU(),
        nn.Conv2d(self.channel_size_1, self.channel_size_2, self.kernel_size_2, stride = 1, padding = 1),
        nn.ReLU()
    )
    # after_CL_feature and after_CL_timestamp mean the "feature size" and "time stamp" after convolutional layer
    self.after_CL_feature = feature_size-kernel_size_1-kernel_size_2+6
    self.after_CL_timestamp = timestamp-kernel_size_1-kernel_size_2+6
    # Q_generator are 2 fully connect layers to generate Q function
    self.Q_generator = nn.Sequential(
        nn.Linear(self.channel_size_2*self.after_CL_feature*self.after_CL_timestamp, self.hidden_size),
        nn.ReLU(),
        nn.Linear(self.hidden_size, output_size)
    )

  def forward(self, x):
    #print(x.shape)
    x = x.unsqueeze(1)
    #print(x.shape)
    x = self.features(x)
    x = x.view(-1, self.channel_size_2*self.after_CL_feature*self.after_CL_timestamp)
    #print(x.shape)
    Q_val = self.Q_generator(x)
    return Q_val

# %%
class test(nn.Module):
  # timestamp: the number of input time stamp 
  # feature_size: the numebr of input feature
  # channel_size 1 and 2: the number of channel_size of 2 convolutional layer
  # kernel_size 1 and 2: the number of 2 kernel size of 2 convolutional layer
  # hidden_size: the size of a fully connected hidden layer 
  # output_size: the number of actions
  def __init__(self, timestamp, feature_size, channel_size_1 = 1, channel_size_2 = 1, kernel_size_1 = 3, kernel_size_2 = 3, hidden_size = 256, output_size = 3):
    super(test, self).__init__()
    self.timestamp = timestamp
    self.feature_size = feature_size
    self.channel_size_1 = channel_size_1
    self.channel_size_2 = channel_size_2
    self.kernel_size_1 = kernel_size_1
    self.kernel_size_2 = kernel_size_2
    self.hidden_size = hidden_size
    # 2 convolutional layer
    self.features = nn.Sequential(
        nn.Conv2d(1, self.channel_size_1, self.kernel_size_1, stride = 1, padding = 1),
        nn.ReLU(),
    )
    # after_CL_feature and after_CL_timestamp mean the "feature size" and "time stamp" after convolutional layer
    self.after_CL_feature = feature_size-kernel_size_1-kernel_size_2+6
    self.after_CL_timestamp = timestamp-kernel_size_1-kernel_size_2+6
    # Q_generator are 2 fully connect layers to generate Q function
    self.Q_generator = nn.Sequential(
        nn.Linear(self.channel_size_2*self.after_CL_feature*self.after_CL_timestamp, self.hidden_size),
        nn.ReLU(),
        nn.Linear(self.hidden_size, output_size)
    )

  def forward(self, x):
    #print(x.shape)
    Q_val = self.features(x)
    return Q_val

# %%
# CNN + RNN model simulate Q function
# input: Batch_size*timestamp*feature_size
# output: Q value of each action
class CNN_RNN_Q_Network(nn.Module):
  # timestamp: the number of input time stamp 
  # feature_size: the numebr of input feature
  # channel_size 1 and 2: the number of channel_size of 2 convolutional layer
  # kernel_size 1 and 2: the number of 2 kernel size of 2 convolutional layer
  # hidden_LSTM: the size of the hidden layer of LSTM
  # hidden_size: the size of a fully connected hidden layer 
  # output_size: the number of actions
  def __init__(self,timestamp, feature_size, channel_size_1 = 1, channel_size_2 = 1, kernel_size_1 = 3, kernel_size_2 = 3, hidden_LSTM = 256, hidden_size = 256, output_size = 3):
    super(CNN_RNN_Q_Network, self).__init__()
    self.timestamp = timestamp
    self.feature_size = feature_size
    self.channel_size_1 = channel_size_1
    self.channel_size_2 = channel_size_2
    self.kernel_size_1 = kernel_size_1
    self.kernel_size_2 = kernel_size_2
    self.hidden_size = hidden_size
    # 2 convolutional layer
    self.features = nn.Sequential(
        nn.Conv2d(1, self.channel_size_1, self.kernel_size_1, stride = 1, padding = 1),
        nn.ReLU(),
        nn.Conv2d(self.channel_size_1, self.channel_size_2, self.kernel_size_2, stride = 1, padding = 1),
        nn.ReLU()
    )
    # after_CL_feature and after_CL_timestamp mean the "feature size" and "time stamp" after convolutional layer
    self.after_CL_feature = feature_size-kernel_size_1-kernel_size_2+6
    self.after_CL_timestamp = timestamp-kernel_size_1-kernel_size_2+6
    # recurrent layer
    self.recurrent = nn.LSTM(self.after_CL_feature*self.channel_size_2, self.hidden_LSTM)
    # Q generator
    self.Q_generator = nn.Sequential(
        nn.Linear(self.hidden_LSTM, self.hidden_size),
        nn.ReLU(),
        nn.Linear(self.hidden_size, self.output_size)
    )

  def forward(self, x):
    x = self.features(x)
    # reshape x to be(time_stamp, batch_size, -1)
    x = torch.transpose(x, 1, 2)
    batch = len(x)
    timestamp = len(x[0])
    x = x.view(batch, timestamp, -1)
    x = torch.transpose(x, 0 ,1)
    # recurrent layer
    outputn, (hidden_n, cell_n) = self.recurrent(x)
    #FC layer
    hidden_n = hidden_n.squeeze(0)
    Q_val = self.Q_generator(x)
    return Q_val

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math as math

# %%
df = pd.read_csv("/content/drive/My Drive/gemini_BTCUSD_2019_10min (1).csv")
label = df["label"]
df.drop(["Unix Timestamp", "Date", "Symbol","open_ma", "high_ma", "low_ma", "open_ea", "low_ea", "high_ea", "label"], axis=1, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of            Open      High       Low  ...     close_ea  close_so  close_stdv
# 0       5882.70   5886.31   5875.50  ...  5890.410000  1.000000    0.000000
# 1       5882.47   5888.06   5880.38  ...  5889.008182  1.379278    0.000000
# 2       5885.00   5890.41   5882.47  ...  5887.819421  0.482897    3.855000
# 3       5894.20   5894.20   5885.00  ...  5887.306799  0.467471    3.689935
# 4       5902.78   5902.78   5888.88  ...  5888.560109  0.508021    3.196674
# ...         ...       ...       ...  ...          ...       ...         ...
# 604787  3691.21  13850.00  13822.80  ...  3687.889022  0.000208    1.260327
# 604788  3689.50  13850.00  13823.16  ...  3688.068654  0.000000    1.476496
# 604789  3689.67  13850.00  13825.52  ...  3688.255808  0.000168    1.635230
# 604790  3695.00  13858.37  13843.71  ...  3688.418025  0.000000    1.639108
# 604791  3692.35   3695.00   3692.35  ...  3688.562929  0.000000    1.645371
#
# [604792 rows x 9 columns]>

# %%
n_test = 20000
n_train = 100000
datapoints = 80000

# %%
df = df.iloc[0:n_test+n_train]

# %%
col_names = list(df.columns.values)
print(col_names)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'close_ma', 'close_ea', 'close_so', 'close_stdv']

# %%
print(len(df))
# Out:
# 120000

# %%
df_test = df.iloc[0:n_test]
df_test.head
# Out:
# <bound method NDFrame.head of           Open     High      Low  ...     close_ea  close_so  close_stdv
# 0      5882.70  5886.31  5875.50  ...  5890.410000  1.000000    0.000000
# 1      5882.47  5888.06  5880.38  ...  5889.008182  1.379278    0.000000
# 2      5885.00  5890.41  5882.47  ...  5887.819421  0.482897    3.855000
# 3      5894.20  5894.20  5885.00  ...  5887.306799  0.467471    3.689935
# 4      5902.78  5902.78  5888.88  ...  5888.560109  0.508021    3.196674
# ...        ...      ...      ...  ...          ...       ...         ...
# 19995  5175.74  5212.81  5199.07  ...  5179.526907  0.002225    6.009341
# 19996  5178.81  5213.44  5206.93  ...  5178.435469  0.003091    5.460828
# 19997  5180.22  5213.44  5191.65  ...  5177.617747  0.000000    5.456202
# 19998  5188.33  5193.39  5181.74  ...  5177.089975  0.000000    5.540777
# 19999  5183.41  5192.20  5179.02  ...  5176.820525  0.002846    5.635619
#
# [20000 rows x 9 columns]>

# %%
df = df.iloc[n_test:n_test+n_train]
df1 = pd.DataFrame({'Open' :df['Open'].to_numpy(),'High':df['High'].to_numpy(),'Low':df['Low'].to_numpy(), 'Close':df['Close'].to_numpy(), 'Volume':df['Volume'].to_numpy(), 'close_ma':df['close_ma'].to_numpy(), 'close_ea':df['close_ea'].to_numpy(), 'close_so':df['close_so'].to_numpy(), 'close_stdv':df['close_stdv'].to_numpy()})
df = df1
print(df)
# Out:
#           Open     High      Low  ...     close_ea  close_so  close_stdv
# 0      5183.36  5184.08  5177.16  ...  5176.915521  0.002753    6.541641
# 1      5199.24  5179.48  5173.18  ...  5177.402153  0.000167    3.800581
# 2      5208.52  5180.40  5173.18  ...  5177.939944  0.000000    3.707290
# 3      5204.39  5180.41  5174.31  ...  5178.808317  0.000000    6.453562
# 4      5208.49  5177.04  5176.27  ...  5180.080623  0.002329    9.802453
# ...        ...      ...      ...  ...          ...       ...         ...
# 99995  7210.24  7215.06  7215.06  ...  7204.166624  0.000000    4.243275
# 99996  7210.24  7217.99  7211.26  ...  7205.209419  0.000142    3.213029
# 99997  7210.24  7214.23  7211.26  ...  7206.236980  0.000000    0.924851
# 99998  7210.24  7214.23  7210.56  ...  7207.082074  0.000000    0.905099
# 99999  7210.01  7214.24  7208.37  ...  7207.772788  0.000000    0.907849
#
# [100000 rows x 9 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of           Open     High      Low  ...     close_ea  close_so  close_stdv
# 0      5183.36  5184.08  5177.16  ...  5176.915521  0.002753    6.541641
# 1      5199.24  5179.48  5173.18  ...  5177.402153  0.000167    3.800581
# 2      5208.52  5180.40  5173.18  ...  5177.939944  0.000000    3.707290
# 3      5204.39  5180.41  5174.31  ...  5178.808317  0.000000    6.453562
# 4      5208.49  5177.04  5176.27  ...  5180.080623  0.002329    9.802453
# ...        ...      ...      ...  ...          ...       ...         ...
# 99995  7210.24  7215.06  7215.06  ...  7204.166624  0.000000    4.243275
# 99996  7210.24  7217.99  7211.26  ...  7205.209419  0.000142    3.213029
# 99997  7210.24  7214.23  7211.26  ...  7206.236980  0.000000    0.924851
# 99998  7210.24  7214.23  7210.56  ...  7207.082074  0.000000    0.905099
# 99999  7210.01  7214.24  7208.37  ...  7207.772788  0.000000    0.907849
#
# [100000 rows x 9 columns]>

# %%
df_test.head
# Out:
# <bound method NDFrame.head of           Open     High      Low  ...     close_ea  close_so  close_stdv
# 0      5882.70  5886.31  5875.50  ...  5890.410000  1.000000    0.000000
# 1      5882.47  5888.06  5880.38  ...  5889.008182  1.379278    0.000000
# 2      5885.00  5890.41  5882.47  ...  5887.819421  0.482897    3.855000
# 3      5894.20  5894.20  5885.00  ...  5887.306799  0.467471    3.689935
# 4      5902.78  5902.78  5888.88  ...  5888.560109  0.508021    3.196674
# ...        ...      ...      ...  ...          ...       ...         ...
# 19995  5175.74  5212.81  5199.07  ...  5179.526907  0.002225    6.009341
# 19996  5178.81  5213.44  5206.93  ...  5178.435469  0.003091    5.460828
# 19997  5180.22  5213.44  5191.65  ...  5177.617747  0.000000    5.456202
# 19998  5188.33  5193.39  5181.74  ...  5177.089975  0.000000    5.540777
# 19999  5183.41  5192.20  5179.02  ...  5176.820525  0.002846    5.635619
#
# [20000 rows x 9 columns]>

# %%
class tradingEnv():
    # initialize all the attributes, define action_space and observation_space
    def __init__(self, df, lookback_window, initial_cash): 
        self.df = df # our dataframe, this should be only the columns we need (OHLC+16 technical indicators)
        self.lookback_window = lookback_window # this is the number of timesteps we look back to, 10 in our case
        self.initial_cash = initial_cash
        self.bitcoin_held = 0
        self.current_cash = 0
        self.current_asset = 0
        self.episode = 1
        self.current_step = len(self.df) - 1
        self.start_step = self.current_step
        self.current_reward = 0

        # short: 0, keep: 1, long: 2
        self.action_space = [0, 1, 2]

        # 10x21 ndarray, columns: OHLC, Volume, Close_MA, Close_EA, Close_SO, Close_Stdv,..., Account (current_cash, bitcoin_held, current_asset)
       # self.observation_space = np.empty([10,21])
        self.observation_space = np.empty([10,10])

        # graph to render
        self.graph_reward = []

      # reset all the attributes, set the current step to some random position
    def reset(self):
        self.bitcoin_held = 0
        self.current_cash = self.initial_cash
        self.current_asset = self.initial_cash
        # reset should be called after each episode to clear reward
        self.episode_reward = 0
        self.current_reward = 0

        # set the current step to a random point within the data frame
        self.current_step = random.randint(datapoints, len(self.df) - 1)
        self.start_step = self.current_step
        observation = self._current_observation()
        return observation

    # return the current state which consists of the past 10 timesteps of historical prices and technical indicators
    def _current_observation(self):  
        historial_prices = np.array([
            self.df.loc[self.current_step : self.current_step + 9, 'Open'],
            self.df.loc[self.current_step : self.current_step + 9, 'High'],
            self.df.loc[self.current_step : self.current_step + 9, 'Low'],
            self.df.loc[self.current_step : self.current_step + 9, 'Close'],
            self.df.loc[self.current_step : self.current_step + 9, 'Volume'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_ma'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_ea'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_so'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_stdv'],
            #self.df.loc[self.current_step : self.current_step + 9, 'close_macd'],
            #self.df.loc[self.current_step : self.current_step + 9, 'RSI'],
            #self.df.loc[self.current_step : self.current_step + 9, 'Retracement'],
            #self.df.loc[self.current_step : self.current_step + 9, 'tenkan_sen'],
            #self.df.loc[self.current_step : self.current_step + 9, 'kijun_sen'],
            #self.df.loc[self.current_step : self.current_step + 9, 'senkou_span_a'],
            #self.df.loc[self.current_step : self.current_step + 9, 'senkou_span_b'],
            #self.df.loc[self.current_step : self.current_step + 9, 'chikou_span'],
            #self.df.loc[self.current_step : self.current_step + 9, 'pos_directional_indicator'],
            #self.df.loc[self.current_step : self.current_step + 9, 'neg_directional_indicator'],
            #self.df.loc[self.current_step : self.current_step + 9, 'adx']
        ])

        # our current situation is the last column. Fill empty cells with 0
        observation = np.append(historial_prices, [[self.current_asset, self.current_cash, self.bitcoin_held, 0, 0, 0, 0, 0, 0, 0]], axis=0)
        return observation


    # helper function to calculate reward. reward=current_asset-initial_cash
    def _calculate_reward(self, action):
        # set the current price to a random price between current timestep's open and close
        current_price = self.df.loc[self.current_step, 'Close']#random.uniform(self.df.loc[self.current_step, 'Open']#, self.df.loc[self.current_step, 'Open'])

        #long
        if action == 2:
            num_buy = math.floor(self.current_cash/current_price)
            self.current_cash -= num_buy * current_price
            self.bitcoin_held += num_buy

        #short
        if action == 0:
            num_sell = self.bitcoin_held
            self.current_cash += num_sell * current_price
            self.bitcoin_held = 0

        self.current_asset = self.current_cash + self.bitcoin_held * current_price
        self.current_reward = (self.current_cash + self.bitcoin_held * self.df.loc[self.current_step - 1, 'Close']) - self.current_asset
        print("price for reward:", self.df.loc[self.current_step - 1, 'Close'])

    # return the next state and reward after performing the specified action
    def step(self, action, done):
        # done should always be passed as False unless testing
        if (self.current_step < 1):
            # Cannot calculate reward, because no next timestep is available
            done = True     
        else: 
            self._calculate_reward(action)
            self.current_step -= 1
            done = done #only for testing purpose

            # stop criteria: datapoints steps or current asset is negative
            if self.current_step <= self.start_step - datapoints or self.current_asset <= 0 or self.current_step < 1:
              done = True

        if done:
            self.episode_reward = self.current_reward
            self.graph_reward.append(self.episode_reward) #save this episode's reward
            self.episode += 1 # episode is over at this step

        state = self._current_observation()
        return state, self.current_reward, done

    def render(self, mode, close=False):
        # print out current state, should be called after step()
        if mode == "print after step":
            print("step: ", self.current_step)
            print("current_cash: ", self.current_cash)
            print("bitcoin_held: ", self.bitcoin_held)
            print("current_asset: ", self.current_asset)
            print("reward: ", self.current_reward)

        if mode == "plot episode rewards":
            # plot reward graph
            plt.plot(self.graph_reward)
            plt.xlabel("Episode")
            plt.ylabel("Reward")
            plt.show()

# %% [markdown]
# ## Replay Buffer

# %%
class ReplayBuffer:
  """ ReplayBuffer is a Buffer that allows us to implement Memory Replay.
      Feel free to modify the method signatures as you like, this is simply
      how we implemented it.
  """
  def __init__(self, capacity):
    """ Initializes the ReplayBuffer
    Args:
      capacity (int): The maximum number of memories stored in the ReplayBuffer
    """
    # pass
    self.capacity = capacity
    self.memory = []
    self.pos = 0

  def push(self, replay):
    """ Pushes a new memory to ReplayBuffer. If at capacity, removes first
    memory stored (FIFO).

    Args:
      replay (Tuple): The tuple of all pertinent information for the replay
    """
    # pass
    if(len(self.memory)) < self.capacity:
      self.memory.append(replay)
    else:
      self.memory[self.pos] = replay
      self.pos = (self.pos + 1) % self.capacity

  def sample(self, batch_size):
    """ Randomly samples a batch of size 'batch_size' from the ReplayBuffer

    Args:
      batch_size (int): Integer representing the desired batch size to be sampled

    Returns:
      Tuple representing the replay
    
    Hint: You can use random.sample to do this really easily
    """
    # pass
    return random.sample(self.memory, batch_size)

  def __len__(self):
    """ 
    Returns:
      (int) Returns the current length of the Replay Buffer
    """
    # pass
    return len(self.memory)

# %% [markdown]
# ### $\varepsilon$-greedy action selection

# %%
 import math
 
 def epsilon_greedy_action(q_values, epsilon):
    """
    Implements an epsilon-greedy action selection.
    
    Args:
      q_values (Tensor): Tensor representing the predicted q_values for each action
      epsilon  (Float):  Float from 0-1 representing the probability of selecting a random action, instead of the optimal
      
    """
    
    if random.random() > epsilon:
      return torch.argmax(q_values.data,dim=1)
    else:
      action_space = [0,1,2]
      action = random.choice(action_space)
      return torch.LongTensor([action])

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Number of states and actions
states = 4 # Original is 4. Check How many features you are using and change accordingly
actions = 3 # Long, Keep, Short

# Batch Size
BATCH_SIZE = 32

# Hyperparameters
gamma = 0.9
learning_rate = 0.0001
epsilon = 0.9
EPSILON_END = 0.01
# EPSILON_START = 1
EPSILON_DECAY = 0.99

# Class instantiation
memory = ReplayBuffer(10000) 
q_net = CNN_Q_Network(10, 10)
optimizer = torch.optim.Adam(q_net.parameters(), lr=learning_rate)
loss_func = torch.nn.MSELoss()

# %%
def learn():

  """ Method that updates the DQN parameters for a single batch sampled from the 
      Memory Replay Buffer. Feel free to modify the method header as you like.
  """

  """ Pseudocode:
      1. Sample batch from ReplayBuffer
      2. From the ReplayBuffer feed in state at time t to the DQN
      3. From the ReplayBuffer feed in state at time t + 1 to the DQN
      4. Detach the output from step 3
      5. Calculate Loss
      6. Zero Optimizer Gradient
      7. Backpropagate Loss
      8. Step Optimizer
      """

  # 1. Sample batch from ReplayBuffer
  experiences = memory.sample(BATCH_SIZE)
  # print(experiences)
  experience_batch = list(zip(*(experiences)))
  # print(experience_batch)

  state_batch = torch.Tensor(experience_batch[0])
  action_batch = torch.LongTensor(experience_batch[1])
  reward_batch = torch.Tensor(experience_batch[2])
  next_state_batch = torch.Tensor(experience_batch[3])
  done_batch = torch.Tensor(experience_batch[4])
  # print(state_batch.size())
  # print(action_batch)
  # print(reward_batch)
  # print(next_state_batch.size())
  # print(done_batch)

  # 2. From the ReplayBuffer feed in state at time t to the DQN
  states_action_values = q_net(state_batch)
  # print(states_action_values)
  # print(action_batch)
  # print(len(action_batch))
  # print(torch.Tensor(action_batch).size())
  # print(torch.Tensor(action_batch).unsqueeze(-1))
  # print(states_action_values)

  # 3. From the ReplayBuffer feed in state at time t + 1 to the DQN
  next_states_action_values = q_net(next_state_batch)
  # print(next_states_action_values.size())
  
  # 4. Detach the output from step 3
  next_states_action_values = next_states_action_values.detach()
  # print(next_states_action_values)

  # 5. Calculate Loss
  q_next = torch.max(next_states_action_values, dim = 1 ).values.unsqueeze(-1)
  #print(torch.LongTensor(action_batch))
  #print(states_action_values)
  #print(torch.LongTensor(action_batch).unsqueeze(-1))
  temp = torch.LongTensor(action_batch).unsqueeze(1)
  #print(torch.gather(states_action_values, 1, temp))
  q_current = torch.gather(states_action_values, dim = 1, index= torch.LongTensor(action_batch).unsqueeze(-1))
  # print(q_current)
  indices = (done_batch == 1).nonzero()
  q_next[indices] = 0
  
  # print(indices)
  # if terminal_state:
    # q_next = torch.zeros(q_next.size())

  # print(q_next)
  # print(q_current)
  # print(gamma)
  # print(reward_batch.unsqueeze(-1).size())
  # print(torch.max(next_states_action_values, dim =1 ).values )
  loss = calculate_loss(gamma, reward_batch.unsqueeze(-1), q_current, q_next, loss_func)
  # print(loss)
  # print(loss)

  # 6. Zero Optimizer Gradient
  optimizer.zero_grad()
  
  # 7. Backpropagate Loss
  loss.backward()

  # 8. Step Optimizer
  optimizer.step()
  # print(loss)

  return loss.item()

# %%
treward = []
def run_episode():

  global epsilon
  state = env.reset()
  episode_reward = 0
  cur_loss = 0
  episode_loss = 0
  i = 0
  
  while True:
    """ Pseudocode:
        1. Input state into your network to get the predicted Q Values for each action
        2. Use "epsilon_greedy_action" to get your next action from your Q-Values
    """
    #print(torch.Tensor([state]).shape)
    #print(q_net)
    action_values = q_net(torch.Tensor([state]))
    
    action = epsilon_greedy_action(action_values, epsilon)
    
    # Decay the epsilon
    epsilon = max(epsilon * EPSILON_DECAY, EPSILON_END)
    
    # print(type(action.item()))
    # 3. Once you've done the first two steps, you can simulate tacking the action
    # "action" in the environment as follows. 

    # Return Values: 
    # next_state: (Tuple) Next state after having taken action "action"
    # reward    : (int)   Reward received for taking action "action"
    # done      : (bool)  Whether or not the simulation has reached an ending condition (see github repo linked earlier for more information)
    next_state, reward, done = env.step(action.item(), False)
    
    episode_reward += reward
    experience = (state, action, reward, next_state, done)
    memory.push(experience)
    state = next_state
    if len(memory.memory) >= BATCH_SIZE:
      cur_loss = learn()
    episode_loss += cur_loss
    print('Step: ', i, ' Loss: ', cur_loss, ' Total Reward: ', episode_reward)
    treward.append(episode_reward)
    i += 1
    if done:
      return (episode_reward, episode_loss/ (i + 1))
    """ Pseudocode (cont):
        4. Push this information to your ReplayBuffer
        5. Set your current state to the next state returned
        6. Call "learn" for a single batch
        7. Check if the simulation is done, and if so exit out of the function
           If the simulation is not done, then we loop and repeat steps 1-7
    """

# %%
env = tradingEnv(df, 10, 1000000)
observation = env.reset()
print(observation.shape)
print(env.action_space)
# Out:
# (10, 10)
# [0, 1, 2]

# %%
memory = ReplayBuffer(10000) 
print(len(memory))
# Out:
# 0

# %%
Max_episode = 20
for idx in range(Max_episode):
  run_episode()
#env.render("plot episode rewards")
plt.plot(treward)
# Out:
# Streaming output truncated to the last 5000 lines.
# Step:  77500  Loss:  110817544.0  Total Reward:  40455454.07000002
# price for reward: 9113.94
# Step:  77501  Loss:  241806848.0  Total Reward:  40455454.07000002
# price for reward: 9120.65
# Step:  77502  Loss:  242746816.0  Total Reward:  40455454.07000002
# price for reward: 9120.65
# Step:  77503  Loss:  902595200.0  Total Reward:  40455454.07000002
# price for reward: 9113.99
# Step:  77504  Loss:  266106176.0  Total Reward:  40455454.07000002
# price for reward: 9114.03
# Step:  77505  Loss:  67918656.0  Total Reward:  40455454.07000002
# price for reward: 9111.89
# Step:  77506  Loss:  579796608.0  Total Reward:  40455454.07000002
# price for reward: 9111.89
# Step:  77507  Loss:  287316064.0  Total Reward:  40455454.07000002
# price for reward: 9110.0
# Step:  77508  Loss:  428737984.0  Total Reward:  40446856.46000002
# price for reward: 9110.0
# Step:  77509  Loss:  292125312.0  Total Reward:  40446856.46000002
# price for reward: 9110.0
# Step:  77510  Loss:  183860608.0  Total Reward:  40446856.46000002
# price for reward: 9110.0
# Step:  77511  Loss:  311271424.0  Total Reward:  40446856.46000002
# price for reward: 9103.45
# Step:  77512  Loss:  313599680.0  Total Reward:  40417060.51000003
# price for reward: 9103.45
# Step:  77513  Loss:  1228737792.0  Total Reward:  40417060.51000003
# price for reward: 9103.45
# Step:  77514  Loss:  125880176.0  Total Reward:  40417060.51000003
# price for reward: 9105.62
# Step:  77515  Loss:  489015936.0  Total Reward:  40426931.840000026
# price for reward: 9105.62
# Step:  77516  Loss:  283852992.0  Total Reward:  40426931.840000026
# price for reward: 9103.69
# Step:  77517  Loss:  416857120.0  Total Reward:  40426931.840000026
# price for reward: 9103.48
# Step:  77518  Loss:  422547904.0  Total Reward:  40426931.840000026
# price for reward: 9100.14
# Step:  77519  Loss:  394098048.0  Total Reward:  40426931.840000026
# price for reward: 9097.58
# Step:  77520  Loss:  130453032.0  Total Reward:  40426931.840000026
# price for reward: 9103.71
# Step:  77521  Loss:  422661568.0  Total Reward:  40426931.840000026
# price for reward: 9090.53
# Step:  77522  Loss:  401491008.0  Total Reward:  40426931.840000026
# price for reward: 9087.79
# Step:  77523  Loss:  585823168.0  Total Reward:  40426931.840000026
# price for reward: 9090.1
# Step:  77524  Loss:  288847424.0  Total Reward:  40437460.82000003
# price for reward: 9067.79
# Step:  77525  Loss:  345725408.0  Total Reward:  40335771.840000026
# price for reward: 9067.85
# Step:  77526  Loss:  413923904.0  Total Reward:  40336045.32000003
# price for reward: 9067.85
# Step:  77527  Loss:  715550400.0  Total Reward:  40336045.32000003
# price for reward: 9067.85
# Step:  77528  Loss:  351801312.0  Total Reward:  40336045.32000003
# price for reward: 9074.04
# Step:  77529  Loss:  102721640.0  Total Reward:  40364259.340000026
# price for reward: 9074.04
# Step:  77530  Loss:  575033280.0  Total Reward:  40364259.340000026
# price for reward: 9073.62
# Step:  77531  Loss:  168382208.0  Total Reward:  40362344.98000003
# price for reward: 9076.14
# Step:  77532  Loss:  363787360.0  Total Reward:  40373831.14000002
# price for reward: 9079.73
# Step:  77533  Loss:  773545920.0  Total Reward:  40390194.36000002
# price for reward: 9077.25
# Step:  77534  Loss:  986353408.0  Total Reward:  40378890.520000026
# price for reward: 9081.25
# Step:  77535  Loss:  189010944.0  Total Reward:  40397122.520000026
# price for reward: 9081.25
# Step:  77536  Loss:  150266544.0  Total Reward:  40397122.520000026
# price for reward: 9072.32
# Step:  77537  Loss:  783383936.0  Total Reward:  40356419.58000003
# price for reward: 9069.29
# Step:  77538  Loss:  392428864.0  Total Reward:  40342608.840000026
# price for reward: 9076.4
# Step:  77539  Loss:  215422032.0  Total Reward:  40375016.22000002
# price for reward: 9077.25
# Step:  77540  Loss:  93580448.0  Total Reward:  40378890.520000026
# price for reward: 9076.4
# Step:  77541  Loss:  329047776.0  Total Reward:  40375016.22000002
# price for reward: 9075.64
# Step:  77542  Loss:  644223104.0  Total Reward:  40371552.14000002
# price for reward: 9075.77
# Step:  77543  Loss:  167082480.0  Total Reward:  40372144.68000003
# price for reward: 9077.77
# Step:  77544  Loss:  355055520.0  Total Reward:  40381260.68000003
# price for reward: 9075.0
# Step:  77545  Loss:  543683584.0  Total Reward:  40368635.020000026
# price for reward: 9075.04
# Step:  77546  Loss:  255121360.0  Total Reward:  40368817.340000026
# price for reward: 9080.0
# Step:  77547  Loss:  231193936.0  Total Reward:  40391425.020000026
# price for reward: 9088.0
# Step:  77548  Loss:  297709184.0  Total Reward:  40427889.020000026
# price for reward: 9087.06
# Step:  77549  Loss:  544264128.0  Total Reward:  40423604.50000002
# price for reward: 9087.4
# Step:  77550  Loss:  205376128.0  Total Reward:  40425154.22000002
# price for reward: 9087.4
# Step:  77551  Loss:  236073984.0  Total Reward:  40425154.22000002
# price for reward: 9096.24
# Step:  77552  Loss:  232113632.0  Total Reward:  40465446.94000003
# price for reward: 9090.6
# Step:  77553  Loss:  410286272.0  Total Reward:  40439739.82000003
# price for reward: 9096.01
# Step:  77554  Loss:  402962496.0  Total Reward:  40464398.600000024
# price for reward: 9087.24
# Step:  77555  Loss:  191089616.0  Total Reward:  40424424.94000003
# price for reward: 9087.42
# Step:  77556  Loss:  206523568.0  Total Reward:  40425245.380000025
# price for reward: 9102.89
# Step:  77557  Loss:  155026160.0  Total Reward:  40495757.64000002
# price for reward: 9105.24
# Step:  77558  Loss:  414611328.0  Total Reward:  40506468.94000003
# price for reward: 9105.31
# Step:  77559  Loss:  784599616.0  Total Reward:  40506788.00000002
# price for reward: 9107.48
# Step:  77560  Loss:  243509856.0  Total Reward:  40516678.86000002
# price for reward: 9107.55
# Step:  77561  Loss:  344198464.0  Total Reward:  40516997.920000024
# price for reward: 9117.4
# Step:  77562  Loss:  415954240.0  Total Reward:  40561894.22000002
# price for reward: 9113.28
# Step:  77563  Loss:  445788512.0  Total Reward:  40543115.26000003
# price for reward: 9113.29
# Step:  77564  Loss:  524359200.0  Total Reward:  40543160.840000026
# price for reward: 9107.51
# Step:  77565  Loss:  376321344.0  Total Reward:  40516815.600000024
# price for reward: 9107.51
# Step:  77566  Loss:  458118272.0  Total Reward:  40516815.600000024
# price for reward: 9107.51
# Step:  77567  Loss:  214640320.0  Total Reward:  40516815.600000024
# price for reward: 9098.17
# Step:  77568  Loss:  401336000.0  Total Reward:  40474243.880000025
# price for reward: 9098.02
# Step:  77569  Loss:  192797616.0  Total Reward:  40473560.18000003
# price for reward: 9098.01
# Step:  77570  Loss:  250725216.0  Total Reward:  40473514.600000024
# price for reward: 9088.43
# Step:  77571  Loss:  231195072.0  Total Reward:  40429848.96000002
# price for reward: 9088.53
# Step:  77572  Loss:  237112464.0  Total Reward:  40430304.76000003
# price for reward: 9093.21
# Step:  77573  Loss:  122224368.0  Total Reward:  40451636.200000025
# price for reward: 9093.21
# Step:  77574  Loss:  248055680.0  Total Reward:  40451636.200000025
# price for reward: 9093.19
# Step:  77575  Loss:  596869760.0  Total Reward:  40451545.04000003
# price for reward: 9093.19
# Step:  77576  Loss:  178068976.0  Total Reward:  40451545.04000003
# price for reward: 9087.41
# Step:  77577  Loss:  230235808.0  Total Reward:  40425199.80000003
# price for reward: 9075.0
# Step:  77578  Loss:  542394432.0  Total Reward:  40368635.020000026
# price for reward: 9075.15
# Step:  77579  Loss:  293320192.0  Total Reward:  40369318.72000002
# price for reward: 9078.22
# Step:  77580  Loss:  233781424.0  Total Reward:  40383311.78000002
# price for reward: 9078.84
# Step:  77581  Loss:  990919680.0  Total Reward:  40386137.740000024
# price for reward: 9082.85
# Step:  77582  Loss:  361632384.0  Total Reward:  40404415.32000003
# price for reward: 9075.27
# Step:  77583  Loss:  223078976.0  Total Reward:  40369865.68000003
# price for reward: 9077.5
# Step:  77584  Loss:  215596112.0  Total Reward:  40380030.020000026
# price for reward: 9080.09
# Step:  77585  Loss:  348834112.0  Total Reward:  40391835.240000024
# price for reward: 9084.58
# Step:  77586  Loss:  379283456.0  Total Reward:  40412300.660000026
# price for reward: 9091.84
# Step:  77587  Loss:  175065280.0  Total Reward:  40445391.740000024
# price for reward: 9087.08
# Step:  77588  Loss:  889091840.0  Total Reward:  40423695.660000026
# price for reward: 9086.69
# Step:  77589  Loss:  434984576.0  Total Reward:  40421918.04000003
# price for reward: 9087.65
# Step:  77590  Loss:  483686112.0  Total Reward:  40426293.72000002
# price for reward: 9090.98
# Step:  77591  Loss:  266753760.0  Total Reward:  40426293.72000002
# price for reward: 9097.81
# Step:  77592  Loss:  301504192.0  Total Reward:  40426293.72000002
# price for reward: 9096.81
# Step:  77593  Loss:  287705376.0  Total Reward:  40426293.72000002
# price for reward: 9097.81
# Step:  77594  Loss:  278759808.0  Total Reward:  40426293.72000002
# price for reward: 9095.4
# Step:  77595  Loss:  582204160.0  Total Reward:  40426293.72000002
# price for reward: 9095.4
# Step:  77596  Loss:  150574368.0  Total Reward:  40426293.72000002
# price for reward: 9095.27
# Step:  77597  Loss:  658968064.0  Total Reward:  40426293.72000002
# price for reward: 9097.8
# Step:  77598  Loss:  409541408.0  Total Reward:  40426293.72000002
# price for reward: 9097.81
# Step:  77599  Loss:  229670816.0  Total Reward:  40426293.72000002
# price for reward: 9097.81
# Step:  77600  Loss:  415044064.0  Total Reward:  40426293.72000002
# price for reward: 9096.8
# Step:  77601  Loss:  250151456.0  Total Reward:  40426293.72000002
# price for reward: 9096.82
# Step:  77602  Loss:  589630656.0  Total Reward:  40426293.72000002
# price for reward: 9087.28
# Step:  77603  Loss:  271180160.0  Total Reward:  40426293.72000002
# price for reward: 9086.27
# Step:  77604  Loss:  300620192.0  Total Reward:  40426293.72000002
# price for reward: 9086.27
# Step:  77605  Loss:  432210432.0  Total Reward:  40426293.72000002
# price for reward: 9086.37
# Step:  77606  Loss:  228986784.0  Total Reward:  40426293.72000002
# price for reward: 9079.85
# Step:  77607  Loss:  254830960.0  Total Reward:  40426293.72000002
# price for reward: 9080.86
# Step:  77608  Loss:  96375448.0  Total Reward:  40426293.72000002
# price for reward: 9079.88
# Step:  77609  Loss:  128111544.0  Total Reward:  40421823.94000002
# price for reward: 9075.25
# Step:  77610  Loss:  123533264.0  Total Reward:  40400706.51000002
# price for reward: 9075.42
# Step:  77611  Loss:  184247728.0  Total Reward:  40401481.88000002
# price for reward: 9077.11
# Step:  77612  Loss:  572030272.0  Total Reward:  40409189.97000002
# price for reward: 9079.27
# Step:  77613  Loss:  380591968.0  Total Reward:  40419041.73000002
# price for reward: 9076.03
# Step:  77614  Loss:  164649200.0  Total Reward:  40404264.090000026
# price for reward: 9076.07
# Step:  77615  Loss:  326498144.0  Total Reward:  40404264.090000026
# price for reward: 9078.31
# Step:  77616  Loss:  254103552.0  Total Reward:  40404264.090000026
# price for reward: 9075.0
# Step:  77617  Loss:  111180400.0  Total Reward:  40389170.49000003
# price for reward: 9075.01
# Step:  77618  Loss:  225154112.0  Total Reward:  40389216.09000003
# price for reward: 9067.79
# Step:  77619  Loss:  310643200.0  Total Reward:  40356292.89000004
# price for reward: 9080.43
# Step:  77620  Loss:  384288704.0  Total Reward:  40413931.29000004
# price for reward: 9068.92
# Step:  77621  Loss:  214358880.0  Total Reward:  40361445.690000035
# price for reward: 9070.06
# Step:  77622  Loss:  181100720.0  Total Reward:  40366644.090000026
# price for reward: 9070.07
# Step:  77623  Loss:  486682944.0  Total Reward:  40366689.69000003
# price for reward: 9070.07
# Step:  77624  Loss:  928888128.0  Total Reward:  40366689.69000003
# price for reward: 9062.34
# Step:  77625  Loss:  208199408.0  Total Reward:  40331440.89000003
# price for reward: 9059.39
# Step:  77626  Loss:  286449376.0  Total Reward:  40317988.89000003
# price for reward: 9067.78
# Step:  77627  Loss:  380891040.0  Total Reward:  40356247.29000004
# price for reward: 9065.16
# Step:  77628  Loss:  501620448.0  Total Reward:  40344300.09000003
# price for reward: 9060.43
# Step:  77629  Loss:  240842000.0  Total Reward:  40322731.29000004
# price for reward: 9064.56
# Step:  77630  Loss:  331691584.0  Total Reward:  40341564.090000026
# price for reward: 9064.02
# Step:  77631  Loss:  374268288.0  Total Reward:  40339101.690000035
# price for reward: 9067.01
# Step:  77632  Loss:  681664704.0  Total Reward:  40352736.09000003
# price for reward: 9068.01
# Step:  77633  Loss:  372028128.0  Total Reward:  40357296.09000003
# price for reward: 9063.15
# Step:  77634  Loss:  247238976.0  Total Reward:  40335134.49000003
# price for reward: 9054.03
# Step:  77635  Loss:  226453376.0  Total Reward:  40293547.29000004
# price for reward: 9054.03
# Step:  77636  Loss:  626841728.0  Total Reward:  40293547.29000004
# price for reward: 9054.18
# Step:  77637  Loss:  540352768.0  Total Reward:  40294231.29000004
# price for reward: 9047.78
# Step:  77638  Loss:  99965792.0  Total Reward:  40265047.29000004
# price for reward: 9043.27
# Step:  77639  Loss:  246544848.0  Total Reward:  40244481.690000035
# price for reward: 9040.93
# Step:  77640  Loss:  234747648.0  Total Reward:  40233811.29000004
# price for reward: 9051.32
# Step:  77641  Loss:  358166912.0  Total Reward:  40281189.69000003
# price for reward: 9052.0
# Step:  77642  Loss:  235921664.0  Total Reward:  40284290.49000003
# price for reward: 9038.81
# Step:  77643  Loss:  323126400.0  Total Reward:  40224144.090000026
# price for reward: 9042.79
# Step:  77644  Loss:  146223376.0  Total Reward:  40242292.89000004
# price for reward: 9042.79
# Step:  77645  Loss:  520335264.0  Total Reward:  40242292.89000004
# price for reward: 9050.86
# Step:  77646  Loss:  188226432.0  Total Reward:  40279092.09000003
# price for reward: 9038.07
# Step:  77647  Loss:  205000496.0  Total Reward:  40220769.69000003
# price for reward: 9038.07
# Step:  77648  Loss:  131618656.0  Total Reward:  40220769.69000003
# price for reward: 9029.69
# Step:  77649  Loss:  724594560.0  Total Reward:  40182556.89000004
# price for reward: 9034.19
# Step:  77650  Loss:  688394816.0  Total Reward:  40203076.89000004
# price for reward: 9041.4
# Step:  77651  Loss:  602734080.0  Total Reward:  40235954.49000003
# price for reward: 9045.95
# Step:  77652  Loss:  262960640.0  Total Reward:  40256702.49000003
# price for reward: 9053.23
# Step:  77653  Loss:  306277024.0  Total Reward:  40289899.29000003
# price for reward: 9049.0
# Step:  77654  Loss:  235844160.0  Total Reward:  40270610.49000003
# price for reward: 9045.57
# Step:  77655  Loss:  133989552.0  Total Reward:  40254969.69000003
# price for reward: 9047.03
# Step:  77656  Loss:  291483584.0  Total Reward:  40261627.29000004
# price for reward: 9047.03
# Step:  77657  Loss:  319278976.0  Total Reward:  40261627.29000004
# price for reward: 9047.03
# Step:  77658  Loss:  237649504.0  Total Reward:  40261627.29000004
# price for reward: 9047.03
# Step:  77659  Loss:  272851552.0  Total Reward:  40261627.29000004
# price for reward: 9057.32
# Step:  77660  Loss:  445919392.0  Total Reward:  40308549.69000003
# price for reward: 9055.72
# Step:  77661  Loss:  324024864.0  Total Reward:  40301253.69000003
# price for reward: 9055.72
# Step:  77662  Loss:  666724992.0  Total Reward:  40301253.69000003
# price for reward: 9063.6
# Step:  77663  Loss:  641358144.0  Total Reward:  40337186.49000003
# price for reward: 9072.08
# Step:  77664  Loss:  525224416.0  Total Reward:  40375855.29000003
# price for reward: 9072.71
# Step:  77665  Loss:  267907296.0  Total Reward:  40378728.090000026
# price for reward: 9077.18
# Step:  77666  Loss:  219491568.0  Total Reward:  40378728.090000026
# price for reward: 9069.65
# Step:  77667  Loss:  221699520.0  Total Reward:  40378728.090000026
# price for reward: 9068.13
# Step:  77668  Loss:  265254592.0  Total Reward:  40378728.090000026
# price for reward: 9068.88
# Step:  77669  Loss:  419393920.0  Total Reward:  40378728.090000026
# price for reward: 9063.84
# Step:  77670  Loss:  208598400.0  Total Reward:  40378728.090000026
# price for reward: 9064.78
# Step:  77671  Loss:  528457024.0  Total Reward:  40378728.090000026
# price for reward: 9065.67
# Step:  77672  Loss:  206370752.0  Total Reward:  40378728.090000026
# price for reward: 9063.55
# Step:  77673  Loss:  219935312.0  Total Reward:  40378728.090000026
# price for reward: 9062.69
# Step:  77674  Loss:  190041008.0  Total Reward:  40378728.090000026
# price for reward: 9062.73
# Step:  77675  Loss:  212460896.0  Total Reward:  40378910.69000002
# price for reward: 9062.69
# Step:  77676  Loss:  156291920.0  Total Reward:  40378728.090000026
# price for reward: 9065.01
# Step:  77677  Loss:  151012224.0  Total Reward:  40389318.89000002
# price for reward: 9065.4
# Step:  77678  Loss:  487617792.0  Total Reward:  40391099.240000024
# price for reward: 9065.01
# Step:  77679  Loss:  1148549632.0  Total Reward:  40389318.89000002
# price for reward: 9065.02
# Step:  77680  Loss:  132945808.0  Total Reward:  40389364.54000003
# price for reward: 9072.22
# Step:  77681  Loss:  190728096.0  Total Reward:  40422232.54000002
# price for reward: 9080.01
# Step:  77682  Loss:  102442416.0  Total Reward:  40457793.89000002
# price for reward: 9081.91
# Step:  77683  Loss:  564025408.0  Total Reward:  40466467.39000002
# price for reward: 9079.96
# Step:  77684  Loss:  484751840.0  Total Reward:  40466467.39000002
# price for reward: 9079.98
# Step:  77685  Loss:  1259293312.0  Total Reward:  40466467.39000002
# price for reward: 9077.63
# Step:  77686  Loss:  78742760.0  Total Reward:  40466467.39000002
# price for reward: 9074.31
# Step:  77687  Loss:  154920272.0  Total Reward:  40466467.39000002
# price for reward: 9074.34
# Step:  77688  Loss:  373891072.0  Total Reward:  40466467.39000002
# price for reward: 9077.05
# Step:  77689  Loss:  966153664.0  Total Reward:  40466467.39000002
# price for reward: 9077.05
# Step:  77690  Loss:  199924944.0  Total Reward:  40466467.39000002
# price for reward: 9074.34
# Step:  77691  Loss:  234696272.0  Total Reward:  40454088.11000002
# price for reward: 9074.37
# Step:  77692  Loss:  426522656.0  Total Reward:  40454225.15000003
# price for reward: 9074.37
# Step:  77693  Loss:  262886272.0  Total Reward:  40454225.15000003
# price for reward: 9062.68
# Step:  77694  Loss:  304216704.0  Total Reward:  40400825.23000003
# price for reward: 9056.03
# Step:  77695  Loss:  206052912.0  Total Reward:  40370448.03000003
# price for reward: 9056.06
# Step:  77696  Loss:  124576744.0  Total Reward:  40370585.07000002
# price for reward: 9061.84
# Step:  77697  Loss:  330463776.0  Total Reward:  40396988.11000002
# price for reward: 9060.67
# Step:  77698  Loss:  496899008.0  Total Reward:  40391643.55000003
# price for reward: 9062.56
# Step:  77699  Loss:  639167552.0  Total Reward:  40400277.07000002
# price for reward: 9062.56
# Step:  77700  Loss:  448193984.0  Total Reward:  40400277.07000002
# price for reward: 9062.6
# Step:  77701  Loss:  305456992.0  Total Reward:  40400459.79000003
# price for reward: 9067.08
# Step:  77702  Loss:  379236608.0  Total Reward:  40420924.43000002
# price for reward: 9067.12
# Step:  77703  Loss:  410562848.0  Total Reward:  40421107.15000003
# price for reward: 9071.72
# Step:  77704  Loss:  621700736.0  Total Reward:  40442119.95000002
# price for reward: 9075.12
# Step:  77705  Loss:  480901472.0  Total Reward:  40457651.15000003
# price for reward: 9079.19
# Step:  77706  Loss:  151840240.0  Total Reward:  40476242.910000026
# price for reward: 9077.87
# Step:  77707  Loss:  109903232.0  Total Reward:  40470213.15000003
# price for reward: 9075.12
# Step:  77708  Loss:  153624416.0  Total Reward:  40457651.15000003
# price for reward: 9069.47
# Step:  77709  Loss:  254023920.0  Total Reward:  40431841.95000002
# price for reward: 9073.79
# Step:  77710  Loss:  423550336.0  Total Reward:  40451575.71000003
# price for reward: 9073.82
# Step:  77711  Loss:  194050624.0  Total Reward:  40451712.75000002
# price for reward: 9073.8
# Step:  77712  Loss:  388034880.0  Total Reward:  40451621.39000002
# price for reward: 9073.84
# Step:  77713  Loss:  477216384.0  Total Reward:  40451804.11000002
# price for reward: 9082.15
# Step:  77714  Loss:  410871712.0  Total Reward:  40489764.19000002
# price for reward: 9083.12
# Step:  77715  Loss:  381361408.0  Total Reward:  40494195.15000003
# price for reward: 9083.21
# Step:  77716  Loss:  101213720.0  Total Reward:  40494606.27000002
# price for reward: 9079.99
# Step:  77717  Loss:  227661120.0  Total Reward:  40479897.310000025
# price for reward: 9080.12
# Step:  77718  Loss:  311724672.0  Total Reward:  40480491.15000003
# price for reward: 9083.52
# Step:  77719  Loss:  843119488.0  Total Reward:  40496022.350000024
# price for reward: 9082.22
# Step:  77720  Loss:  208833328.0  Total Reward:  40490083.95000002
# price for reward: 9080.32
# Step:  77721  Loss:  338141504.0  Total Reward:  40481404.75000002
# price for reward: 9081.27
# Step:  77722  Loss:  298013984.0  Total Reward:  40485744.350000024
# price for reward: 9081.38
# Step:  77723  Loss:  313891136.0  Total Reward:  40486246.83000002
# price for reward: 9081.38
# Step:  77724  Loss:  160604160.0  Total Reward:  40486246.83000002
# price for reward: 9081.24
# Step:  77725  Loss:  216903120.0  Total Reward:  40485607.310000025
# price for reward: 9081.25
# Step:  77726  Loss:  296422016.0  Total Reward:  40485652.990000024
# price for reward: 9084.11
# Step:  77727  Loss:  338759936.0  Total Reward:  40498717.47000003
# price for reward: 9092.93
# Step:  77728  Loss:  265096976.0  Total Reward:  40539007.23000003
# price for reward: 9097.8
# Step:  77729  Loss:  404047488.0  Total Reward:  40561253.39000002
# price for reward: 9097.24
# Step:  77730  Loss:  160121280.0  Total Reward:  40558695.310000025
# price for reward: 9094.38
# Step:  77731  Loss:  648055616.0  Total Reward:  40558695.310000025
# price for reward: 9092.04
# Step:  77732  Loss:  470485824.0  Total Reward:  40558695.310000025
# price for reward: 9093.7
# Step:  77733  Loss:  101689904.0  Total Reward:  40558695.310000025
# price for reward: 9085.96
# Step:  77734  Loss:  220682144.0  Total Reward:  40558695.310000025
# price for reward: 9088.48
# Step:  77735  Loss:  290301312.0  Total Reward:  40558695.310000025
# price for reward: 9087.85
# Step:  77736  Loss:  1303792128.0  Total Reward:  40558695.310000025
# price for reward: 9089.26
# Step:  77737  Loss:  167736688.0  Total Reward:  40558695.310000025
# price for reward: 9094.17
# Step:  77738  Loss:  307731264.0  Total Reward:  40558695.310000025
# price for reward: 9096.81
# Step:  77739  Loss:  289823360.0  Total Reward:  40558695.310000025
# price for reward: 9097.66
# Step:  77740  Loss:  412497728.0  Total Reward:  40558695.310000025
# price for reward: 9096.3
# Step:  77741  Loss:  172588992.0  Total Reward:  40558695.310000025
# price for reward: 9096.31
# Step:  77742  Loss:  123670192.0  Total Reward:  40558695.310000025
# price for reward: 9093.37
# Step:  77743  Loss:  385735456.0  Total Reward:  40558695.310000025
# price for reward: 9085.27
# Step:  77744  Loss:  257899536.0  Total Reward:  40558695.310000025
# price for reward: 9086.97
# Step:  77745  Loss:  285735008.0  Total Reward:  40558695.310000025
# price for reward: 9091.27
# Step:  77746  Loss:  340576640.0  Total Reward:  40558695.310000025
# price for reward: 9085.34
# Step:  77747  Loss:  373585344.0  Total Reward:  40558695.310000025
# price for reward: 9085.34
# Step:  77748  Loss:  169299408.0  Total Reward:  40558695.310000025
# price for reward: 9085.51
# Step:  77749  Loss:  214655056.0  Total Reward:  40558695.310000025
# price for reward: 9085.53
# Step:  77750  Loss:  302603488.0  Total Reward:  40558695.310000025
# price for reward: 9085.55
# Step:  77751  Loss:  521613920.0  Total Reward:  40558695.310000025
# price for reward: 9085.63
# Step:  77752  Loss:  498249824.0  Total Reward:  40558695.310000025
# price for reward: 9089.11
# Step:  77753  Loss:  732166528.0  Total Reward:  40558695.310000025
# price for reward: 9089.77
# Step:  77754  Loss:  503278752.0  Total Reward:  40558695.310000025
# price for reward: 9090.23
# Step:  77755  Loss:  360079584.0  Total Reward:  40558695.310000025
# price for reward: 9087.91
# Step:  77756  Loss:  543560256.0  Total Reward:  40548090.590000026
# price for reward: 9087.93
# Step:  77757  Loss:  104050808.0  Total Reward:  40548182.01000003
# price for reward: 9082.27
# Step:  77758  Loss:  602170176.0  Total Reward:  40522310.15000003
# price for reward: 9083.05
# Step:  77759  Loss:  228588208.0  Total Reward:  40525875.53000002
# price for reward: 9090.1
# Step:  77760  Loss:  272692256.0  Total Reward:  40558101.08000003
# price for reward: 9092.01
# Step:  77761  Loss:  475124448.0  Total Reward:  40566831.69000003
# price for reward: 9092.01
# Step:  77762  Loss:  257292960.0  Total Reward:  40566831.69000003
# price for reward: 9092.01
# Step:  77763  Loss:  380931744.0  Total Reward:  40566831.69000003
# price for reward: 9092.01
# Step:  77764  Loss:  162393888.0  Total Reward:  40566831.69000003
# price for reward: 9092.78
# Step:  77765  Loss:  107921440.0  Total Reward:  40570351.36000003
# price for reward: 9092.01
# Step:  77766  Loss:  332520288.0  Total Reward:  40566831.69000003
# price for reward: 9092.01
# Step:  77767  Loss:  591156352.0  Total Reward:  40566831.69000003
# price for reward: 9092.05
# Step:  77768  Loss:  422122112.0  Total Reward:  40567014.53000002
# price for reward: 9092.04
# Step:  77769  Loss:  272066912.0  Total Reward:  40566968.82000003
# price for reward: 9092.04
# Step:  77770  Loss:  564549120.0  Total Reward:  40566968.82000003
# price for reward: 9092.0
# Step:  77771  Loss:  334649856.0  Total Reward:  40566785.98000003
# price for reward: 9092.01
# Step:  77772  Loss:  346394048.0  Total Reward:  40566831.69000003
# price for reward: 9085.84
# Step:  77773  Loss:  434091456.0  Total Reward:  40538628.62000003
# price for reward: 9095.01
# Step:  77774  Loss:  257943088.0  Total Reward:  40580544.69000003
# price for reward: 9095.01
# Step:  77775  Loss:  317132640.0  Total Reward:  40580544.69000003
# price for reward: 9095.77
# Step:  77776  Loss:  541405568.0  Total Reward:  40584018.65000003
# price for reward: 9095.77
# Step:  77777  Loss:  252606400.0  Total Reward:  40584018.65000003
# price for reward: 9095.02
# Step:  77778  Loss:  337031488.0  Total Reward:  40580590.40000003
# price for reward: 9095.56
# Step:  77779  Loss:  267851152.0  Total Reward:  40583058.740000024
# price for reward: 9095.58
# Step:  77780  Loss:  323441824.0  Total Reward:  40583150.160000026
# price for reward: 9095.56
# Step:  77781  Loss:  279137344.0  Total Reward:  40583058.740000024
# price for reward: 9096.43
# Step:  77782  Loss:  142184912.0  Total Reward:  40583058.740000024
# price for reward: 9097.33
# Step:  77783  Loss:  145098288.0  Total Reward:  40583058.740000024
# price for reward: 9095.54
# Step:  77784  Loss:  240186976.0  Total Reward:  40583058.740000024
# price for reward: 9090.7
# Step:  77785  Loss:  384505856.0  Total Reward:  40583058.740000024
# price for reward: 9090.7
# Step:  77786  Loss:  528368416.0  Total Reward:  40583058.740000024
# price for reward: 9091.63
# Step:  77787  Loss:  186298464.0  Total Reward:  40583058.740000024
# price for reward: 9090.41
# Step:  77788  Loss:  157507776.0  Total Reward:  40583058.740000024
# price for reward: 9086.12
# Step:  77789  Loss:  763408256.0  Total Reward:  40583058.740000024
# price for reward: 9085.9
# Step:  77790  Loss:  627977216.0  Total Reward:  40583058.740000024
# price for reward: 9081.3
# Step:  77791  Loss:  224115664.0  Total Reward:  40562009.14000002
# price for reward: 9081.31
# Step:  77792  Loss:  982961152.0  Total Reward:  40562054.90000002
# price for reward: 9081.54
# Step:  77793  Loss:  532370304.0  Total Reward:  40563107.38000003
# price for reward: 9083.59
# Step:  77794  Loss:  298461376.0  Total Reward:  40572488.18000003
# price for reward: 9081.58
# Step:  77795  Loss:  279517952.0  Total Reward:  40563290.420000024
# price for reward: 9081.28
# Step:  77796  Loss:  130966376.0  Total Reward:  40561917.62000003
# price for reward: 9081.95
# Step:  77797  Loss:  682471744.0  Total Reward:  40564983.54000003
# price for reward: 9081.94
# Step:  77798  Loss:  482830592.0  Total Reward:  40564937.78000003
# price for reward: 9085.7
# Step:  77799  Loss:  346202816.0  Total Reward:  40582143.54000003
# price for reward: 9085.7
# Step:  77800  Loss:  428959264.0  Total Reward:  40582143.54000003
# price for reward: 9086.59
# Step:  77801  Loss:  216801776.0  Total Reward:  40586216.18000003
# price for reward: 9087.43
# Step:  77802  Loss:  855890816.0  Total Reward:  40590060.020000026
# price for reward: 9087.44
# Step:  77803  Loss:  405009856.0  Total Reward:  40590105.78000003
# price for reward: 9088.35
# Step:  77804  Loss:  379694272.0  Total Reward:  40594269.94000003
# price for reward: 9087.43
# Step:  77805  Loss:  285033792.0  Total Reward:  40590060.020000026
# price for reward: 9088.57
# Step:  77806  Loss:  465544128.0  Total Reward:  40595276.660000026
# price for reward: 9087.62
# Step:  77807  Loss:  134186176.0  Total Reward:  40590929.46000003
# price for reward: 9087.7
# Step:  77808  Loss:  267065200.0  Total Reward:  40591295.54000003
# price for reward: 9089.44
# Step:  77809  Loss:  155428512.0  Total Reward:  40599257.78000003
# price for reward: 9089.44
# Step:  77810  Loss:  385336224.0  Total Reward:  40599257.78000003
# price for reward: 9089.44
# Step:  77811  Loss:  299634304.0  Total Reward:  40599257.78000003
# price for reward: 9091.63
# Step:  77812  Loss:  386174496.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77813  Loss:  255965728.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77814  Loss:  484433280.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77815  Loss:  137791136.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77816  Loss:  433165440.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77817  Loss:  345444384.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77818  Loss:  413671808.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77819  Loss:  175574080.0  Total Reward:  40609279.22000002
# price for reward: 9091.62
# Step:  77820  Loss:  329139200.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77821  Loss:  638670336.0  Total Reward:  40609279.22000002
# price for reward: 9091.62
# Step:  77822  Loss:  203181808.0  Total Reward:  40609279.22000002
# price for reward: 9091.63
# Step:  77823  Loss:  446769312.0  Total Reward:  40609279.22000002
# price for reward: 9087.64
# Step:  77824  Loss:  169725888.0  Total Reward:  40609279.22000002
# price for reward: 9087.69
# Step:  77825  Loss:  273682752.0  Total Reward:  40609279.22000002
# price for reward: 9087.7
# Step:  77826  Loss:  313285088.0  Total Reward:  40609279.22000002
# price for reward: 9087.7
# Step:  77827  Loss:  904781632.0  Total Reward:  40609279.22000002
# price for reward: 9087.69
# Step:  77828  Loss:  459684352.0  Total Reward:  40609279.22000002
# price for reward: 9087.71
# Step:  77829  Loss:  323546432.0  Total Reward:  40609279.22000002
# price for reward: 9088.26
# Step:  77830  Loss:  140228960.0  Total Reward:  40609279.22000002
# price for reward: 9088.05
# Step:  77831  Loss:  349966016.0  Total Reward:  40609279.22000002
# price for reward: 9088.05
# Step:  77832  Loss:  863035264.0  Total Reward:  40609279.22000002
# price for reward: 9088.05
# Step:  77833  Loss:  309219360.0  Total Reward:  40609279.22000002
# price for reward: 9088.05
# Step:  77834  Loss:  424012896.0  Total Reward:  40609279.22000002
# price for reward: 9090.33
# Step:  77835  Loss:  338753376.0  Total Reward:  40609279.22000002
# price for reward: 9088.05
# Step:  77836  Loss:  461165056.0  Total Reward:  40609279.22000002
# price for reward: 9088.06
# Step:  77837  Loss:  131160576.0  Total Reward:  40609279.22000002
# price for reward: 9085.57
# Step:  77838  Loss:  166733264.0  Total Reward:  40609279.22000002
# price for reward: 9085.57
# Step:  77839  Loss:  191004544.0  Total Reward:  40609279.22000002
# price for reward: 9086.55
# Step:  77840  Loss:  184671216.0  Total Reward:  40609279.22000002
# price for reward: 9083.03
# Step:  77841  Loss:  215618480.0  Total Reward:  40609279.22000002
# price for reward: 9083.04
# Step:  77842  Loss:  265720544.0  Total Reward:  40609325.02000002
# price for reward: 9083.04
# Step:  77843  Loss:  381505792.0  Total Reward:  40609325.02000002
# price for reward: 9087.02
# Step:  77844  Loss:  673874944.0  Total Reward:  40627553.42000002
# price for reward: 9091.25
# Step:  77845  Loss:  158283600.0  Total Reward:  40646926.820000015
# price for reward: 9091.62
# Step:  77846  Loss:  195315584.0  Total Reward:  40648621.42000002
# price for reward: 9090.29
# Step:  77847  Loss:  60486292.0  Total Reward:  40642530.02000002
# price for reward: 9090.29
# Step:  77848  Loss:  374686048.0  Total Reward:  40642530.02000002
# price for reward: 9090.33
# Step:  77849  Loss:  182222896.0  Total Reward:  40642713.22000001
# price for reward: 9090.3
# Step:  77850  Loss:  359715264.0  Total Reward:  40642575.820000015
# price for reward: 9090.3
# Step:  77851  Loss:  245106672.0  Total Reward:  40642575.820000015
# price for reward: 9090.3
# Step:  77852  Loss:  131834496.0  Total Reward:  40642575.820000015
# price for reward: 9095.22
# Step:  77853  Loss:  742718912.0  Total Reward:  40665109.42000001
# price for reward: 9095.22
# Step:  77854  Loss:  641124992.0  Total Reward:  40665109.42000001
# price for reward: 9095.23
# Step:  77855  Loss:  427423008.0  Total Reward:  40665155.22000001
# price for reward: 9095.23
# Step:  77856  Loss:  178700016.0  Total Reward:  40665155.22000001
# price for reward: 9107.87
# Step:  77857  Loss:  165786496.0  Total Reward:  40723046.42000002
# price for reward: 9104.62
# Step:  77858  Loss:  388925920.0  Total Reward:  40708161.42000002
# price for reward: 9105.86
# Step:  77859  Loss:  181779312.0  Total Reward:  40708161.42000002
# price for reward: 9106.71
# Step:  77860  Loss:  822221568.0  Total Reward:  40708161.42000002
# price for reward: 9109.25
# Step:  77861  Loss:  363876256.0  Total Reward:  40708161.42000002
# price for reward: 9110.12
# Step:  77862  Loss:  84700208.0  Total Reward:  40708161.42000002
# price for reward: 9110.24
# Step:  77863  Loss:  99554064.0  Total Reward:  40708161.42000002
# price for reward: 9111.2
# Step:  77864  Loss:  495948704.0  Total Reward:  40708161.42000002
# price for reward: 9105.89
# Step:  77865  Loss:  2165697792.0  Total Reward:  40708161.42000002
# price for reward: 9109.78
# Step:  77866  Loss:  217500896.0  Total Reward:  40708161.42000002
# price for reward: 9116.82
# Step:  77867  Loss:  167968272.0  Total Reward:  40708161.42000002
# price for reward: 9116.82
# Step:  77868  Loss:  418834560.0  Total Reward:  40708161.42000002
# price for reward: 9119.87
# Step:  77869  Loss:  357762816.0  Total Reward:  40708161.42000002
# price for reward: 9118.14
# Step:  77870  Loss:  429971776.0  Total Reward:  40708161.42000002
# price for reward: 9119.86
# Step:  77871  Loss:  329234656.0  Total Reward:  40708161.42000002
# price for reward: 9119.75
# Step:  77872  Loss:  188779568.0  Total Reward:  40708161.42000002
# price for reward: 9119.09
# Step:  77873  Loss:  231193344.0  Total Reward:  40708161.42000002
# price for reward: 9116.24
# Step:  77874  Loss:  250578400.0  Total Reward:  40708161.42000002
# price for reward: 9115.06
# Step:  77875  Loss:  188455040.0  Total Reward:  40708161.42000002
# price for reward: 9115.08
# Step:  77876  Loss:  397245504.0  Total Reward:  40708161.42000002
# price for reward: 9116.93
# Step:  77877  Loss:  370775360.0  Total Reward:  40708161.42000002
# price for reward: 9115.07
# Step:  77878  Loss:  199957072.0  Total Reward:  40708161.42000002
# price for reward: 9117.35
# Step:  77879  Loss:  283536928.0  Total Reward:  40708161.42000002
# price for reward: 9115.08
# Step:  77880  Loss:  328570688.0  Total Reward:  40708161.42000002
# price for reward: 9115.85
# Step:  77881  Loss:  353822688.0  Total Reward:  40708161.42000002
# price for reward: 9116.09
# Step:  77882  Loss:  550900608.0  Total Reward:  40708161.42000002
# price for reward: 9116.0
# Step:  77883  Loss:  171261376.0  Total Reward:  40708161.42000002
# price for reward: 9116.0
# Step:  77884  Loss:  436080736.0  Total Reward:  40708161.42000002
# price for reward: 9112.4
# Step:  77885  Loss:  149312944.0  Total Reward:  40708161.42000002
# price for reward: 9106.94
# Step:  77886  Loss:  698489664.0  Total Reward:  40708161.42000002
# price for reward: 9106.94
# Step:  77887  Loss:  188073232.0  Total Reward:  40708161.42000002
# price for reward: 9106.99
# Step:  77888  Loss:  159978848.0  Total Reward:  40708161.42000002
# price for reward: 9107.01
# Step:  77889  Loss:  193577424.0  Total Reward:  40708253.000000015
# price for reward: 9113.46
# Step:  77890  Loss:  117771872.0  Total Reward:  40737787.55000001
# price for reward: 9107.86
# Step:  77891  Loss:  317608896.0  Total Reward:  40712145.15000002
# price for reward: 9108.75
# Step:  77892  Loss:  1010546624.0  Total Reward:  40716220.460000016
# price for reward: 9112.16
# Step:  77893  Loss:  408369504.0  Total Reward:  40731834.85000002
# price for reward: 9113.15
# Step:  77894  Loss:  788260224.0  Total Reward:  40736368.06000002
# price for reward: 9113.17
# Step:  77895  Loss:  224149216.0  Total Reward:  40736459.640000015
# price for reward: 9113.14
# Step:  77896  Loss:  505593952.0  Total Reward:  40736322.27000001
# price for reward: 9113.14
# Step:  77897  Loss:  270018528.0  Total Reward:  40736322.27000001
# price for reward: 9114.12
# Step:  77898  Loss:  263886304.0  Total Reward:  40740809.69000002
# price for reward: 9115.72
# Step:  77899  Loss:  500189664.0  Total Reward:  40748136.09000001
# price for reward: 9115.75
# Step:  77900  Loss:  1156156544.0  Total Reward:  40748273.460000016
# price for reward: 9115.82
# Step:  77901  Loss:  178773408.0  Total Reward:  40748593.99000002
# price for reward: 9115.87
# Step:  77902  Loss:  278183104.0  Total Reward:  40748822.94000002
# price for reward: 9115.87
# Step:  77903  Loss:  207356640.0  Total Reward:  40748822.94000002
# price for reward: 9121.2
# Step:  77904  Loss:  769527360.0  Total Reward:  40773229.01000002
# price for reward: 9118.57
# Step:  77905  Loss:  142113248.0  Total Reward:  40761186.24000002
# price for reward: 9128.9
# Step:  77906  Loss:  199983552.0  Total Reward:  40808487.31000002
# price for reward: 9127.82
# Step:  77907  Loss:  420068544.0  Total Reward:  40803541.99000002
# price for reward: 9127.81
# Step:  77908  Loss:  209035808.0  Total Reward:  40803496.20000001
# price for reward: 9120.73
# Step:  77909  Loss:  417695680.0  Total Reward:  40771076.88000001
# price for reward: 9120.73
# Step:  77910  Loss:  732543808.0  Total Reward:  40771076.88000001
# price for reward: 9120.73
# Step:  77911  Loss:  377365888.0  Total Reward:  40771076.88000001
# price for reward: 9126.83
# Step:  77912  Loss:  541907840.0  Total Reward:  40799008.780000016
# price for reward: 9122.23
# Step:  77913  Loss:  165564720.0  Total Reward:  40777945.38000001
# price for reward: 9122.23
# Step:  77914  Loss:  237772912.0  Total Reward:  40777945.38000001
# price for reward: 9122.26
# Step:  77915  Loss:  226544704.0  Total Reward:  40778082.750000015
# price for reward: 9122.46
# Step:  77916  Loss:  426977408.0  Total Reward:  40778998.55000001
# price for reward: 9121.52
# Step:  77917  Loss:  133764464.0  Total Reward:  40774694.29000002
# price for reward: 9123.33
# Step:  77918  Loss:  446312128.0  Total Reward:  40782982.280000016
# price for reward: 9126.88
# Step:  77919  Loss:  340196992.0  Total Reward:  40799237.73000001
# price for reward: 9118.58
# Step:  77920  Loss:  293288736.0  Total Reward:  40761232.030000016
# price for reward: 9118.58
# Step:  77921  Loss:  303924768.0  Total Reward:  40761232.030000016
# price for reward: 9123.26
# Step:  77922  Loss:  251641568.0  Total Reward:  40782661.750000015
# price for reward: 9123.4
# Step:  77923  Loss:  648040640.0  Total Reward:  40783302.81000002
# price for reward: 9118.29
# Step:  77924  Loss:  136227456.0  Total Reward:  40759904.12000002
# price for reward: 9120.75
# Step:  77925  Loss:  274120832.0  Total Reward:  40771168.460000016
# price for reward: 9124.41
# Step:  77926  Loss:  246366592.0  Total Reward:  40787927.60000002
# price for reward: 9124.43
# Step:  77927  Loss:  175856192.0  Total Reward:  40788019.180000015
# price for reward: 9124.43
# Step:  77928  Loss:  217097184.0  Total Reward:  40788019.180000015
# price for reward: 9122.12
# Step:  77929  Loss:  68438536.0  Total Reward:  40777441.69000002
# price for reward: 9122.21
# Step:  77930  Loss:  445181696.0  Total Reward:  40777853.80000001
# price for reward: 9122.25
# Step:  77931  Loss:  381688544.0  Total Reward:  40778036.960000016
# price for reward: 9123.15
# Step:  77932  Loss:  160895744.0  Total Reward:  40782158.06000002
# price for reward: 9123.12
# Step:  77933  Loss:  646814016.0  Total Reward:  40782020.69000002
# price for reward: 9127.13
# Step:  77934  Loss:  667137536.0  Total Reward:  40800382.48000001
# price for reward: 9123.18
# Step:  77935  Loss:  96280336.0  Total Reward:  40782295.430000015
# price for reward: 9123.16
# Step:  77936  Loss:  102940640.0  Total Reward:  40782203.85000002
# price for reward: 9117.31
# Step:  77937  Loss:  387793952.0  Total Reward:  40755416.70000001
# price for reward: 9115.73
# Step:  77938  Loss:  552427840.0  Total Reward:  40748181.88000001
# price for reward: 9115.72
# Step:  77939  Loss:  636729664.0  Total Reward:  40748136.09000001
# price for reward: 9115.72
# Step:  77940  Loss:  312633312.0  Total Reward:  40748136.09000001
# price for reward: 9115.72
# Step:  77941  Loss:  127695832.0  Total Reward:  40748136.09000001
# price for reward: 9115.75
# Step:  77942  Loss:  271174752.0  Total Reward:  40748273.460000016
# price for reward: 9115.73
# Step:  77943  Loss:  221105584.0  Total Reward:  40748181.88000001
# price for reward: 9115.73
# Step:  77944  Loss:  216225120.0  Total Reward:  40748181.88000001
# price for reward: 9115.87
# Step:  77945  Loss:  105159032.0  Total Reward:  40748822.94000002
# price for reward: 9123.4
# Step:  77946  Loss:  396578496.0  Total Reward:  40783302.81000002
# price for reward: 9117.82
# Step:  77947  Loss:  307894880.0  Total Reward:  40757751.99000002
# price for reward: 9118.15
# Step:  77948  Loss:  134166520.0  Total Reward:  40759263.06000002
# price for reward: 9118.19
# Step:  77949  Loss:  252565824.0  Total Reward:  40759446.22000002
# price for reward: 9124.5
# Step:  77950  Loss:  286655168.0  Total Reward:  40788339.710000016
# price for reward: 9125.94
# Step:  77951  Loss:  194097056.0  Total Reward:  40794933.47000002
# price for reward: 9129.87
# Step:  77952  Loss:  234007856.0  Total Reward:  40812928.94000002
# price for reward: 9125.97
# Step:  77953  Loss:  424037824.0  Total Reward:  40812928.94000002
# price for reward: 9125.97
# Step:  77954  Loss:  183611296.0  Total Reward:  40812928.94000002
# price for reward: 9126.31
# Step:  77955  Loss:  259471504.0  Total Reward:  40812928.94000002
# price for reward: 9126.34
# Step:  77956  Loss:  192739216.0  Total Reward:  40812928.94000002
# price for reward: 9126.44
# Step:  77957  Loss:  435404576.0  Total Reward:  40813387.04000002
# price for reward: 9126.44
# Step:  77958  Loss:  121196528.0  Total Reward:  40813387.04000002
# price for reward: 9131.23
# Step:  77959  Loss:  225024688.0  Total Reward:  40835330.030000016
# price for reward: 9130.25
# Step:  77960  Loss:  304174624.0  Total Reward:  40830840.65000002
# price for reward: 9129.38
# Step:  77961  Loss:  358646656.0  Total Reward:  40826855.180000015
# price for reward: 9128.82
# Step:  77962  Loss:  454869440.0  Total Reward:  40824289.82000002
# price for reward: 9128.83
# Step:  77963  Loss:  179202144.0  Total Reward:  40824335.63000002
# price for reward: 9128.86
# Step:  77964  Loss:  440605920.0  Total Reward:  40824473.060000025
# price for reward: 9129.38
# Step:  77965  Loss:  145855360.0  Total Reward:  40826855.180000015
# price for reward: 9132.51
# Step:  77966  Loss:  254668288.0  Total Reward:  40841193.71000002
# price for reward: 9132.46
# Step:  77967  Loss:  209246144.0  Total Reward:  40840964.66000002
# price for reward: 9131.46
# Step:  77968  Loss:  176911520.0  Total Reward:  40836383.66000002
# price for reward: 9131.58
# Step:  77969  Loss:  273761248.0  Total Reward:  40836933.38000002
# price for reward: 9131.67
# Step:  77970  Loss:  719627712.0  Total Reward:  40837345.670000024
# price for reward: 9136.84
# Step:  77971  Loss:  336019392.0  Total Reward:  40861029.44000002
# price for reward: 9134.77
# Step:  77972  Loss:  238548256.0  Total Reward:  40851546.770000026
# price for reward: 9134.82
# Step:  77973  Loss:  582262784.0  Total Reward:  40851775.82000002
# price for reward: 9134.83
# Step:  77974  Loss:  164223216.0  Total Reward:  40851821.63000002
# price for reward: 9136.81
# Step:  77975  Loss:  287587968.0  Total Reward:  40860892.01000002
# price for reward: 9139.12
# Step:  77976  Loss:  226317376.0  Total Reward:  40871474.12000003
# price for reward: 9138.61
# Step:  77977  Loss:  342848672.0  Total Reward:  40869137.810000025
# price for reward: 9138.64
# Step:  77978  Loss:  2345413376.0  Total Reward:  40869137.810000025
# price for reward: 9138.67
# Step:  77979  Loss:  278867328.0  Total Reward:  40869137.810000025
# price for reward: 9138.71
# Step:  77980  Loss:  229096240.0  Total Reward:  40869137.810000025
# price for reward: 9138.71
# Step:  77981  Loss:  55866096.0  Total Reward:  40869137.810000025
# price for reward: 9138.74
# Step:  77982  Loss:  582947840.0  Total Reward:  40869137.810000025
# price for reward: 9138.75
# Step:  77983  Loss:  214903040.0  Total Reward:  40869137.810000025
# price for reward: 9142.75
# Step:  77984  Loss:  164066592.0  Total Reward:  40869137.810000025
# price for reward: 9138.75
# Step:  77985  Loss:  174701808.0  Total Reward:  40869137.810000025
# price for reward: 9138.8
# Step:  77986  Loss:  763430144.0  Total Reward:  40869137.810000025
# price for reward: 9138.8
# Step:  77987  Loss:  247639664.0  Total Reward:  40869137.810000025
# price for reward: 9138.8
# Step:  77988  Loss:  304601184.0  Total Reward:  40869137.810000025
# price for reward: 9136.73
# Step:  77989  Loss:  341070272.0  Total Reward:  40869137.810000025
# price for reward: 9136.74
# Step:  77990  Loss:  325277952.0  Total Reward:  40869137.810000025
# price for reward: 9128.82
# Step:  77991  Loss:  178902976.0  Total Reward:  40869137.810000025
# price for reward: 9128.82
# Step:  77992  Loss:  243795616.0  Total Reward:  40869137.810000025
# price for reward: 9128.83
# Step:  77993  Loss:  607217152.0  Total Reward:  40869183.67000003
# price for reward: 9128.85
# Step:  77994  Loss:  313153216.0  Total Reward:  40869275.39000003
# price for reward: 9128.85
# Step:  77995  Loss:  803900352.0  Total Reward:  40869275.39000003
# price for reward: 9129.0
# Step:  77996  Loss:  405955136.0  Total Reward:  40869963.29000003
# price for reward: 9129.0
# Step:  77997  Loss:  419648160.0  Total Reward:  40869963.29000003
# price for reward: 9124.17
# Step:  77998  Loss:  386700320.0  Total Reward:  40847812.910000026
# price for reward: 9124.17
# Step:  77999  Loss:  250374848.0  Total Reward:  40847812.910000026
# price for reward: 9125.92
# Step:  78000  Loss:  710377472.0  Total Reward:  40855838.410000026
# price for reward: 9125.96
# Step:  78001  Loss:  182116272.0  Total Reward:  40856021.850000024
# price for reward: 9132.09
# Step:  78002  Loss:  509752128.0  Total Reward:  40884134.03000003
# price for reward: 9133.91
# Step:  78003  Loss:  220240768.0  Total Reward:  40892480.55000003
# price for reward: 9133.91
# Step:  78004  Loss:  305316224.0  Total Reward:  40892480.55000003
# price for reward: 9134.01
# Step:  78005  Loss:  194359616.0  Total Reward:  40892939.15000003
# price for reward: 9139.86
# Step:  78006  Loss:  474590528.0  Total Reward:  40919767.25000003
# price for reward: 9134.92
# Step:  78007  Loss:  275543840.0  Total Reward:  40897112.410000026
# price for reward: 9134.9
# Step:  78008  Loss:  243603456.0  Total Reward:  40897020.69000003
# price for reward: 9136.72
# Step:  78009  Loss:  745386112.0  Total Reward:  40905367.21000002
# price for reward: 9137.63
# Step:  78010  Loss:  99381168.0  Total Reward:  40909540.47000003
# price for reward: 9137.65
# Step:  78011  Loss:  150116912.0  Total Reward:  40909632.19000003
# price for reward: 9138.7
# Step:  78012  Loss:  315986848.0  Total Reward:  40914447.49000003
# price for reward: 9138.7
# Step:  78013  Loss:  264756752.0  Total Reward:  40914447.49000003
# price for reward: 9142.0
# ...
# price for reward: 8743.76
# Step:  79828  Loss:  292777216.0  Total Reward:  41353407.24000002
# price for reward: 8743.76
# Step:  79829  Loss:  908948096.0  Total Reward:  41353407.24000002
# price for reward: 8749.77
# Step:  79830  Loss:  365144160.0  Total Reward:  41382513.67000002
# price for reward: 8749.77
# Step:  79831  Loss:  157533728.0  Total Reward:  41382513.67000002
# price for reward: 8750.0
# Step:  79832  Loss:  175274320.0  Total Reward:  41383627.56000002
# price for reward: 8750.0
# Step:  79833  Loss:  518151360.0  Total Reward:  41383627.56000002
# price for reward: 8750.0
# Step:  79834  Loss:  348345376.0  Total Reward:  41383627.56000002
# price for reward: 8750.0
# Step:  79835  Loss:  243460736.0  Total Reward:  41383627.56000002
# price for reward: 8753.62
# Step:  79836  Loss:  664927232.0  Total Reward:  41401159.22000002
# price for reward: 8753.62
# Step:  79837  Loss:  232523312.0  Total Reward:  41401159.22000002
# price for reward: 8753.62
# Step:  79838  Loss:  407715040.0  Total Reward:  41401159.22000002
# price for reward: 8751.42
# Step:  79839  Loss:  142480704.0  Total Reward:  41390504.62000002
# price for reward: 8751.43
# Step:  79840  Loss:  1050156992.0  Total Reward:  41390553.05000002
# price for reward: 8751.42
# Step:  79841  Loss:  475191456.0  Total Reward:  41390504.62000002
# price for reward: 8752.56
# Step:  79842  Loss:  701031744.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79843  Loss:  1066064128.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79844  Loss:  63217288.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79845  Loss:  543195328.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79846  Loss:  208906736.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79847  Loss:  435619424.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79848  Loss:  220089408.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79849  Loss:  135615536.0  Total Reward:  41396025.640000015
# price for reward: 8752.56
# Step:  79850  Loss:  164422624.0  Total Reward:  41396025.640000015
# price for reward: 8746.93
# Step:  79851  Loss:  209099744.0  Total Reward:  41368759.55000002
# price for reward: 8752.51
# Step:  79852  Loss:  185831504.0  Total Reward:  41395783.49000002
# price for reward: 8754.96
# Step:  79853  Loss:  140439792.0  Total Reward:  41407648.84000001
# price for reward: 8754.96
# Step:  79854  Loss:  504400256.0  Total Reward:  41407648.84000001
# price for reward: 8754.96
# Step:  79855  Loss:  411624576.0  Total Reward:  41407648.84000001
# price for reward: 8754.96
# Step:  79856  Loss:  357794784.0  Total Reward:  41407648.84000001
# price for reward: 8754.95
# Step:  79857  Loss:  142858400.0  Total Reward:  41407600.41000002
# price for reward: 8754.95
# Step:  79858  Loss:  159135632.0  Total Reward:  41407600.41000002
# price for reward: 8751.42
# Step:  79859  Loss:  160103040.0  Total Reward:  41390504.62000002
# price for reward: 8752.76
# Step:  79860  Loss:  219621232.0  Total Reward:  41396994.24000002
# price for reward: 8752.76
# Step:  79861  Loss:  281883456.0  Total Reward:  41396994.24000002
# price for reward: 8752.76
# Step:  79862  Loss:  194356448.0  Total Reward:  41396994.24000002
# price for reward: 8755.58
# Step:  79863  Loss:  466311552.0  Total Reward:  41410651.500000015
# price for reward: 8755.58
# Step:  79864  Loss:  284040960.0  Total Reward:  41410651.500000015
# price for reward: 8755.67
# Step:  79865  Loss:  485039328.0  Total Reward:  41411087.37000002
# price for reward: 8758.62
# Step:  79866  Loss:  635400192.0  Total Reward:  41425374.22000002
# price for reward: 8751.96
# Step:  79867  Loss:  107664232.0  Total Reward:  41393119.84000001
# price for reward: 8751.48
# Step:  79868  Loss:  166532880.0  Total Reward:  41390795.20000002
# price for reward: 8751.42
# Step:  79869  Loss:  239530192.0  Total Reward:  41390504.62000002
# price for reward: 8751.43
# Step:  79870  Loss:  924304064.0  Total Reward:  41390553.05000002
# price for reward: 8741.43
# Step:  79871  Loss:  292377536.0  Total Reward:  41342123.05000002
# price for reward: 8746.59
# Step:  79872  Loss:  193144672.0  Total Reward:  41367112.930000015
# price for reward: 8746.59
# Step:  79873  Loss:  435283904.0  Total Reward:  41367112.930000015
# price for reward: 8742.26
# Step:  79874  Loss:  111707568.0  Total Reward:  41346142.74000002
# price for reward: 8741.42
# Step:  79875  Loss:  596879808.0  Total Reward:  41342074.62000002
# price for reward: 8741.87
# Step:  79876  Loss:  336928320.0  Total Reward:  41344253.97000002
# price for reward: 8738.41
# Step:  79877  Loss:  188619344.0  Total Reward:  41327497.19000002
# price for reward: 8738.41
# Step:  79878  Loss:  530130048.0  Total Reward:  41327497.19000002
# price for reward: 8740.32
# Step:  79879  Loss:  357679232.0  Total Reward:  41336747.320000015
# price for reward: 8745.62
# Step:  79880  Loss:  152656800.0  Total Reward:  41362415.22000002
# price for reward: 8735.0
# Step:  79881  Loss:  166261840.0  Total Reward:  41310982.56000002
# price for reward: 8735.01
# Step:  79882  Loss:  579646784.0  Total Reward:  41311030.99000002
# price for reward: 8735.01
# Step:  79883  Loss:  322320512.0  Total Reward:  41311030.99000002
# price for reward: 8735.0
# Step:  79884  Loss:  251419152.0  Total Reward:  41310982.56000002
# price for reward: 8735.0
# Step:  79885  Loss:  242939776.0  Total Reward:  41310982.56000002
# price for reward: 8735.0
# Step:  79886  Loss:  358276000.0  Total Reward:  41310982.56000002
# price for reward: 8735.0
# Step:  79887  Loss:  271895424.0  Total Reward:  41310982.56000002
# price for reward: 8735.02
# Step:  79888  Loss:  858056512.0  Total Reward:  41311079.42000002
# price for reward: 8735.43
# Step:  79889  Loss:  772621568.0  Total Reward:  41313065.05000002
# price for reward: 8735.43
# Step:  79890  Loss:  405248896.0  Total Reward:  41313065.05000002
# price for reward: 8735.43
# Step:  79891  Loss:  198887776.0  Total Reward:  41313065.05000002
# price for reward: 8740.61
# Step:  79892  Loss:  528968576.0  Total Reward:  41338151.79000002
# price for reward: 8738.82
# Step:  79893  Loss:  168970352.0  Total Reward:  41329482.820000015
# price for reward: 8740.46
# Step:  79894  Loss:  425614432.0  Total Reward:  41337425.34000001
# price for reward: 8735.02
# Step:  79895  Loss:  493290720.0  Total Reward:  41311079.42000002
# price for reward: 8738.16
# Step:  79896  Loss:  749438272.0  Total Reward:  41326286.44000002
# price for reward: 8743.99
# Step:  79897  Loss:  143939712.0  Total Reward:  41354521.13000002
# price for reward: 8744.0
# Step:  79898  Loss:  395562368.0  Total Reward:  41354569.56000002
# price for reward: 8744.0
# Step:  79899  Loss:  158763920.0  Total Reward:  41354569.56000002
# price for reward: 8744.0
# Step:  79900  Loss:  233660528.0  Total Reward:  41354569.56000002
# price for reward: 8747.02
# Step:  79901  Loss:  65118904.0  Total Reward:  41354569.56000002
# price for reward: 8747.02
# Step:  79902  Loss:  202479472.0  Total Reward:  41354569.56000002
# price for reward: 8751.42
# Step:  79903  Loss:  181550880.0  Total Reward:  41354569.56000002
# price for reward: 8751.43
# Step:  79904  Loss:  725670912.0  Total Reward:  41354569.56000002
# price for reward: 8751.43
# Step:  79905  Loss:  156310560.0  Total Reward:  41354569.56000002
# price for reward: 8752.11
# Step:  79906  Loss:  595955200.0  Total Reward:  41354569.56000002
# price for reward: 8752.12
# Step:  79907  Loss:  461148736.0  Total Reward:  41354569.56000002
# price for reward: 8752.12
# Step:  79908  Loss:  239549792.0  Total Reward:  41354569.56000002
# price for reward: 8752.12
# Step:  79909  Loss:  183481728.0  Total Reward:  41354569.56000002
# price for reward: 8752.77
# Step:  79910  Loss:  343298848.0  Total Reward:  41354569.56000002
# price for reward: 8745.76
# Step:  79911  Loss:  721156672.0  Total Reward:  41354569.56000002
# price for reward: 8745.78
# Step:  79912  Loss:  244418304.0  Total Reward:  41354569.56000002
# price for reward: 8745.76
# Step:  79913  Loss:  163958688.0  Total Reward:  41354472.72000001
# price for reward: 8745.76
# Step:  79914  Loss:  386012000.0  Total Reward:  41354472.72000001
# price for reward: 8750.56
# Step:  79915  Loss:  315177504.0  Total Reward:  41377714.32000001
# price for reward: 8750.65
# Step:  79916  Loss:  251744720.0  Total Reward:  41378150.10000001
# price for reward: 8752.75
# Step:  79917  Loss:  154124000.0  Total Reward:  41388318.30000001
# price for reward: 8752.75
# Step:  79918  Loss:  305064320.0  Total Reward:  41388318.30000001
# price for reward: 8745.02
# Step:  79919  Loss:  414483392.0  Total Reward:  41350889.640000015
# price for reward: 8745.02
# Step:  79920  Loss:  225995568.0  Total Reward:  41350889.640000015
# price for reward: 8745.02
# Step:  79921  Loss:  271574944.0  Total Reward:  41350889.640000015
# price for reward: 8741.42
# Step:  79922  Loss:  85326312.0  Total Reward:  41333458.44000001
# price for reward: 8741.42
# Step:  79923  Loss:  461794656.0  Total Reward:  41333458.44000001
# price for reward: 8741.42
# Step:  79924  Loss:  235104416.0  Total Reward:  41333458.44000001
# price for reward: 8741.43
# Step:  79925  Loss:  371473824.0  Total Reward:  41333506.860000014
# price for reward: 8738.17
# Step:  79926  Loss:  288422272.0  Total Reward:  41317721.94000001
# price for reward: 8736.39
# Step:  79927  Loss:  239611248.0  Total Reward:  41309103.18000001
# price for reward: 8736.39
# Step:  79928  Loss:  450835072.0  Total Reward:  41309103.18000001
# price for reward: 8736.86
# Step:  79929  Loss:  544590976.0  Total Reward:  41311378.92000002
# price for reward: 8735.03
# Step:  79930  Loss:  239359728.0  Total Reward:  41302518.06000002
# price for reward: 8735.03
# Step:  79931  Loss:  1075898624.0  Total Reward:  41302518.06000002
# price for reward: 8740.45
# Step:  79932  Loss:  533904864.0  Total Reward:  41328761.70000002
# price for reward: 8731.42
# Step:  79933  Loss:  351670368.0  Total Reward:  41285038.44000001
# price for reward: 8732.49
# Step:  79934  Loss:  333098976.0  Total Reward:  41290219.38000001
# price for reward: 8726.81
# Step:  79935  Loss:  479670976.0  Total Reward:  41262716.82000001
# price for reward: 8725.94
# Step:  79936  Loss:  530975712.0  Total Reward:  41258504.280000016
# price for reward: 8728.15
# Step:  79937  Loss:  123623376.0  Total Reward:  41269205.10000001
# price for reward: 8728.15
# Step:  79938  Loss:  659591296.0  Total Reward:  41269205.10000001
# price for reward: 8721.47
# Step:  79939  Loss:  325711328.0  Total Reward:  41236860.54000001
# price for reward: 8728.15
# Step:  79940  Loss:  183300592.0  Total Reward:  41269205.10000001
# price for reward: 8726.56
# Step:  79941  Loss:  374021344.0  Total Reward:  41261506.32000001
# price for reward: 8728.14
# Step:  79942  Loss:  184147696.0  Total Reward:  41269156.68000001
# price for reward: 8727.79
# Step:  79943  Loss:  162446032.0  Total Reward:  41267461.98000002
# price for reward: 8729.48
# Step:  79944  Loss:  143987968.0  Total Reward:  41275644.96000001
# price for reward: 8730.0
# Step:  79945  Loss:  421305568.0  Total Reward:  41278162.80000001
# price for reward: 8730.0
# Step:  79946  Loss:  154767808.0  Total Reward:  41278162.80000001
# price for reward: 8730.0
# Step:  79947  Loss:  428770432.0  Total Reward:  41278162.80000001
# price for reward: 8738.59
# Step:  79948  Loss:  127946624.0  Total Reward:  41319755.58000001
# price for reward: 8740.38
# Step:  79949  Loss:  674225664.0  Total Reward:  41328422.760000005
# price for reward: 8738.12
# Step:  79950  Loss:  392569312.0  Total Reward:  41317479.84000002
# price for reward: 8738.12
# Step:  79951  Loss:  375592640.0  Total Reward:  41317479.84000002
# price for reward: 8738.12
# Step:  79952  Loss:  417012480.0  Total Reward:  41317479.84000002
# price for reward: 8738.12
# Step:  79953  Loss:  288141408.0  Total Reward:  41317479.84000002
# price for reward: 8739.6
# Step:  79954  Loss:  231394320.0  Total Reward:  41317479.84000002
# price for reward: 8741.5
# Step:  79955  Loss:  78253336.0  Total Reward:  41317479.84000002
# price for reward: 8741.5
# Step:  79956  Loss:  277940096.0  Total Reward:  41317479.84000002
# price for reward: 8741.56
# Step:  79957  Loss:  199697616.0  Total Reward:  41317479.84000002
# price for reward: 8734.9
# Step:  79958  Loss:  520816736.0  Total Reward:  41317479.84000002
# price for reward: 8738.21
# Step:  79959  Loss:  134789824.0  Total Reward:  41317479.84000002
# price for reward: 8731.55
# Step:  79960  Loss:  396160768.0  Total Reward:  41317479.84000002
# price for reward: 8725.0
# Step:  79961  Loss:  401594944.0  Total Reward:  41317479.84000002
# price for reward: 8721.42
# Step:  79962  Loss:  274566656.0  Total Reward:  41317479.84000002
# price for reward: 8721.42
# Step:  79963  Loss:  190083376.0  Total Reward:  41317479.84000002
# price for reward: 8721.42
# Step:  79964  Loss:  372728192.0  Total Reward:  41317479.84000002
# price for reward: 8715.64
# Step:  79965  Loss:  369693920.0  Total Reward:  41317479.84000002
# price for reward: 8715.64
# Step:  79966  Loss:  260443632.0  Total Reward:  41317479.84000002
# price for reward: 8718.24
# Step:  79967  Loss:  199360416.0  Total Reward:  41317479.84000002
# price for reward: 8724.11
# Step:  79968  Loss:  346695392.0  Total Reward:  41317479.84000002
# price for reward: 8724.11
# Step:  79969  Loss:  392506272.0  Total Reward:  41317479.84000002
# price for reward: 8724.11
# Step:  79970  Loss:  730512128.0  Total Reward:  41317479.84000002
# price for reward: 8734.9
# Step:  79971  Loss:  399138848.0  Total Reward:  41317479.84000002
# price for reward: 8734.9
# Step:  79972  Loss:  326109120.0  Total Reward:  41317479.84000002
# price for reward: 8731.42
# Step:  79973  Loss:  245007440.0  Total Reward:  41317479.84000002
# price for reward: 8731.42
# Step:  79974  Loss:  184096016.0  Total Reward:  41317479.84000002
# price for reward: 8731.42
# Step:  79975  Loss:  909583104.0  Total Reward:  41317479.84000002
# price for reward: 8734.17
# Step:  79976  Loss:  154058784.0  Total Reward:  41317479.84000002
# price for reward: 8731.7
# Step:  79977  Loss:  686669760.0  Total Reward:  41317479.84000002
# price for reward: 8731.76
# Step:  79978  Loss:  141383008.0  Total Reward:  41317479.84000002
# price for reward: 8735.78
# Step:  79979  Loss:  256569952.0  Total Reward:  41317479.84000002
# price for reward: 8737.36
# Step:  79980  Loss:  226697792.0  Total Reward:  41317479.84000002
# price for reward: 8735.7
# Step:  79981  Loss:  1160453248.0  Total Reward:  41317479.84000002
# price for reward: 8737.42
# Step:  79982  Loss:  317942944.0  Total Reward:  41317479.84000002
# price for reward: 8737.42
# Step:  79983  Loss:  368886240.0  Total Reward:  41317479.84000002
# price for reward: 8737.42
# Step:  79984  Loss:  257661744.0  Total Reward:  41317479.84000002
# price for reward: 8737.42
# Step:  79985  Loss:  660419968.0  Total Reward:  41317479.84000002
# price for reward: 8732.13
# Step:  79986  Loss:  213527552.0  Total Reward:  41317479.84000002
# price for reward: 8732.13
# Step:  79987  Loss:  200406896.0  Total Reward:  41317479.84000002
# price for reward: 8732.13
# Step:  79988  Loss:  218029440.0  Total Reward:  41317479.84000002
# price for reward: 8735.14
# Step:  79989  Loss:  494731136.0  Total Reward:  41332066.30000002
# price for reward: 8740.0
# Step:  79990  Loss:  188061328.0  Total Reward:  41355617.86000002
# price for reward: 8740.0
# Step:  79991  Loss:  623546752.0  Total Reward:  41355617.86000002
# price for reward: 8754.21
# Step:  79992  Loss:  600530752.0  Total Reward:  41424479.52000002
# price for reward: 8753.36
# Step:  79993  Loss:  351634816.0  Total Reward:  41420360.420000024
# price for reward: 8753.36
# Step:  79994  Loss:  383808544.0  Total Reward:  41420360.420000024
# price for reward: 8753.36
# Step:  79995  Loss:  888611264.0  Total Reward:  41420360.420000024
# price for reward: 8759.98
# Step:  79996  Loss:  388913216.0  Total Reward:  41452440.94000002
# price for reward: 8759.98
# Step:  79997  Loss:  198313776.0  Total Reward:  41452440.94000002
# price for reward: 8759.97
# Step:  79998  Loss:  177712032.0  Total Reward:  41452440.94000002
# price for reward: 8759.98
# Step:  79999  Loss:  432758656.0  Total Reward:  41452440.94000002

# %%
class testEnv():
    # initialize all the attributes, define action_space and observation_space
    def __init__(self, df, lookback_window, initial_cash): 
        self.df = df # our dataframe, this should be only the columns we need (OHLC+16 technical indicators)
        self.lookback_window = lookback_window # this is the number of timesteps we look back to, 10 in our case
        self.initial_cash = initial_cash
        self.bitcoin_held = 0
        self.current_cash = 0
        self.current_asset = 0
        self.episode = 1
        self.current_step = len(self.df) - 1
        self.start_step = self.current_step
        self.current_reward = 0

        # short: 0, keep: 1, long: 2
        self.action_space = [0, 1, 2]

        # 10x21 ndarray, columns: OHLC, Volume, Close_MA, Close_EA, Close_SO, Close_Stdv,..., Account (current_cash, bitcoin_held, current_asset)
       # self.observation_space = np.empty([10,21])
        self.observation_space = np.empty([10,10])

        # graph to render
        self.graph_reward = []

      # reset all the attributes, set the current step to some random position
    def reset(self):
        self.bitcoin_held = 0
        self.current_cash = self.initial_cash
        self.current_asset = self.initial_cash
        # reset should be called after each episode to clear reward
        self.episode_reward = 0
        self.current_reward = 0

        # set the current step to a random point within the data frame
        self.current_step = len(self.df) - 10
        self.start_step = self.current_step
        observation = self._current_observation()
        return observation

    # return the current state which consists of the past 10 timesteps of historical prices and technical indicators
    def _current_observation(self):  
        historial_prices = np.array([
            self.df.loc[self.current_step : self.current_step + 9, 'Open'],
            self.df.loc[self.current_step : self.current_step + 9, 'High'],
            self.df.loc[self.current_step : self.current_step + 9, 'Low'],
            self.df.loc[self.current_step : self.current_step + 9, 'Close'],
            self.df.loc[self.current_step : self.current_step + 9, 'Volume'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_ma'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_ea'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_so'],
            self.df.loc[self.current_step : self.current_step + 9, 'close_stdv']
            #self.df.loc[self.current_step : self.current_step + 9, 'close_macd'],
            #self.df.loc[self.current_step : self.current_step + 9, 'RSI'],
            #self.df.loc[self.current_step : self.current_step + 9, 'Retracement'],
            #self.df.loc[self.current_step : self.current_step + 9, 'tenkan_sen'],
            #self.df.loc[self.current_step : self.current_step + 9, 'kijun_sen'],
            #self.df.loc[self.current_step : self.current_step + 9, 'senkou_span_a'],
            #self.df.loc[self.current_step : self.current_step + 9, 'senkou_span_b'],
            #self.df.loc[self.current_step : self.current_step + 9, 'chikou_span'],
            #self.df.loc[self.current_step : self.current_step + 9, 'pos_directional_indicator'],
            #self.df.loc[self.current_step : self.current_step + 9, 'neg_directional_indicator'],
            #self.df.loc[self.current_step : self.current_step + 9, 'adx']
        ])

        # our current situation is the last column. Fill empty cells with 0
        observation = np.append(historial_prices, [[self.current_asset, self.current_cash, self.bitcoin_held, 0, 0, 0, 0, 0, 0, 0]], axis=0)
        return observation


    # helper function to calculate reward. reward=current_asset-initial_cash
    def _calculate_reward(self, action):
        # set the current price to a random price between current timestep's open and close
        # current_price = random.uniform(self.df.loc[self.current_step, 'Open'], self.df.loc[self.current_step, 'Close'])
        current_price = self.df.loc[self.current_step, 'Open']

        #long
        if action == 2:
            num_buy = math.floor(self.current_cash/current_price)
            self.current_cash -= num_buy * current_price
            self.bitcoin_held += num_buy

        #short
        if action == 0:
            num_sell = self.bitcoin_held
            self.current_cash += num_sell * current_price
            self.bitcoin_held = 0

        self.current_asset = self.current_cash + self.bitcoin_held * current_price
        self.current_reward = (self.current_cash + self.bitcoin_held * self.df.loc[self.current_step - 1, 'Open']) - self.current_asset
        print("price for reward:", self.df.loc[self.current_step - 1, 'Open'])

    # return the next state and reward after performing the specified action
    def step(self, action, done):
        # done should always be passed as False unless testing
        if (self.current_step < 1):
            # Cannot calculate reward, because no next timestep is available
            self.current_reward = 0
            done = True     
        else:    
            self._calculate_reward(action)
            self.episode_reward = self.episode_reward + self.current_reward
            self.current_step -= 1
            done = False #only for testing purpose


        if done:
            #self.episode_reward = self.current_reward
            self.graph_reward.append(self.episode_reward) #save this episode's reward
            self.episode += 1 # episode is over at this step

        state = self._current_observation()
        return state, self.current_reward, done

    def render(self, mode, close=False):
        # print out current state, should be called after step()
        if mode == "print after step":
            print("step: ", self.current_step)
            print("current_cash: ", self.current_cash)
            print("bitcoin_held: ", self.bitcoin_held)
            print("current_asset: ", self.current_asset)
            print("reward: ", self.current_reward)

        if mode == "plot episode rewards":
            # plot reward graph
            plt.plot(self.graph_reward)
            plt.xlabel("Episode")
            plt.ylabel("Reward")
            plt.show()

# %%
def run_episode_test():
  episode_reward_list = []
  global epsilon
  state = env_test.reset()
  episode_reward = 0
  action_list = []
  i = 0

  while True:
    """ Pseudocode:
        1. Input state into your network to get the predicted Q Values for each action
        2. Use "epsilon_greedy_action" to get your next action from your Q-Values
    """

    action_values = q_net(torch.Tensor([state]))
    
    action = epsilon_greedy_action(action_values, epsilon)
    action_list.append(action)
    # Decay the epsilon
    epsilon = max(epsilon * EPSILON_DECAY, EPSILON_END)
    
    # print(type(action.item()))
    # 3. Once you've done the first two steps, you can simulate tacking the action
    # "action" in the environment as follows. 

    # Return Values: 
    # next_state: (Tuple) Next state after having taken action "action"
    # reward    : (int)   Reward received for taking action "action"
    # done      : (bool)  Whether or not the simulation has reached an ending condition (see github repo linked earlier for more information)
    next_state, reward, done = env_test.step(action.item(), False)
    
    episode_reward += reward
    episode_reward_list.append(episode_reward)
    state = next_state
    print('Step: ', i ,' Total Reward: ', episode_reward)
    i += 1
    if done:
      return (action_list, episode_reward_list)
    """ Pseudocode (cont):
        4. Push this information to your ReplayBuffer
        5. Set your current state to the next state returned
        6. Call "learn" for a single batch
        7. Check if the simulation is done, and if so exit out of the function
           If the simulation is not done, then we loop and repeat steps 1-7
    """

# %%
env_test = testEnv(df_test, 10, 1000000)
observation = env_test.reset()
print(observation.shape)
print(env_test.action_space)
action_list, reward_list = run_episode_test()
print(reward_list)
print(action_list)
plt.plot(reward_list)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# price for reward: 6131.45
# Step:  17492  Total Reward:  2427804.8400000064
# price for reward: 6133.37
# Step:  17493  Total Reward:  2428878.1200000066
# price for reward: 6140.0
# Step:  17494  Total Reward:  2432584.2900000066
# price for reward: 6144.83
# Step:  17495  Total Reward:  2435284.2600000063
# price for reward: 6144.42
# Step:  17496  Total Reward:  2435055.070000007
# price for reward: 6140.61
# Step:  17497  Total Reward:  2432925.2800000063
# price for reward: 6137.6
# Step:  17498  Total Reward:  2431242.690000007
# price for reward: 6136.46
# Step:  17499  Total Reward:  2430605.4300000067
# price for reward: 6136.46
# Step:  17500  Total Reward:  2430605.4300000067
# price for reward: 6138.41
# Step:  17501  Total Reward:  2431695.4800000065
# price for reward: 6138.41
# Step:  17502  Total Reward:  2431695.4800000065
# price for reward: 6144.43
# Step:  17503  Total Reward:  2435060.6600000067
# price for reward: 6144.21
# Step:  17504  Total Reward:  2434937.6800000067
# price for reward: 6152.28
# Step:  17505  Total Reward:  2439448.8100000066
# price for reward: 6148.22
# Step:  17506  Total Reward:  2437179.2700000065
# price for reward: 6149.46
# Step:  17507  Total Reward:  2437872.4300000067
# price for reward: 6149.46
# Step:  17508  Total Reward:  2437872.4300000067
# price for reward: 6163.56
# Step:  17509  Total Reward:  2445754.3300000066
# price for reward: 6162.99
# Step:  17510  Total Reward:  2445435.7000000062
# price for reward: 6160.79
# Step:  17511  Total Reward:  2444205.9000000064
# price for reward: 6155.64
# Step:  17512  Total Reward:  2441327.050000007
# price for reward: 6155.64
# Step:  17513  Total Reward:  2441327.050000007
# price for reward: 6164.98
# Step:  17514  Total Reward:  2446548.1100000064
# price for reward: 6173.0
# Step:  17515  Total Reward:  2451031.2900000066
# price for reward: 6178.3
# Step:  17516  Total Reward:  2453993.9900000067
# price for reward: 6178.3
# Step:  17517  Total Reward:  2453993.9900000067
# price for reward: 6178.0
# Step:  17518  Total Reward:  2453826.2900000066
# price for reward: 6174.55
# Step:  17519  Total Reward:  2451897.7400000067
# price for reward: 6178.44
# Step:  17520  Total Reward:  2454072.2500000065
# price for reward: 6180.0
# Step:  17521  Total Reward:  2454944.2900000066
# price for reward: 6170.0
# Step:  17522  Total Reward:  2449354.2900000066
# price for reward: 6175.34
# Step:  17523  Total Reward:  2452339.3500000066
# price for reward: 6173.06
# Step:  17524  Total Reward:  2451064.8300000066
# price for reward: 6168.31
# Step:  17525  Total Reward:  2448409.5800000066
# price for reward: 6168.31
# Step:  17526  Total Reward:  2448409.5800000066
# price for reward: 6168.31
# Step:  17527  Total Reward:  2448409.5800000066
# price for reward: 6168.31
# Step:  17528  Total Reward:  2448409.5800000066
# price for reward: 6172.9
# Step:  17529  Total Reward:  2450975.390000006
# price for reward: 6185.71
# Step:  17530  Total Reward:  2458136.1800000067
# price for reward: 6185.5
# Step:  17531  Total Reward:  2458018.7900000066
# price for reward: 6187.39
# Step:  17532  Total Reward:  2459075.300000007
# price for reward: 6186.5
# Step:  17533  Total Reward:  2458577.7900000066
# price for reward: 6183.3
# Step:  17534  Total Reward:  2456788.9900000067
# price for reward: 6181.19
# Step:  17535  Total Reward:  2455609.5000000065
# price for reward: 6181.48
# Step:  17536  Total Reward:  2455771.6100000064
# price for reward: 6180.36
# Step:  17537  Total Reward:  2455145.5300000063
# price for reward: 6185.57
# Step:  17538  Total Reward:  2458057.9200000064
# price for reward: 6189.28
# Step:  17539  Total Reward:  2460131.8100000066
# price for reward: 6193.14
# Step:  17540  Total Reward:  2462289.550000007
# price for reward: 6189.2
# Step:  17541  Total Reward:  2460087.0900000064
# price for reward: 6189.2
# Step:  17542  Total Reward:  2460087.0900000064
# price for reward: 6189.2
# Step:  17543  Total Reward:  2460087.0900000064
# price for reward: 6185.83
# Step:  17544  Total Reward:  2458203.2600000063
# price for reward: 6185.83
# Step:  17545  Total Reward:  2458203.2600000063
# price for reward: 6184.2
# Step:  17546  Total Reward:  2457292.0900000064
# price for reward: 6182.0
# Step:  17547  Total Reward:  2456062.2900000066
# price for reward: 6182.0
# Step:  17548  Total Reward:  2456062.2900000066
# price for reward: 6181.02
# Step:  17549  Total Reward:  2455514.4700000067
# price for reward: 6181.02
# Step:  17550  Total Reward:  2455514.4700000067
# price for reward: 6181.02
# Step:  17551  Total Reward:  2455514.4700000067
# price for reward: 6183.53
# Step:  17552  Total Reward:  2456917.5600000066
# price for reward: 6188.7
# Step:  17553  Total Reward:  2459807.5900000064
# price for reward: 6187.53
# Step:  17554  Total Reward:  2459153.5600000066
# price for reward: 6201.0
# Step:  17555  Total Reward:  2466683.2900000066
# price for reward: 6195.83
# Step:  17556  Total Reward:  2463793.2600000063
# price for reward: 6197.75
# Step:  17557  Total Reward:  2463793.2600000063
# price for reward: 6196.0
# Step:  17558  Total Reward:  2463793.2600000063
# price for reward: 6194.47
# Step:  17559  Total Reward:  2463793.2600000063
# price for reward: 6194.47
# Step:  17560  Total Reward:  2463793.2600000063
# price for reward: 6194.47
# Step:  17561  Total Reward:  2463793.2600000063
# price for reward: 6194.47
# Step:  17562  Total Reward:  2463793.2600000063
# price for reward: 6186.99
# Step:  17563  Total Reward:  2459611.940000006
# price for reward: 6186.99
# Step:  17564  Total Reward:  2459611.940000006
# price for reward: 6191.78
# Step:  17565  Total Reward:  2462289.5500000063
# price for reward: 6189.11
# Step:  17566  Total Reward:  2460797.020000006
# price for reward: 6188.49
# Step:  17567  Total Reward:  2460450.440000006
# price for reward: 6190.09
# Step:  17568  Total Reward:  2461344.8400000064
# price for reward: 6190.09
# Step:  17569  Total Reward:  2461344.8400000064
# price for reward: 6187.5
# Step:  17570  Total Reward:  2459897.0300000063
# price for reward: 6194.04
# Step:  17571  Total Reward:  2463552.890000006
# price for reward: 6194.04
# Step:  17572  Total Reward:  2463552.890000006
# price for reward: 6194.04
# Step:  17573  Total Reward:  2463552.890000006
# price for reward: 6193.5
# Step:  17574  Total Reward:  2463251.0300000063
# price for reward: 6197.6
# Step:  17575  Total Reward:  2465542.9300000067
# price for reward: 6200.35
# Step:  17576  Total Reward:  2467080.1800000067
# price for reward: 6200.35
# Step:  17577  Total Reward:  2467080.1800000067
# price for reward: 6200.35
# Step:  17578  Total Reward:  2467080.1800000067
# price for reward: 6200.35
# Step:  17579  Total Reward:  2467080.1800000067
# price for reward: 6203.58
# Step:  17580  Total Reward:  2467080.1800000067
# price for reward: 6201.54
# Step:  17581  Total Reward:  2467080.1800000067
# price for reward: 6205.44
# Step:  17582  Total Reward:  2467080.1800000067
# price for reward: 6205.44
# Step:  17583  Total Reward:  2467080.1800000067
# price for reward: 6203.69
# Step:  17584  Total Reward:  2467080.1800000067
# price for reward: 6200.7
# Step:  17585  Total Reward:  2467080.1800000067
# price for reward: 6202.31
# Step:  17586  Total Reward:  2467980.170000007
# price for reward: 6200.4
# Step:  17587  Total Reward:  2466912.4800000065
# price for reward: 6202.16
# Step:  17588  Total Reward:  2467896.320000007
# price for reward: 6202.16
# Step:  17589  Total Reward:  2467896.320000007
# price for reward: 6199.96
# Step:  17590  Total Reward:  2466666.520000007
# price for reward: 6191.69
# Step:  17591  Total Reward:  2462043.590000007
# price for reward: 6185.96
# Step:  17592  Total Reward:  2458840.520000007
# price for reward: 6190.35
# Step:  17593  Total Reward:  2461294.5300000072
# price for reward: 6190.36
# Step:  17594  Total Reward:  2461300.1200000066
# price for reward: 6189.61
# Step:  17595  Total Reward:  2460880.8700000066
# price for reward: 6188.8
# Step:  17596  Total Reward:  2460428.080000007
# price for reward: 6188.99
# Step:  17597  Total Reward:  2460534.2900000066
# price for reward: 6188.99
# Step:  17598  Total Reward:  2460534.2900000066
# price for reward: 6188.99
# Step:  17599  Total Reward:  2460534.2900000066
# price for reward: 6195.71
# Step:  17600  Total Reward:  2464290.770000007
# price for reward: 6245.22
# Step:  17601  Total Reward:  2491966.860000007
# price for reward: 6257.58
# Step:  17602  Total Reward:  2498876.1000000066
# price for reward: 6247.19
# Step:  17603  Total Reward:  2493068.090000007
# price for reward: 6259.1
# Step:  17604  Total Reward:  2499725.7800000072
# price for reward: 6256.57
# Step:  17605  Total Reward:  2499725.7800000072
# price for reward: 6254.52
# Step:  17606  Total Reward:  2499725.7800000072
# price for reward: 6252.39
# Step:  17607  Total Reward:  2499725.7800000072
# price for reward: 6253.37
# Step:  17608  Total Reward:  2499725.7800000072
# price for reward: 6254.59
# Step:  17609  Total Reward:  2499725.7800000072
# price for reward: 6251.81
# Step:  17610  Total Reward:  2498171.760000007
# price for reward: 6256.29
# Step:  17611  Total Reward:  2500676.080000007
# price for reward: 6251.78
# Step:  17612  Total Reward:  2498154.990000007
# price for reward: 6251.96
# Step:  17613  Total Reward:  2498255.6100000073
# price for reward: 6258.8
# Step:  17614  Total Reward:  2502079.1700000074
# price for reward: 6258.8
# Step:  17615  Total Reward:  2502079.1700000074
# price for reward: 6243.68
# Step:  17616  Total Reward:  2493627.0900000073
# price for reward: 6255.61
# Step:  17617  Total Reward:  2500295.960000007
# price for reward: 6255.61
# Step:  17618  Total Reward:  2500295.960000007
# price for reward: 6255.61
# Step:  17619  Total Reward:  2500295.960000007
# price for reward: 6248.08
# Step:  17620  Total Reward:  2496086.690000007
# price for reward: 6247.83
# Step:  17621  Total Reward:  2495946.940000007
# price for reward: 6247.83
# Step:  17622  Total Reward:  2495946.940000007
# price for reward: 6244.79
# Step:  17623  Total Reward:  2494247.580000007
# price for reward: 6248.66
# Step:  17624  Total Reward:  2496410.910000007
# price for reward: 6250.39
# Step:  17625  Total Reward:  2497377.9800000074
# price for reward: 6265.1
# Step:  17626  Total Reward:  2505600.8700000076
# price for reward: 6259.99
# Step:  17627  Total Reward:  2502744.380000007
# price for reward: 6261.03
# Step:  17628  Total Reward:  2503325.740000007
# price for reward: 6262.77
# Step:  17629  Total Reward:  2504298.4000000074
# price for reward: 6267.7
# Step:  17630  Total Reward:  2507054.270000007
# price for reward: 6270.44
# Step:  17631  Total Reward:  2507054.270000007
# price for reward: 6265.38
# Step:  17632  Total Reward:  2507054.270000007
# price for reward: 6267.38
# Step:  17633  Total Reward:  2507054.270000007
# price for reward: 6267.3
# Step:  17634  Total Reward:  2507054.270000007
# price for reward: 6267.31
# Step:  17635  Total Reward:  2507054.270000007
# price for reward: 6259.99
# Step:  17636  Total Reward:  2502962.3900000066
# price for reward: 6258.28
# Step:  17637  Total Reward:  2502006.500000007
# price for reward: 6255.99
# Step:  17638  Total Reward:  2500726.3900000066
# price for reward: 6261.82
# Step:  17639  Total Reward:  2503985.360000007
# price for reward: 6265.77
# Step:  17640  Total Reward:  2506193.410000007
# price for reward: 6265.79
# Step:  17641  Total Reward:  2506204.590000007
# price for reward: 6265.79
# Step:  17642  Total Reward:  2506204.590000007
# price for reward: 6262.82
# Step:  17643  Total Reward:  2504544.360000007
# price for reward: 6251.2
# Step:  17644  Total Reward:  2498048.780000007
# price for reward: 6252.21
# Step:  17645  Total Reward:  2498613.370000007
# price for reward: 6259.84
# Step:  17646  Total Reward:  2502878.540000007
# price for reward: 6264.47
# Step:  17647  Total Reward:  2505466.710000007
# price for reward: 6273.29
# Step:  17648  Total Reward:  2510397.090000007
# price for reward: 6274.81
# Step:  17649  Total Reward:  2511246.770000007
# price for reward: 6275.16
# Step:  17650  Total Reward:  2511442.420000007
# price for reward: 6271.89
# Step:  17651  Total Reward:  2509614.490000007
# price for reward: 6269.21
# Step:  17652  Total Reward:  2508116.370000007
# price for reward: 6274.0
# Step:  17653  Total Reward:  2510793.980000007
# price for reward: 6274.0
# Step:  17654  Total Reward:  2510793.980000007
# price for reward: 6274.0
# Step:  17655  Total Reward:  2510793.980000007
# price for reward: 6285.0
# Step:  17656  Total Reward:  2516942.980000007
# price for reward: 6292.46
# Step:  17657  Total Reward:  2521113.120000007
# price for reward: 6299.18
# Step:  17658  Total Reward:  2524869.600000007
# price for reward: 6294.58
# Step:  17659  Total Reward:  2522298.2000000067
# price for reward: 6298.0
# Step:  17660  Total Reward:  2522298.2000000067
# price for reward: 6292.43
# Step:  17661  Total Reward:  2522298.2000000067
# price for reward: 6292.43
# Step:  17662  Total Reward:  2522298.2000000067
# price for reward: 6294.71
# Step:  17663  Total Reward:  2522298.2000000067
# price for reward: 6294.71
# Step:  17664  Total Reward:  2522298.2000000067
# price for reward: 6286.65
# Step:  17665  Total Reward:  2522298.2000000067
# price for reward: 6290.08
# Step:  17666  Total Reward:  2524219.0000000065
# price for reward: 6285.55
# Step:  17667  Total Reward:  2521682.2000000067
# price for reward: 6283.96
# Step:  17668  Total Reward:  2520791.800000007
# price for reward: 6282.95
# Step:  17669  Total Reward:  2520226.2000000067
# price for reward: 6282.53
# Step:  17670  Total Reward:  2519991.0000000065
# price for reward: 6281.51
# Step:  17671  Total Reward:  2519419.800000007
# price for reward: 6279.77
# Step:  17672  Total Reward:  2518445.400000007
# price for reward: 6276.7
# Step:  17673  Total Reward:  2516726.2000000067
# price for reward: 6276.7
# Step:  17674  Total Reward:  2516726.2000000067
# price for reward: 6279.25
# Step:  17675  Total Reward:  2518154.2000000067
# price for reward: 6273.83
# Step:  17676  Total Reward:  2515119.0000000065
# price for reward: 6269.01
# Step:  17677  Total Reward:  2512419.800000007
# price for reward: 6263.76
# Step:  17678  Total Reward:  2509479.800000007
# price for reward: 6275.33
# Step:  17679  Total Reward:  2515959.0000000065
# price for reward: 6281.32
# Step:  17680  Total Reward:  2519313.4000000064
# price for reward: 6275.29
# Step:  17681  Total Reward:  2515936.6000000066
# price for reward: 6273.26
# Step:  17682  Total Reward:  2514799.800000007
# price for reward: 6273.29
# Step:  17683  Total Reward:  2514816.6000000066
# price for reward: 6286.12
# Step:  17684  Total Reward:  2522001.4000000064
# price for reward: 6278.92
# Step:  17685  Total Reward:  2522001.4000000064
# price for reward: 6282.91
# Step:  17686  Total Reward:  2522001.4000000064
# price for reward: 6278.88
# Step:  17687  Total Reward:  2522001.4000000064
# price for reward: 6278.89
# Step:  17688  Total Reward:  2522001.4000000064
# price for reward: 6277.31
# Step:  17689  Total Reward:  2522001.4000000064
# price for reward: 6278.91
# Step:  17690  Total Reward:  2522001.4000000064
# price for reward: 6279.51
# Step:  17691  Total Reward:  2522001.4000000064
# price for reward: 6282.62
# Step:  17692  Total Reward:  2522001.4000000064
# price for reward: 6279.62
# Step:  17693  Total Reward:  2522001.4000000064
# price for reward: 6265.82
# Step:  17694  Total Reward:  2514273.4000000064
# price for reward: 6265.82
# Step:  17695  Total Reward:  2514273.4000000064
# price for reward: 6270.61
# Step:  17696  Total Reward:  2516955.8000000063
# price for reward: 6270.61
# Step:  17697  Total Reward:  2516955.8000000063
# price for reward: 6253.54
# Step:  17698  Total Reward:  2507396.6000000066
# price for reward: 6263.83
# Step:  17699  Total Reward:  2513159.0000000065
# price for reward: 6263.83
# Step:  17700  Total Reward:  2513159.0000000065
# price for reward: 6263.83
# Step:  17701  Total Reward:  2513159.0000000065
# price for reward: 6263.83
# Step:  17702  Total Reward:  2513159.0000000065
# price for reward: 6263.83
# Step:  17703  Total Reward:  2513159.0000000065
# price for reward: 6272.87
# Step:  17704  Total Reward:  2518221.4000000064
# price for reward: 6273.76
# Step:  17705  Total Reward:  2518719.800000007
# price for reward: 6276.72
# Step:  17706  Total Reward:  2520377.400000007
# price for reward: 6276.72
# Step:  17707  Total Reward:  2520377.400000007
# price for reward: 6268.24
# Step:  17708  Total Reward:  2515628.6000000066
# price for reward: 6270.96
# Step:  17709  Total Reward:  2517151.800000007
# price for reward: 6277.77
# Step:  17710  Total Reward:  2520965.400000007
# price for reward: 6277.49
# Step:  17711  Total Reward:  2520808.6000000066
# price for reward: 6281.21
# Step:  17712  Total Reward:  2520808.6000000066
# price for reward: 6275.86
# Step:  17713  Total Reward:  2520808.6000000066
# price for reward: 6285.17
# Step:  17714  Total Reward:  2520808.6000000066
# price for reward: 6288.12
# Step:  17715  Total Reward:  2520808.6000000066
# price for reward: 6288.11
# Step:  17716  Total Reward:  2520808.6000000066
# price for reward: 6288.11
# Step:  17717  Total Reward:  2520808.6000000066
# price for reward: 6283.06
# Step:  17718  Total Reward:  2520808.6000000066
# price for reward: 6285.55
# Step:  17719  Total Reward:  2520808.6000000066
# price for reward: 6284.74
# Step:  17720  Total Reward:  2520808.6000000066
# price for reward: 6270.69
# Step:  17721  Total Reward:  2512940.6000000066
# price for reward: 6257.23
# Step:  17722  Total Reward:  2505403.0000000065
# price for reward: 6239.45
# Step:  17723  Total Reward:  2495446.2000000067
# price for reward: 6239.29
# Step:  17724  Total Reward:  2495356.6000000066
# price for reward: 6248.09
# Step:  17725  Total Reward:  2500284.6000000066
# price for reward: 6250.71
# Step:  17726  Total Reward:  2501751.800000007
# price for reward: 6256.54
# Step:  17727  Total Reward:  2505016.6000000066
# price for reward: 6250.29
# Step:  17728  Total Reward:  2501516.6000000066
# price for reward: 6249.25
# Step:  17729  Total Reward:  2500934.2000000067
# price for reward: 6250.81
# Step:  17730  Total Reward:  2501807.800000007
# price for reward: 6244.7
# Step:  17731  Total Reward:  2498386.2000000067
# price for reward: 6249.27
# Step:  17732  Total Reward:  2500945.400000007
# price for reward: 6250.71
# Step:  17733  Total Reward:  2501751.800000007
# price for reward: 6253.62
# Step:  17734  Total Reward:  2503381.4000000064
# price for reward: 6247.44
# Step:  17735  Total Reward:  2499920.6000000066
# price for reward: 6250.32
# Step:  17736  Total Reward:  2501533.4000000064
# price for reward: 6258.26
# Step:  17737  Total Reward:  2505979.800000007
# price for reward: 6262.13
# Step:  17738  Total Reward:  2508147.000000007
# price for reward: 6264.72
# Step:  17739  Total Reward:  2509597.400000007
# price for reward: 6266.43
# Step:  17740  Total Reward:  2510555.000000007
# price for reward: 6266.43
# Step:  17741  Total Reward:  2510555.000000007
# price for reward: 6267.72
# Step:  17742  Total Reward:  2511277.400000007
# price for reward: 6260.89
# Step:  17743  Total Reward:  2507452.600000007
# price for reward: 6249.07
# Step:  17744  Total Reward:  2500833.4000000064
# price for reward: 6256.97
# Step:  17745  Total Reward:  2505257.400000007
# price for reward: 6263.7
# Step:  17746  Total Reward:  2509026.2000000067
# price for reward: 6260.68
# Step:  17747  Total Reward:  2507335.000000007
# price for reward: 6257.51
# Step:  17748  Total Reward:  2505559.800000007
# price for reward: 6256.27
# Step:  17749  Total Reward:  2504865.400000007
# price for reward: 6262.98
# Step:  17750  Total Reward:  2508623.0000000065
# price for reward: 6262.98
# Step:  17751  Total Reward:  2508623.0000000065
# price for reward: 6254.3
# Step:  17752  Total Reward:  2503762.2000000067
# price for reward: 6251.58
# Step:  17753  Total Reward:  2502239.0000000065
# price for reward: 6257.41
# Step:  17754  Total Reward:  2505503.800000007
# price for reward: 6257.41
# Step:  17755  Total Reward:  2505503.800000007
# price for reward: 6255.1
# Step:  17756  Total Reward:  2504210.2000000067
# price for reward: 6253.79
# Step:  17757  Total Reward:  2503476.6000000066
# price for reward: 6258.13
# Step:  17758  Total Reward:  2505907.000000007
# price for reward: 6282.47
# Step:  17759  Total Reward:  2519537.400000007
# price for reward: 6276.91
# Step:  17760  Total Reward:  2516423.800000007
# price for reward: 6279.12
# Step:  17761  Total Reward:  2517661.4000000064
# price for reward: 6274.97
# Step:  17762  Total Reward:  2515337.400000007
# price for reward: 6272.55
# Step:  17763  Total Reward:  2513982.2000000067
# price for reward: 6280.86
# Step:  17764  Total Reward:  2518635.8000000063
# price for reward: 6277.86
# Step:  17765  Total Reward:  2516955.8000000063
# price for reward: 6277.86
# Step:  17766  Total Reward:  2516955.8000000063
# price for reward: 6277.87
# Step:  17767  Total Reward:  2516961.4000000064
# price for reward: 6277.87
# Step:  17768  Total Reward:  2516961.4000000064
# price for reward: 6277.55
# Step:  17769  Total Reward:  2516782.2000000067
# price for reward: 6302.2
# Step:  17770  Total Reward:  2530586.2000000067
# price for reward: 6334.28
# Step:  17771  Total Reward:  2548551.0000000065
# price for reward: 6326.31
# Step:  17772  Total Reward:  2544087.800000007
# price for reward: 6307.44
# Step:  17773  Total Reward:  2533520.6000000066
# price for reward: 6316.26
# Step:  17774  Total Reward:  2533520.6000000066
# price for reward: 6309.88
# Step:  17775  Total Reward:  2533520.6000000066
# price for reward: 6307.01
# Step:  17776  Total Reward:  2533520.6000000066
# price for reward: 6304.73
# Step:  17777  Total Reward:  2533520.6000000066
# price for reward: 6302.2
# Step:  17778  Total Reward:  2533520.6000000066
# price for reward: 6299.18
# Step:  17779  Total Reward:  2533520.6000000066
# price for reward: 6303.95
# Step:  17780  Total Reward:  2536191.8000000063
# price for reward: 6302.24
# Step:  17781  Total Reward:  2535234.2000000062
# price for reward: 6292.05
# Step:  17782  Total Reward:  2529527.8000000063
# price for reward: 6299.26
# Step:  17783  Total Reward:  2533565.4000000064
# price for reward: 6297.99
# Step:  17784  Total Reward:  2532854.2000000062
# price for reward: 6292.05
# Step:  17785  Total Reward:  2529527.8000000063
# price for reward: 6291.81
# Step:  17786  Total Reward:  2529393.4000000064
# price for reward: 6282.93
# Step:  17787  Total Reward:  2524420.6000000066
# price for reward: 6290.31
# Step:  17788  Total Reward:  2528553.4000000064
# price for reward: 6290.31
# Step:  17789  Total Reward:  2528553.4000000064
# price for reward: 6290.31
# Step:  17790  Total Reward:  2528553.4000000064
# price for reward: 6285.36
# Step:  17791  Total Reward:  2525781.400000006
# price for reward: 6290.09
# Step:  17792  Total Reward:  2528430.2000000062
# price for reward: 6290.79
# Step:  17793  Total Reward:  2528822.2000000062
# price for reward: 6293.08
# Step:  17794  Total Reward:  2530104.600000006
# price for reward: 6282.79
# Step:  17795  Total Reward:  2524342.2000000062
# price for reward: 6288.98
# Step:  17796  Total Reward:  2527808.600000006
# price for reward: 6287.98
# Step:  17797  Total Reward:  2527248.600000006
# price for reward: 6280.46
# Step:  17798  Total Reward:  2523037.4000000064
# price for reward: 6286.58
# Step:  17799  Total Reward:  2526464.600000006
# price for reward: 6286.12
# Step:  17800  Total Reward:  2526207.000000006
# price for reward: 6286.12
# Step:  17801  Total Reward:  2526207.000000006
# price for reward: 6282.99
# Step:  17802  Total Reward:  2524454.2000000062
# price for reward: 6267.62
# Step:  17803  Total Reward:  2515847.000000006
# price for reward: 6260.09
# Step:  17804  Total Reward:  2511630.2000000062
# price for reward: 6253.29
# Step:  17805  Total Reward:  2507822.2000000062
# price for reward: 6245.03
# Step:  17806  Total Reward:  2503196.600000006
# price for reward: 6264.05
# Step:  17807  Total Reward:  2513847.8000000063
# price for reward: 6264.05
# Step:  17808  Total Reward:  2513847.8000000063
# price for reward: 6264.32
# Step:  17809  Total Reward:  2513999.000000006
# price for reward: 6268.1
# Step:  17810  Total Reward:  2516115.8000000063
# price for reward: 6268.87
# Step:  17811  Total Reward:  2516547.000000006
# price for reward: 6270.54
# Step:  17812  Total Reward:  2517482.2000000062
# price for reward: 6270.54
# Step:  17813  Total Reward:  2517482.2000000062
# price for reward: 6252.97
# Step:  17814  Total Reward:  2517482.2000000062
# price for reward: 6252.71
# Step:  17815  Total Reward:  2517482.2000000062
# price for reward: 6249.46
# Step:  17816  Total Reward:  2517482.2000000062
# price for reward: 6252.68
# Step:  17817  Total Reward:  2519291.8400000064
# price for reward: 6252.68
# Step:  17818  Total Reward:  2519291.8400000064
# price for reward: 6250.75
# Step:  17819  Total Reward:  2518207.180000006
# price for reward: 6250.75
# Step:  17820  Total Reward:  2518207.180000006
# price for reward: 6251.65
# Step:  17821  Total Reward:  2518712.980000006
# price for reward: 6250.71
# Step:  17822  Total Reward:  2518184.7000000062
# price for reward: 6260.43
# Step:  17823  Total Reward:  2523647.3400000064
# price for reward: 6259.78
# Step:  17824  Total Reward:  2523282.040000006
# price for reward: 6252.25
# Step:  17825  Total Reward:  2519050.180000006
# price for reward: 6252.25
# Step:  17826  Total Reward:  2519050.180000006
# price for reward: 6257.49
# Step:  17827  Total Reward:  2519050.180000006
# price for reward: 6251.21
# Step:  17828  Total Reward:  2519050.180000006
# price for reward: 6246.26
# Step:  17829  Total Reward:  2519050.180000006
# price for reward: 6240.04
# Step:  17830  Total Reward:  2515548.320000006
# price for reward: 6238.59
# Step:  17831  Total Reward:  2514731.970000006
# price for reward: 6236.93
# Step:  17832  Total Reward:  2513797.390000006
# price for reward: 6232.46
# Step:  17833  Total Reward:  2511280.780000006
# price for reward: 6234.17
# Step:  17834  Total Reward:  2512243.510000006
# price for reward: 6231.78
# Step:  17835  Total Reward:  2510897.9400000055
# price for reward: 6235.69
# Step:  17836  Total Reward:  2513099.2700000056
# price for reward: 6238.58
# Step:  17837  Total Reward:  2514726.340000006
# price for reward: 6243.51
# Step:  17838  Total Reward:  2517501.930000006
# price for reward: 6238.27
# Step:  17839  Total Reward:  2514551.810000006
# price for reward: 6237.0
# Step:  17840  Total Reward:  2513836.800000006
# price for reward: 6243.99
# Step:  17841  Total Reward:  2517772.1700000055
# price for reward: 6241.91
# Step:  17842  Total Reward:  2517772.1700000055
# price for reward: 6244.8
# Step:  17843  Total Reward:  2517772.1700000055
# price for reward: 6246.5
# Step:  17844  Total Reward:  2517772.1700000055
# price for reward: 6240.91
# Step:  17845  Total Reward:  2517772.1700000055
# price for reward: 6242.32
# Step:  17846  Total Reward:  2518566.000000005
# price for reward: 6241.84
# Step:  17847  Total Reward:  2518295.7600000054
# price for reward: 6239.61
# Step:  17848  Total Reward:  2517040.270000005
# price for reward: 6241.84
# Step:  17849  Total Reward:  2518295.7600000054
# price for reward: 6241.84
# Step:  17850  Total Reward:  2518295.7600000054
# price for reward: 6244.5
# Step:  17851  Total Reward:  2519793.3400000054
# price for reward: 6244.91
# Step:  17852  Total Reward:  2520024.1700000055
# price for reward: 6247.01
# Step:  17853  Total Reward:  2521206.470000006
# price for reward: 6255.17
# Step:  17854  Total Reward:  2525800.5500000054
# price for reward: 6253.89
# Step:  17855  Total Reward:  2525079.9100000057
# price for reward: 6257.01
# Step:  17856  Total Reward:  2526836.470000006
# price for reward: 6252.97
# Step:  17857  Total Reward:  2524561.950000006
# price for reward: 6255.05
# Step:  17858  Total Reward:  2525732.9900000053
# price for reward: 6252.92
# Step:  17859  Total Reward:  2524533.8000000054
# price for reward: 6254.68
# Step:  17860  Total Reward:  2525524.6800000058
# price for reward: 6254.68
# Step:  17861  Total Reward:  2525524.6800000058
# price for reward: 6251.9
# Step:  17862  Total Reward:  2523959.540000005
# price for reward: 6262.59
# Step:  17863  Total Reward:  2529978.0100000054
# price for reward: 6266.44
# Step:  17864  Total Reward:  2532145.560000005
# price for reward: 6267.59
# Step:  17865  Total Reward:  2532793.0100000054
# price for reward: 6267.59
# Step:  17866  Total Reward:  2532793.0100000054
# price for reward: 6260.91
# Step:  17867  Total Reward:  2532793.0100000054
# price for reward: 6258.18
# Step:  17868  Total Reward:  2532793.0100000054
# price for reward: 6258.18
# Step:  17869  Total Reward:  2532793.0100000054
# price for reward: 6254.89
# Step:  17870  Total Reward:  2530937.4500000053
# price for reward: 6254.89
# Step:  17871  Total Reward:  2530937.4500000053
# price for reward: 6254.89
# Step:  17872  Total Reward:  2530937.4500000053
# price for reward: 6250.89
# Step:  17873  Total Reward:  2528681.4500000053
# price for reward: 6250.89
# Step:  17874  Total Reward:  2528681.4500000053
# price for reward: 6252.24
# Step:  17875  Total Reward:  2529442.850000005
# price for reward: 6250.17
# Step:  17876  Total Reward:  2528275.3700000052
# price for reward: 6254.19
# Step:  17877  Total Reward:  2530542.650000005
# price for reward: 6255.86
# Step:  17878  Total Reward:  2531484.5300000054
# price for reward: 6251.08
# Step:  17879  Total Reward:  2528788.6100000055
# price for reward: 6249.26
# Step:  17880  Total Reward:  2527762.1300000055
# price for reward: 6263.61
# Step:  17881  Total Reward:  2535855.5300000054
# price for reward: 6258.81
# Step:  17882  Total Reward:  2533148.3300000057
# price for reward: 6261.01
# Step:  17883  Total Reward:  2533148.3300000057
# price for reward: 6258.83
# Step:  17884  Total Reward:  2533148.3300000057
# price for reward: 6258.81
# Step:  17885  Total Reward:  2533148.3300000057
# price for reward: 6251.46
# Step:  17886  Total Reward:  2533148.3300000057
# price for reward: 6254.8
# Step:  17887  Total Reward:  2535035.4300000058
# price for reward: 6252.29
# Step:  17888  Total Reward:  2533617.280000006
# price for reward: 6251.09
# Step:  17889  Total Reward:  2532939.280000006
# price for reward: 6254.7
# Step:  17890  Total Reward:  2534978.9300000058
# price for reward: 6254.1
# Step:  17891  Total Reward:  2534639.9300000058
# price for reward: 6254.0
# Step:  17892  Total Reward:  2534583.4300000058
# price for reward: 6258.33
# Step:  17893  Total Reward:  2537029.880000006
# price for reward: 6258.23
# Step:  17894  Total Reward:  2536973.3800000055
# price for reward: 6258.23
# Step:  17895  Total Reward:  2536973.3800000055
# price for reward: 6258.19
# Step:  17896  Total Reward:  2536950.7800000054
# price for reward: 6258.19
# Step:  17897  Total Reward:  2536950.7800000054
# price for reward: 6258.19
# Step:  17898  Total Reward:  2536950.7800000054
# price for reward: 6258.19
# Step:  17899  Total Reward:  2536950.7800000054
# price for reward: 6260.19
# Step:  17900  Total Reward:  2536950.7800000054
# price for reward: 6255.78
# Step:  17901  Total Reward:  2536950.7800000054
# price for reward: 6251.39
# Step:  17902  Total Reward:  2536950.7800000054
# price for reward: 6242.98
# Step:  17903  Total Reward:  2536950.7800000054
# price for reward: 6242.98
# Step:  17904  Total Reward:  2536950.7800000054
# price for reward: 6239.99
# Step:  17905  Total Reward:  2536950.7800000054
# price for reward: 6240.41
# Step:  17906  Total Reward:  2536950.7800000054
# price for reward: 6240.41
# Step:  17907  Total Reward:  2536950.7800000054
# price for reward: 6234.81
# Step:  17908  Total Reward:  2533781.1800000058
# price for reward: 6235.98
# Step:  17909  Total Reward:  2534443.400000005
# price for reward: 6229.93
# Step:  17910  Total Reward:  2531019.1000000057
# price for reward: 6195.76
# Step:  17911  Total Reward:  2511678.8800000055
# price for reward: 6205.98
# Step:  17912  Total Reward:  2517463.400000005
# price for reward: 6209.32
# Step:  17913  Total Reward:  2519353.840000005
# price for reward: 6199.48
# Step:  17914  Total Reward:  2513784.400000005
# price for reward: 6204.21
# Step:  17915  Total Reward:  2516461.580000005
# price for reward: 6200.38
# Step:  17916  Total Reward:  2514293.8000000054
# price for reward: 6204.21
# Step:  17917  Total Reward:  2516461.580000005
# price for reward: 6223.16
# Step:  17918  Total Reward:  2527187.2800000054
# price for reward: 6223.0
# Step:  17919  Total Reward:  2527096.7200000053
# price for reward: 6234.4
# Step:  17920  Total Reward:  2533549.1200000052
# price for reward: 6223.24
# Step:  17921  Total Reward:  2527232.560000005
# price for reward: 6231.13
# Step:  17922  Total Reward:  2531698.3000000054
# price for reward: 6228.9
# Step:  17923  Total Reward:  2531698.3000000054
# price for reward: 6228.9
# Step:  17924  Total Reward:  2531698.3000000054
# price for reward: 6235.39
# Step:  17925  Total Reward:  2531698.3000000054
# price for reward: 6233.07
# Step:  17926  Total Reward:  2531698.3000000054
# price for reward: 6230.69
# Step:  17927  Total Reward:  2531698.3000000054
# price for reward: 6232.14
# Step:  17928  Total Reward:  2532519.000000006
# price for reward: 6227.96
# Step:  17929  Total Reward:  2530153.1200000057
# price for reward: 6223.85
# Step:  17930  Total Reward:  2527826.860000006
# price for reward: 6233.1
# Step:  17931  Total Reward:  2533062.360000006
# price for reward: 6233.1
# Step:  17932  Total Reward:  2533062.360000006
# price for reward: 6227.29
# Step:  17933  Total Reward:  2529773.900000006
# price for reward: 6227.29
# Step:  17934  Total Reward:  2529773.900000006
# price for reward: 6239.88
# Step:  17935  Total Reward:  2536899.840000006
# price for reward: 6244.24
# Step:  17936  Total Reward:  2539367.6000000057
# price for reward: 6243.66
# Step:  17937  Total Reward:  2539039.320000006
# price for reward: 6243.66
# Step:  17938  Total Reward:  2539039.320000006
# price for reward: 6241.15
# Step:  17939  Total Reward:  2537618.6600000057
# price for reward: 6237.16
# Step:  17940  Total Reward:  2535360.320000006
# price for reward: 6239.63
# Step:  17941  Total Reward:  2536758.340000006
# price for reward: 6237.17
# Step:  17942  Total Reward:  2535365.980000006
# price for reward: 6226.49
# Step:  17943  Total Reward:  2529321.1000000057
# price for reward: 6236.88
# Step:  17944  Total Reward:  2535201.840000006
# price for reward: 6239.69
# Step:  17945  Total Reward:  2536792.3000000054
# price for reward: 6237.19
# Step:  17946  Total Reward:  2535377.3000000054
# price for reward: 6239.15
# Step:  17947  Total Reward:  2536486.6600000057
# price for reward: 6242.01
# Step:  17948  Total Reward:  2538105.420000006
# price for reward: 6242.01
# Step:  17949  Total Reward:  2538105.420000006
# price for reward: 6250.0
# Step:  17950  Total Reward:  2542627.760000006
# price for reward: 6255.05
# Step:  17951  Total Reward:  2545486.060000006
# price for reward: 6246.74
# Step:  17952  Total Reward:  2540782.6000000057
# price for reward: 6258.8
# Step:  17953  Total Reward:  2547608.560000006
# price for reward: 6259.47
# Step:  17954  Total Reward:  2547987.780000006
# price for reward: 6259.47
# Step:  17955  Total Reward:  2547987.780000006
# price for reward: 6259.47
# Step:  17956  Total Reward:  2547987.780000006
# price for reward: 6257.01
# Step:  17957  Total Reward:  2547987.780000006
# price for reward: 6254.73
# Step:  17958  Total Reward:  2547987.780000006
# price for reward: 6259.97
# Step:  17959  Total Reward:  2550958.8600000064
# price for reward: 6259.97
# Step:  17960  Total Reward:  2550958.8600000064
# price for reward: 6253.24
# Step:  17961  Total Reward:  2547142.9500000062
# price for reward: 6243.7
# Step:  17962  Total Reward:  2541733.770000006
# price for reward: 6243.01
# Step:  17963  Total Reward:  2541342.540000006
# price for reward: 6247.73
# Step:  17964  Total Reward:  2544018.780000006
# price for reward: 6250.84
# Step:  17965  Total Reward:  2545782.1500000064
# price for reward: 6245.51
# Step:  17966  Total Reward:  2542760.040000006
# price for reward: 6247.07
# Step:  17967  Total Reward:  2543644.560000006
# price for reward: 6247.05
# Step:  17968  Total Reward:  2543633.2200000063
# price for reward: 6246.22
# Step:  17969  Total Reward:  2543162.6100000064
# price for reward: 6251.55
# Step:  17970  Total Reward:  2546184.7200000063
# price for reward: 6249.45
# Step:  17971  Total Reward:  2544994.020000006
# price for reward: 6247.64
# Step:  17972  Total Reward:  2543967.7500000065
# price for reward: 6253.07
# Step:  17973  Total Reward:  2547046.560000006
# price for reward: 6256.39
# Step:  17974  Total Reward:  2548929.0000000065
# price for reward: 6260.19
# Step:  17975  Total Reward:  2551083.600000006
# price for reward: 6260.19
# Step:  17976  Total Reward:  2551083.600000006
# price for reward: 6261.39
# Step:  17977  Total Reward:  2551083.600000006
# price for reward: 6264.17
# Step:  17978  Total Reward:  2551083.600000006
# price for reward: 6260.0
# Step:  17979  Total Reward:  2551083.600000006
# price for reward: 6262.87
# Step:  17980  Total Reward:  2551083.600000006
# price for reward: 6263.24
# Step:  17981  Total Reward:  2551083.600000006
# price for reward: 6261.13
# Step:  17982  Total Reward:  2551083.600000006
# price for reward: 6258.29
# Step:  17983  Total Reward:  2551083.600000006
# price for reward: 6258.11
# Step:  17984  Total Reward:  2551083.600000006
# price for reward: 6258.11
# Step:  17985  Total Reward:  2551083.600000006
# price for reward: 6249.99
# Step:  17986  Total Reward:  2546479.5600000066
# price for reward: 6253.05
# Step:  17987  Total Reward:  2548214.5800000066
# price for reward: 6252.23
# Step:  17988  Total Reward:  2547749.640000006
# price for reward: 6256.27
# Step:  17989  Total Reward:  2550040.320000007
# price for reward: 6256.27
# Step:  17990  Total Reward:  2550040.320000007
# price for reward: 6251.38
# Step:  17991  Total Reward:  2547267.6900000065
# price for reward: 6239.53
# Step:  17992  Total Reward:  2540548.7400000063
# price for reward: 6240.81
# Step:  17993  Total Reward:  2541274.5000000065
# price for reward: 6238.61
# Step:  17994  Total Reward:  2540027.100000006
# price for reward: 6238.61
# Step:  17995  Total Reward:  2540027.100000006
# price for reward: 6245.94
# Step:  17996  Total Reward:  2544183.2100000065
# price for reward: 6247.53
# Step:  17997  Total Reward:  2545084.7400000063
# price for reward: 6247.46
# Step:  17998  Total Reward:  2545045.0500000063
# price for reward: 6251.38
# Step:  17999  Total Reward:  2547267.6900000065
# price for reward: 6249.29
# Step:  18000  Total Reward:  2546082.6600000067
# price for reward: 6252.93
# Step:  18001  Total Reward:  2548146.5400000066
# price for reward: 6252.93
# Step:  18002  Total Reward:  2548146.5400000066
# price for reward: 6248.61
# Step:  18003  Total Reward:  2545697.100000006
# price for reward: 6250.5
# Step:  18004  Total Reward:  2546768.7300000065
# price for reward: 6252.17
# Step:  18005  Total Reward:  2547715.6200000066
# price for reward: 6252.17
# Step:  18006  Total Reward:  2547715.6200000066
# price for reward: 6259.16
# Step:  18007  Total Reward:  2551678.9500000062
# price for reward: 6258.4
# Step:  18008  Total Reward:  2551248.0300000063
# price for reward: 6257.87
# Step:  18009  Total Reward:  2550947.5200000065
# price for reward: 6261.18
# Step:  18010  Total Reward:  2552824.2900000066
# price for reward: 6258.11
# Step:  18011  Total Reward:  2551083.600000006
# price for reward: 6262.3
# Step:  18012  Total Reward:  2553459.3300000066
# price for reward: 6259.82
# Step:  18013  Total Reward:  2553459.3300000066
# price for reward: 6259.79
# Step:  18014  Total Reward:  2553459.3300000066
# price for reward: 6258.52
# Step:  18015  Total Reward:  2553459.3300000066
# price for reward: 6259.72
# Step:  18016  Total Reward:  2554139.7300000065
# price for reward: 6261.06
# Step:  18017  Total Reward:  2554899.5100000063
# price for reward: 6258.48
# Step:  18018  Total Reward:  2553436.650000006
# price for reward: 6257.92
# Step:  18019  Total Reward:  2553119.1300000064
# price for reward: 6257.92
# Step:  18020  Total Reward:  2553119.1300000064
# price for reward: 6257.36
# Step:  18021  Total Reward:  2552801.610000006
# price for reward: 6270.44
# Step:  18022  Total Reward:  2560217.9700000063
# price for reward: 6283.97
# Step:  18023  Total Reward:  2567889.4800000065
# price for reward: 6278.9
# Step:  18024  Total Reward:  2565014.790000006
# price for reward: 6273.24
# Step:  18025  Total Reward:  2565014.790000006
# price for reward: 6268.69
# Step:  18026  Total Reward:  2565014.790000006
# price for reward: 6263.21
# Step:  18027  Total Reward:  2561902.150000006
# price for reward: 6260.0
# Step:  18028  Total Reward:  2560078.870000006
# price for reward: 6252.08
# Step:  18029  Total Reward:  2555580.310000006
# price for reward: 6256.59
# Step:  18030  Total Reward:  2558141.9900000063
# price for reward: 6250.25
# Step:  18031  Total Reward:  2554540.870000006
# price for reward: 6264.96
# Step:  18032  Total Reward:  2562896.150000006
# price for reward: 6264.24
# Step:  18033  Total Reward:  2562487.190000006
# price for reward: 6261.86
# Step:  18034  Total Reward:  2561135.350000006
# price for reward: 6259.99
# Step:  18035  Total Reward:  2560073.190000006
# price for reward: 6263.45
# Step:  18036  Total Reward:  2562038.4700000063
# price for reward: 6263.98
# Step:  18037  Total Reward:  2562339.510000006
# price for reward: 6259.98
# Step:  18038  Total Reward:  2560067.510000006
# price for reward: 6257.72
# Step:  18039  Total Reward:  2558783.830000006
# price for reward: 6258.58
# Step:  18040  Total Reward:  2558783.830000006
# price for reward: 6256.95
# Step:  18041  Total Reward:  2558783.830000006
# price for reward: 6256.0
# Step:  18042  Total Reward:  2558783.830000006
# price for reward: 6251.67
# Step:  18043  Total Reward:  2558783.830000006
# price for reward: 6251.1
# Step:  18044  Total Reward:  2558783.830000006
# price for reward: 6245.12
# Step:  18045  Total Reward:  2555381.2100000056
# price for reward: 6240.49
# Step:  18046  Total Reward:  2552746.740000006
# price for reward: 6249.44
# Step:  18047  Total Reward:  2557839.2900000056
# price for reward: 6245.17
# Step:  18048  Total Reward:  2555409.6600000057
# price for reward: 6241.65
# Step:  18049  Total Reward:  2553406.7800000054
# price for reward: 6237.82
# Step:  18050  Total Reward:  2551227.5100000054
# price for reward: 6233.06
# Step:  18051  Total Reward:  2548519.070000006
# price for reward: 6237.55
# Step:  18052  Total Reward:  2551073.880000006
# price for reward: 6233.1
# Step:  18053  Total Reward:  2548541.830000006
# price for reward: 6236.56
# Step:  18054  Total Reward:  2550510.570000006
# price for reward: 6248.06
# Step:  18055  Total Reward:  2550510.570000006
# price for reward: 6248.37
# Step:  18056  Total Reward:  2550686.650000006
# price for reward: 6246.12
# Step:  18057  Total Reward:  2549408.650000006
# price for reward: 6246.12
# Step:  18058  Total Reward:  2549408.650000006
# price for reward: 6246.12
# Step:  18059  Total Reward:  2549408.650000006
# price for reward: 6246.1
# Step:  18060  Total Reward:  2549408.650000006
# price for reward: 6251.78
# Step:  18061  Total Reward:  2549408.650000006
# price for reward: 6249.21
# Step:  18062  Total Reward:  2549408.650000006
# price for reward: 6249.63
# Step:  18063  Total Reward:  2549408.650000006
# price for reward: 6249.21
# Step:  18064  Total Reward:  2549408.650000006
# price for reward: 6246.34
# Step:  18065  Total Reward:  2549408.650000006
# price for reward: 6240.0
# Step:  18066  Total Reward:  2545807.530000006
# price for reward: 6240.0
# Step:  18067  Total Reward:  2545807.530000006
# price for reward: 6236.7
# Step:  18068  Total Reward:  2543933.130000006
# price for reward: 6231.23
# Step:  18069  Total Reward:  2540826.1700000055
# price for reward: 6225.42
# Step:  18070  Total Reward:  2537526.090000006
# price for reward: 6238.26
# Step:  18071  Total Reward:  2544819.210000006
# price for reward: 6238.26
# Step:  18072  Total Reward:  2544819.210000006
# price for reward: 6239.82
# Step:  18073  Total Reward:  2545705.2900000056
# price for reward: 6236.71
# Step:  18074  Total Reward:  2543938.8100000056
# price for reward: 6236.67
# Step:  18075  Total Reward:  2543916.090000006
# price for reward: 6233.8
# Step:  18076  Total Reward:  2542285.9300000058
# price for reward: 6224.34
# Step:  18077  Total Reward:  2536912.650000006
# price for reward: 6228.56
# Step:  18078  Total Reward:  2539309.610000006
# price for reward: 6232.8
# Step:  18079  Total Reward:  2541717.9300000058
# price for reward: 6229.94
# Step:  18080  Total Reward:  2540093.450000006
# price for reward: 6228.56
# Step:  18081  Total Reward:  2539309.610000006
# price for reward: 6233.84
# Step:  18082  Total Reward:  2542308.650000006
# price for reward: 6230.66
# Step:  18083  Total Reward:  2540502.4100000057
# price for reward: 6241.04
# Step:  18084  Total Reward:  2546398.250000006
# price for reward: 6238.63
# Step:  18085  Total Reward:  2545029.3700000057
# price for reward: 6231.27
# Step:  18086  Total Reward:  2540848.890000006
# price for reward: 6232.49
# Step:  18087  Total Reward:  2541541.8500000057
# price for reward: 6225.21
# Step:  18088  Total Reward:  2537406.8100000056
# price for reward: 6232.09
# Step:  18089  Total Reward:  2541314.650000006
# price for reward: 6230.35
# Step:  18090  Total Reward:  2540326.330000006
# price for reward: 6230.33
# Step:  18091  Total Reward:  2540314.970000006
# price for reward: 6239.57
# Step:  18092  Total Reward:  2545563.2900000056
# price for reward: 6239.57
# Step:  18093  Total Reward:  2545563.2900000056
# price for reward: 6237.05
# Step:  18094  Total Reward:  2544131.9300000058
# price for reward: 6240.47
# Step:  18095  Total Reward:  2546074.490000006
# price for reward: 6241.53
# Step:  18096  Total Reward:  2546676.570000006
# price for reward: 6244.52
# Step:  18097  Total Reward:  2548374.890000006
# price for reward: 6244.52
# Step:  18098  Total Reward:  2548374.890000006
# price for reward: 6251.85
# Step:  18099  Total Reward:  2552538.330000006
# price for reward: 6248.66
# Step:  18100  Total Reward:  2552538.330000006
# price for reward: 6248.94
# Step:  18101  Total Reward:  2552538.330000006
# price for reward: 6249.22
# Step:  18102  Total Reward:  2552538.330000006
# price for reward: 6251.2
# Step:  18103  Total Reward:  2552538.330000006
# price for reward: 6249.21
# Step:  18104  Total Reward:  2552538.330000006
# price for reward: 6248.29
# Step:  18105  Total Reward:  2552538.330000006
# price for reward: 6248.29
# Step:  18106  Total Reward:  2552538.330000006
# price for reward: 6247.78
# Step:  18107  Total Reward:  2552538.330000006
# price for reward: 6249.21
# Step:  18108  Total Reward:  2552538.330000006
# price for reward: 6257.07
# Step:  18109  Total Reward:  2552538.330000006
# price for reward: 6251.68
# Step:  18110  Total Reward:  2552538.330000006
# price for reward: 6249.67
# Step:  18111  Total Reward:  2552538.330000006
# price for reward: 6248.47
# Step:  18112  Total Reward:  2552538.330000006
# price for reward: 6247.35
# Step:  18113  Total Reward:  2552538.330000006
# price for reward: 6243.93
# Step:  18114  Total Reward:  2550595.770000006
# price for reward: 6243.48
# Step:  18115  Total Reward:  2550340.1700000055
# price for reward: 6238.79
# Step:  18116  Total Reward:  2547676.250000006
# price for reward: 6238.77
# Step:  18117  Total Reward:  2547664.890000006
# price for reward: 6238.77
# Step:  18118  Total Reward:  2547664.890000006
# price for reward: 6239.09
# Step:  18119  Total Reward:  2547846.650000006
# price for reward: 6237.85
# Step:  18120  Total Reward:  2547142.330000006
# price for reward: 6237.85
# Step:  18121  Total Reward:  2547142.330000006
# price for reward: 6237.85
# Step:  18122  Total Reward:  2547142.330000006
# price for reward: 6243.21
# Step:  18123  Total Reward:  2550186.8100000056
# price for reward: 6245.13
# Step:  18124  Total Reward:  2551277.3700000057
# price for reward: 6242.8
# Step:  18125  Total Reward:  2549953.9300000058
# price for reward: 6240.56
# Step:  18126  Total Reward:  2548681.610000006
# price for reward: 6247.2
# Step:  18127  Total Reward:  2552453.130000006
# price for reward: 6253.48
# Step:  18128  Total Reward:  2556020.1700000055
# price for reward: 6250.29
# Step:  18129  Total Reward:  2556020.1700000055
# price for reward: 6255.74
# Step:  18130  Total Reward:  2556020.1700000055
# price for reward: 6250.64
# Step:  18131  Total Reward:  2556020.1700000055
# price for reward: 6249.66
# Step:  18132  Total Reward:  2556020.1700000055
# price for reward: 6249.66
# Step:  18133  Total Reward:  2556020.1700000055
# price for reward: 6248.94
# Step:  18134  Total Reward:  2556020.1700000055
# price for reward: 6248.94
# Step:  18135  Total Reward:  2556020.1700000055
# price for reward: 6246.78
# Step:  18136  Total Reward:  2556020.1700000055
# price for reward: 6244.18
# Step:  18137  Total Reward:  2556020.1700000055
# price for reward: 6244.99
# Step:  18138  Total Reward:  2556020.1700000055
# price for reward: 6246.75
# Step:  18139  Total Reward:  2556020.1700000055
# price for reward: 6243.34
# Step:  18140  Total Reward:  2556020.1700000055
# price for reward: 6244.6
# Step:  18141  Total Reward:  2556020.1700000055
# price for reward: 6244.6
# Step:  18142  Total Reward:  2556020.1700000055
# price for reward: 6244.6
# Step:  18143  Total Reward:  2556020.1700000055
# price for reward: 6244.6
# ...
# price for reward: 5917.49
# Step:  19882  Total Reward:  2676523.1700000064
# price for reward: 5915.82
# Step:  19883  Total Reward:  2675486.100000006
# price for reward: 5924.07
# Step:  19884  Total Reward:  2680609.350000006
# price for reward: 5926.5
# Step:  19885  Total Reward:  2682118.3800000064
# price for reward: 5933.5
# Step:  19886  Total Reward:  2686465.3800000064
# price for reward: 5930.15
# Step:  19887  Total Reward:  2684385.0300000063
# price for reward: 5932.49
# Step:  19888  Total Reward:  2685838.1700000064
# price for reward: 5932.49
# Step:  19889  Total Reward:  2685838.1700000064
# price for reward: 5929.99
# Step:  19890  Total Reward:  2684285.6700000064
# price for reward: 5928.11
# Step:  19891  Total Reward:  2683118.190000006
# price for reward: 5935.9
# Step:  19892  Total Reward:  2687955.7800000063
# price for reward: 5933.02
# Step:  19893  Total Reward:  2686167.300000007
# price for reward: 5924.56
# Step:  19894  Total Reward:  2680913.6400000066
# price for reward: 5924.37
# Step:  19895  Total Reward:  2680795.6500000064
# price for reward: 5922.05
# Step:  19896  Total Reward:  2679354.9300000067
# price for reward: 5922.42
# Step:  19897  Total Reward:  2679584.7000000062
# price for reward: 5926.7
# Step:  19898  Total Reward:  2682242.580000006
# price for reward: 5925.0
# Step:  19899  Total Reward:  2681186.8800000064
# price for reward: 5937.4
# Step:  19900  Total Reward:  2688887.2800000063
# price for reward: 5943.11
# Step:  19901  Total Reward:  2692433.190000006
# price for reward: 5944.42
# Step:  19902  Total Reward:  2693246.7000000062
# price for reward: 5943.47
# Step:  19903  Total Reward:  2693246.7000000062
# price for reward: 5943.47
# Step:  19904  Total Reward:  2693246.7000000062
# price for reward: 5939.56
# Step:  19905  Total Reward:  2693246.7000000062
# price for reward: 5938.98
# Step:  19906  Total Reward:  2693246.7000000062
# price for reward: 5933.34
# Step:  19907  Total Reward:  2693246.7000000062
# price for reward: 5930.43
# Step:  19908  Total Reward:  2693246.7000000062
# price for reward: 5927.87
# Step:  19909  Total Reward:  2693246.7000000062
# price for reward: 5922.43
# Step:  19910  Total Reward:  2693246.7000000062
# price for reward: 5925.48
# Step:  19911  Total Reward:  2693246.7000000062
# price for reward: 5925.48
# Step:  19912  Total Reward:  2693246.7000000062
# price for reward: 5928.16
# Step:  19913  Total Reward:  2693246.7000000062
# price for reward: 5924.23
# Step:  19914  Total Reward:  2693246.7000000062
# price for reward: 5928.17
# Step:  19915  Total Reward:  2693246.7000000062
# price for reward: 5918.49
# Step:  19916  Total Reward:  2693246.7000000062
# price for reward: 5916.19
# Step:  19917  Total Reward:  2693246.7000000062
# price for reward: 5918.92
# Step:  19918  Total Reward:  2694950.2200000067
# price for reward: 5909.02
# Step:  19919  Total Reward:  2688772.620000007
# price for reward: 5909.4
# Step:  19920  Total Reward:  2689009.7400000063
# price for reward: 5915.51
# Step:  19921  Total Reward:  2692822.380000007
# price for reward: 5910.54
# Step:  19922  Total Reward:  2689721.1000000066
# price for reward: 5907.01
# Step:  19923  Total Reward:  2687518.380000007
# price for reward: 5903.19
# Step:  19924  Total Reward:  2685134.7000000062
# price for reward: 5902.0
# Step:  19925  Total Reward:  2684392.1400000066
# price for reward: 5899.45
# Step:  19926  Total Reward:  2682800.9400000065
# price for reward: 5901.52
# Step:  19927  Total Reward:  2684092.620000007
# price for reward: 5918.92
# Step:  19928  Total Reward:  2694950.2200000067
# price for reward: 5918.75
# Step:  19929  Total Reward:  2694844.1400000066
# price for reward: 5912.2
# Step:  19930  Total Reward:  2690756.9400000065
# price for reward: 5909.74
# Step:  19931  Total Reward:  2689221.9000000064
# price for reward: 5912.49
# Step:  19932  Total Reward:  2690937.9000000064
# price for reward: 5913.64
# Step:  19933  Total Reward:  2691655.500000007
# price for reward: 5921.3
# Step:  19934  Total Reward:  2696435.340000007
# price for reward: 5930.16
# Step:  19935  Total Reward:  2701963.9800000065
# price for reward: 5921.3
# Step:  19936  Total Reward:  2696435.340000007
# price for reward: 5922.95
# Step:  19937  Total Reward:  2697464.9400000065
# price for reward: 5923.53
# Step:  19938  Total Reward:  2697826.8600000064
# price for reward: 5927.95
# Step:  19939  Total Reward:  2700584.9400000065
# price for reward: 5924.03
# Step:  19940  Total Reward:  2698138.8600000064
# price for reward: 5918.42
# Step:  19941  Total Reward:  2694638.2200000067
# price for reward: 5911.29
# Step:  19942  Total Reward:  2690189.1000000066
# price for reward: 5916.99
# Step:  19943  Total Reward:  2693745.9000000064
# price for reward: 5921.65
# Step:  19944  Total Reward:  2696653.7400000063
# price for reward: 5928.4
# Step:  19945  Total Reward:  2700865.7400000063
# price for reward: 5933.51
# Step:  19946  Total Reward:  2704054.380000007
# price for reward: 5924.46
# Step:  19947  Total Reward:  2698407.1800000067
# price for reward: 5925.3
# Step:  19948  Total Reward:  2698931.340000007
# price for reward: 5923.5
# Step:  19949  Total Reward:  2697808.1400000066
# price for reward: 5922.49
# Step:  19950  Total Reward:  2697808.1400000066
# price for reward: 5918.69
# Step:  19951  Total Reward:  2697808.1400000066
# price for reward: 5920.19
# Step:  19952  Total Reward:  2697808.1400000066
# price for reward: 5920.19
# Step:  19953  Total Reward:  2697808.1400000066
# price for reward: 5922.28
# Step:  19954  Total Reward:  2697808.1400000066
# price for reward: 5923.1
# Step:  19955  Total Reward:  2697808.1400000066
# price for reward: 5921.36
# Step:  19956  Total Reward:  2697808.1400000066
# price for reward: 5919.0
# Step:  19957  Total Reward:  2697808.1400000066
# price for reward: 5916.88
# Step:  19958  Total Reward:  2697808.1400000066
# price for reward: 5915.37
# Step:  19959  Total Reward:  2697808.1400000066
# price for reward: 5914.95
# Step:  19960  Total Reward:  2697808.1400000066
# price for reward: 5914.42
# Step:  19961  Total Reward:  2697808.1400000066
# price for reward: 5916.23
# Step:  19962  Total Reward:  2697808.1400000066
# price for reward: 5916.0
# Step:  19963  Total Reward:  2697808.1400000066
# price for reward: 5919.41
# Step:  19964  Total Reward:  2697808.1400000066
# price for reward: 5917.83
# Step:  19965  Total Reward:  2697808.1400000066
# price for reward: 5899.68
# Step:  19966  Total Reward:  2686482.540000007
# price for reward: 5906.88
# Step:  19967  Total Reward:  2690975.340000007
# price for reward: 5904.0
# Step:  19968  Total Reward:  2689178.2200000067
# price for reward: 5906.68
# Step:  19969  Total Reward:  2690850.540000007
# price for reward: 5910.61
# Step:  19970  Total Reward:  2693302.8600000064
# price for reward: 5910.61
# Step:  19971  Total Reward:  2693302.8600000064
# price for reward: 5907.15
# Step:  19972  Total Reward:  2691143.8200000064
# price for reward: 5907.15
# Step:  19973  Total Reward:  2691143.8200000064
# price for reward: 5911.38
# Step:  19974  Total Reward:  2693783.340000007
# price for reward: 5905.27
# Step:  19975  Total Reward:  2689970.700000007
# price for reward: 5913.65
# Step:  19976  Total Reward:  2689970.700000007
# price for reward: 5908.29
# Step:  19977  Total Reward:  2689970.700000007
# price for reward: 5906.26
# Step:  19978  Total Reward:  2689970.700000007
# price for reward: 5908.62
# Step:  19979  Total Reward:  2689970.700000007
# price for reward: 5910.5
# Step:  19980  Total Reward:  2689970.700000007
# price for reward: 5916.18
# Step:  19981  Total Reward:  2693515.0200000075
# price for reward: 5918.92
# Step:  19982  Total Reward:  2695224.7800000072
# price for reward: 5915.14
# Step:  19983  Total Reward:  2692866.0600000075
# price for reward: 5908.71
# Step:  19984  Total Reward:  2688853.740000007
# price for reward: 5902.78
# Step:  19985  Total Reward:  2685153.420000007
# price for reward: 5894.2
# Step:  19986  Total Reward:  2679799.500000007
# price for reward: 5885.0
# Step:  19987  Total Reward:  2674058.700000007
# price for reward: 5882.47
# Step:  19988  Total Reward:  2672479.9800000074
# price for reward: 5882.7
# Step:  19989  Total Reward:  2672623.500000007
# Step:  19990  Total Reward:  2672623.500000007
# [-2848.680000000051, -907.1000000002095, -847.270000000135, -895.520000000135, -787.4400000000605, 1738.9299999998184, 1449.4299999998184, 2047.729999999865, 1904.9099999999162, 1638.5699999999488, 2393.199999999837, 2613.219999999972, 4780.60999999987, 4234.4199999999255, 3313.8099999999395, 4049.1399999998976, 5212.929999999818, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 3136.25, 2993.4299999998184, 5176.259999999893, 5506.289999999921, 2902.719999999972, 4332.849999999977, 2613.219999999972, 3335.039999999921, 2474.259999999893, 3800.1699999999255, 2561.1099999998696, 1491.8899999998976, 882.0099999998929, 1188.8799999998882, 457.4099999999162, 683.2199999999721, 658.1299999998882, 897.4499999999534, -1185.020000000135, -1076.9400000000605, -858.8499999999767, -858.8499999999767, -310.7300000000978, 600.229999999865, 1316.259999999893, 1331.6999999999534, 1599.969999999972, 2344.9499999999534, 2902.719999999972, 2611.289999999921, 2613.219999999972, 3250.1199999999953, 2611.289999999921, 1814.1999999999534, 1518.9099999999162, 1130.979999999865, 1341.3499999999767, 3914.039999999921, 6594.8099999999395, 6594.8099999999395, 5438.739999999874, 9684.739999999874, 8806.589999999967, 7075.379999999888, 6286.009999999893, 6774.299999999814, 5726.3099999999395, 4977.469999999972, 4927.289999999921, 6384.439999999944, 5321.009999999893, 7801.0599999999395, 7820.35999999987, 7058.009999999893, 7063.799999999814, 8146.530000000028, 5707.009999999893, 5707.009999999893, 6401.8099999999395, 4931.150000000023, 5579.629999999888, 5579.629999999888, 5587.349999999977, 7251.009999999893, 6552.349999999977, 6552.349999999977, 6552.349999999977, 7305.049999999814, 7349.439999999944, 6847.639999999898, 7222.0599999999395, 13733.879999999888, 14233.75, 12060.569999999949, 13948.10999999987, 12807.479999999865, 13957.759999999893, 15715.989999999874, 16225.509999999893, 14449.909999999916, 14588.869999999995, 17848.639999999898, 20156.919999999925, 17790.739999999874, 18184.459999999846, 17804.25, 18414.12999999989, 18485.53999999992, 16931.889999999898, 15221.909999999916, 14569.569999999949, 16613.439999999944, 15252.78999999992, 14843.629999999888, 15592.469999999972, 13430.869999999995, 16783.280000000028, 14527.10999999987, 14453.769999999902, 14915.03999999992, 13834.239999999874, 13836.169999999925, 13635.449999999953, 13197.339999999967, 13710.719999999972, 14901.530000000028, 15364.729999999865, 15947.589999999967, 14013.729999999865, 14015.659999999916, 14060.049999999814, 14042.679999999818, 10719.219999999972, 9792.819999999949, 8563.409999999916, 9700.179999999818, 10003.189999999944, 9987.75, 9989.679999999818, 10983.629999999888, 10339.009999999893, 10350.589999999967, 12463.939999999944, 12124.259999999893, 12763.089999999967, 12797.829999999842, 14021.449999999953, 14693.089999999967, 15382.099999999977, 13675.979999999865, 15318.409999999916, 15899.339999999967, 15235.419999999925, 15285.599999999977, 14309.019999999902, 14918.900000000023, 14307.089999999967, 14023.379999999888, 14143.03999999992, 14789.589999999967, 14253.049999999814, 15125.409999999916, 16694.5, 18506.769999999902, 19334.739999999874, 20413.60999999987, 20413.60999999987, 20413.60999999987, 20388.38999999978, 19045.9099999998, 19662.82999999984, 19660.88999999978, 20539.70999999973, 20287.509999999776, 19482.4099999998, 20729.82999999984, 18277.66999999981, 19201.10999999987, 20159.46999999974, 20159.46999999974, 20828.76999999967, 20828.76999999967, 23106.32999999984, 23694.14999999979, 25626.38999999978, 28070.78999999992, 28074.66999999981, 26668.16999999981, 26738.009999999776, 26194.809999999823, 25996.92999999982, 28423.86999999988, 28487.88999999978, 27199.72999999975, 28452.96999999974, 29859.46999999974, 28433 ...
# [tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([ ...

# %%
bitcoin = []
print(df_test['Close'].iloc[-1])
idx = -1
while True:
  bitcoin.append(1000000/df_test['Close'].iloc[-1]*df_test['Close'].iloc[idx] - 1000000)
  idx = idx -1
  if idx < -len(df_test['Close']):
    break
print(bitcoin)
plt.plot(bitcoin)
plt.show()
# Out:
# 5188.33
# [0.0, -1563.123394232709, -1834.8871409489075, -2426.599695855868, -1353.036526203854, -1775.137664720649, -2064.2480335675646, -2438.1641106096795, -2438.1641106096795, -5283.010140064289, -3344.0432663304964, -3284.293790102005, -3332.478851576452, -3224.5443138735136, -701.5744950687513, -990.6848639157834, -393.19010163191706, -535.8178835964063, -801.7994229356991, -48.18506147444714, 171.5388188493671, 2336.0117802838795, 1790.556884392514, 871.1859114591498, 1605.5262483303668, 2767.7499310952844, 2445.8737204457866, 2073.8850458626403, 1081.272779487772, 2058.4658261907753, 2058.4658261907753, 2058.4658261907753, 2077.739850780461, 1526.5027475121897, 1536.139759807149, 1709.6059811153682, 1241.2471835833276, 903.9517532617319, 560.8741155632306, -1023.4507057182491, -292.9651737648528, -2044.9740089777624, -2187.601790942368, -7.709609835874289, 321.87621064973064, -2278.1897065143567, -849.9844844101463, -2567.3000753613887, -1846.4515557028353, -2706.073052407941, -1381.9475630887318, -2619.3399417538894, -3687.1209040288813, -4296.180081066559, -3989.7230900886934, -4720.20862204209, -4494.70253434137, -4519.758766308194, -4280.760861394694, -6360.428114634124, -6252.493576931185, -6034.697099066456, -6034.697099066456, -5487.314800716238, -4577.5808400776, -3862.5145277959527, -3847.095308124204, -3579.1863663258264, -2835.20901715965, -2278.1897065143567, -2569.2274778203573, -2567.3000753613887, -1931.2572638979182, -2569.2274778203573, -3365.2446933791507, -3660.1372696030885, -4047.5451638581, -3837.458295829245, -1268.2308180088876, 1408.9311975145247, 1408.9311975145247, 254.41712458536495, 4494.702534341486, 3617.7344155056635, 1888.8544098004932, 1100.5468040776905, 1588.1796261995332, 541.6000909735449, -206.2320631108014, -256.3445270443335, 1198.8443294856697, 136.84557458758354, 2613.5577343771, 2632.831758966786, 1871.5077876696596, 1877.2899950465653, 2958.5627745344536, 522.3260663836263, 522.3260663836263, 1216.1909516165033, -252.48972212627996, 395.11750409100205, 395.11750409100205, 402.82711392687634, 2064.248033567681, 1366.5283434168668, 1366.5283434168668, 1366.5283434168668, 2118.215302419034, 2162.5455589756602, 1661.4209196408046, 2035.336996683036, 8538.392893281765, 9037.590130157536, 6867.334961346001, 8752.334566228441, 7613.239712971263, 8761.9715785234, 10517.83521865413, 11026.669467824977, 9253.459205563297, 9392.232182609965, 12647.614935827092, 14952.788276767242, 12589.792862057686, 12982.982963689603, 12603.284679270699, 13212.343856308376, 13283.657747290563, 11732.098767811665, 10024.420189155382, 9372.958158020047, 11414.077362079988, 10055.258628498996, 9646.649307195214, 10394.48146127956, 8235.790707221953, 11583.68877847027, 9330.555303922505, 9257.314010481234, 9717.963198177516, 8638.617821148597, 8640.545223607565, 8440.09536787367, 8002.575009685359, 8515.264063774026, 9704.471380964736, 10167.047971119871, 10749.123513731873, 8817.866249833838, 8819.793652292807, 8864.123908849317, 8846.777286718367, 5527.790252354927, 4602.637072044425, 3374.88170567411, 4510.121754013235, 4812.72394007328, 4797.304720401415, 4799.232122860267, 5791.844389235135, 5148.09196793579, 5159.656382689718, 7270.162075272878, 6930.9392424923135, 7568.909456414753, 7603.602700676303, 8825.575859669712, 9496.31191539485, 10184.394593250705, 8480.570819512242, 10120.790312104393, 10700.938452257426, 10037.912006368162, 10088.024470301694, 9112.75882605766, 9721.81800309557, 9110.831423598807, 8827.503262128681, 8947.002214585431, 9592.68203834386, 9056.864154747222, 9928.050066206371, 11495.028265357134, 13304.859174339334, 14131.71482924174, 15209.132803811575, 13925.48276613094, 11992.298099773936, 11967.241867807228, 10633.47936619306, 11246.393348148675, 11244.465945689706, 12117.579259607592, 11867.016939940164, 11067.14491946355, 12306.464700587792, 9870.227992436965, 10787.671562911477, 11739.80837764754, 11739.80837764754, 12404.762225995655, 12404.762225995655, 14667.53271283838, 15 ...

# %%
#save the trained model
import joblib
filename = '/content/drive/My Drive/finalized_model2.sav'
joblib.dump(q_net, filename)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)
# ['/content/drive/My Drive/finalized_model2.sav']

# %%
#load the trained model
loaded_model = joblib.load(filename)

#test the loaded model again
def run_episode_test_load():
  episode_reward_list = []
  global epsilon
  state = env_test.reset()
  episode_reward = 0
  action_list = []
  i = 0

  while True:
    """ Pseudocode:
        1. Input state into your network to get the predicted Q Values for each action
        2. Use "epsilon_greedy_action" to get your next action from your Q-Values
    """

    action_values = loaded_model(torch.Tensor([state]))
    
    action = epsilon_greedy_action(action_values, epsilon)
    action_list.append(action)
    # Decay the epsilon
    epsilon = max(epsilon * EPSILON_DECAY, EPSILON_END)
    
    # print(type(action.item()))
    # 3. Once you've done the first two steps, you can simulate tacking the action
    # "action" in the environment as follows. 

    # Return Values: 
    # next_state: (Tuple) Next state after having taken action "action"
    # reward    : (int)   Reward received for taking action "action"
    # done      : (bool)  Whether or not the simulation has reached an ending condition (see github repo linked earlier for more information)
    next_state, reward, done = env_test.step(action.item(), False)
    
    episode_reward += reward
    episode_reward_list.append(episode_reward)
    state = next_state
    print('Step: ', i ,' Total Reward: ', episode_reward)
    i += 1
    if done:
      return (action_list, episode_reward_list)
    """ Pseudocode (cont):
        4. Push this information to your ReplayBuffer
        5. Set your current state to the next state returned
        6. Call "learn" for a single batch
        7. Check if the simulation is done, and if so exit out of the function
           If the simulation is not done, then we loop and repeat steps 1-7
    """

env_test = testEnv(df_test, 10, 1000000)
observation = env_test.reset()
print(observation.shape)
print(env_test.action_space)
action_list, episode_reward_list_load = run_episode_test_load()
print(reward_list)
print(action_list)
plt.plot(episode_reward_list_load)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# price for reward: 6131.45
# Step:  17492  Total Reward:  2337579.0899999985
# price for reward: 6133.37
# Step:  17493  Total Reward:  2338623.5699999984
# price for reward: 6140.0
# Step:  17494  Total Reward:  2342230.2899999986
# price for reward: 6144.83
# Step:  17495  Total Reward:  2344857.8099999987
# price for reward: 6144.42
# Step:  17496  Total Reward:  2344634.7699999986
# price for reward: 6140.61
# Step:  17497  Total Reward:  2342562.1299999985
# price for reward: 6137.6
# Step:  17498  Total Reward:  2340924.689999999
# price for reward: 6136.46
# Step:  17499  Total Reward:  2340304.529999999
# price for reward: 6136.46
# Step:  17500  Total Reward:  2340304.529999999
# price for reward: 6138.41
# Step:  17501  Total Reward:  2341365.3299999987
# price for reward: 6138.41
# Step:  17502  Total Reward:  2341365.3299999987
# price for reward: 6144.43
# Step:  17503  Total Reward:  2344640.2099999986
# price for reward: 6144.21
# Step:  17504  Total Reward:  2344520.529999999
# price for reward: 6152.28
# Step:  17505  Total Reward:  2348910.6099999985
# price for reward: 6148.22
# Step:  17506  Total Reward:  2346701.969999999
# price for reward: 6149.46
# Step:  17507  Total Reward:  2347376.529999999
# price for reward: 6149.46
# Step:  17508  Total Reward:  2347376.529999999
# price for reward: 6163.56
# Step:  17509  Total Reward:  2355046.929999999
# price for reward: 6162.99
# Step:  17510  Total Reward:  2354736.8499999987
# price for reward: 6160.79
# Step:  17511  Total Reward:  2353540.0499999984
# price for reward: 6155.64
# Step:  17512  Total Reward:  2350738.449999999
# price for reward: 6155.64
# Step:  17513  Total Reward:  2350738.449999999
# price for reward: 6164.98
# Step:  17514  Total Reward:  2355819.4099999983
# price for reward: 6173.0
# Step:  17515  Total Reward:  2360182.2899999986
# price for reward: 6178.3
# Step:  17516  Total Reward:  2363065.489999999
# price for reward: 6178.3
# Step:  17517  Total Reward:  2363065.489999999
# price for reward: 6178.0
# Step:  17518  Total Reward:  2362902.2899999986
# price for reward: 6174.55
# Step:  17519  Total Reward:  2361025.489999999
# price for reward: 6178.44
# Step:  17520  Total Reward:  2363141.6499999985
# price for reward: 6180.0
# Step:  17521  Total Reward:  2363990.2899999986
# price for reward: 6170.0
# Step:  17522  Total Reward:  2358550.2899999986
# price for reward: 6175.34
# Step:  17523  Total Reward:  2361455.2499999986
# price for reward: 6173.06
# Step:  17524  Total Reward:  2360214.929999999
# price for reward: 6168.31
# Step:  17525  Total Reward:  2357630.929999999
# price for reward: 6168.31
# Step:  17526  Total Reward:  2357630.929999999
# price for reward: 6168.31
# Step:  17527  Total Reward:  2357630.929999999
# price for reward: 6168.31
# Step:  17528  Total Reward:  2357630.929999999
# price for reward: 6172.9
# Step:  17529  Total Reward:  2360127.8899999983
# price for reward: 6185.71
# Step:  17530  Total Reward:  2367096.529999999
# price for reward: 6185.5
# Step:  17531  Total Reward:  2366982.2899999986
# price for reward: 6187.39
# Step:  17532  Total Reward:  2368010.449999999
# price for reward: 6186.5
# Step:  17533  Total Reward:  2367526.2899999986
# price for reward: 6183.3
# Step:  17534  Total Reward:  2365785.489999999
# price for reward: 6181.19
# Step:  17535  Total Reward:  2364637.6499999985
# price for reward: 6181.48
# Step:  17536  Total Reward:  2364795.4099999983
# price for reward: 6180.36
# Step:  17537  Total Reward:  2364186.1299999985
# price for reward: 6185.57
# Step:  17538  Total Reward:  2367020.3699999987
# price for reward: 6189.28
# Step:  17539  Total Reward:  2369038.6099999985
# price for reward: 6193.14
# Step:  17540  Total Reward:  2371138.449999999
# price for reward: 6189.2
# Step:  17541  Total Reward:  2368995.0899999985
# price for reward: 6189.2
# Step:  17542  Total Reward:  2368995.0899999985
# price for reward: 6189.2
# Step:  17543  Total Reward:  2368995.0899999985
# price for reward: 6185.83
# Step:  17544  Total Reward:  2367161.8099999987
# price for reward: 6185.83
# Step:  17545  Total Reward:  2367161.8099999987
# price for reward: 6184.2
# Step:  17546  Total Reward:  2366275.0899999985
# price for reward: 6182.0
# Step:  17547  Total Reward:  2365078.2899999986
# price for reward: 6182.0
# Step:  17548  Total Reward:  2365078.2899999986
# price for reward: 6181.02
# Step:  17549  Total Reward:  2364545.169999999
# price for reward: 6181.02
# Step:  17550  Total Reward:  2364545.169999999
# price for reward: 6181.02
# Step:  17551  Total Reward:  2364545.169999999
# price for reward: 6183.53
# Step:  17552  Total Reward:  2365910.6099999985
# price for reward: 6188.7
# Step:  17553  Total Reward:  2368723.0899999985
# price for reward: 6187.53
# Step:  17554  Total Reward:  2368086.6099999985
# price for reward: 6201.0
# Step:  17555  Total Reward:  2375414.2899999986
# price for reward: 6195.83
# Step:  17556  Total Reward:  2372601.8099999987
# price for reward: 6197.75
# Step:  17557  Total Reward:  2372601.8099999987
# price for reward: 6196.0
# Step:  17558  Total Reward:  2372601.8099999987
# price for reward: 6194.47
# Step:  17559  Total Reward:  2372601.8099999987
# price for reward: 6194.47
# Step:  17560  Total Reward:  2372601.8099999987
# price for reward: 6194.47
# Step:  17561  Total Reward:  2372601.8099999987
# price for reward: 6194.47
# Step:  17562  Total Reward:  2372601.8099999987
# price for reward: 6186.99
# Step:  17563  Total Reward:  2368532.6899999985
# price for reward: 6186.99
# Step:  17564  Total Reward:  2368532.6899999985
# price for reward: 6191.78
# Step:  17565  Total Reward:  2371138.4499999983
# price for reward: 6189.11
# Step:  17566  Total Reward:  2369685.9699999983
# price for reward: 6188.49
# Step:  17567  Total Reward:  2369348.6899999985
# price for reward: 6190.09
# Step:  17568  Total Reward:  2370219.0899999985
# price for reward: 6190.09
# Step:  17569  Total Reward:  2370219.0899999985
# price for reward: 6187.5
# Step:  17570  Total Reward:  2368810.1299999985
# price for reward: 6194.04
# Step:  17571  Total Reward:  2372367.8899999983
# price for reward: 6194.04
# Step:  17572  Total Reward:  2372367.8899999983
# price for reward: 6194.04
# Step:  17573  Total Reward:  2372367.8899999983
# price for reward: 6193.5
# Step:  17574  Total Reward:  2372074.1299999985
# price for reward: 6197.6
# Step:  17575  Total Reward:  2374304.529999999
# price for reward: 6200.35
# Step:  17576  Total Reward:  2375800.529999999
# price for reward: 6200.35
# Step:  17577  Total Reward:  2375800.529999999
# price for reward: 6200.35
# Step:  17578  Total Reward:  2375800.529999999
# price for reward: 6200.35
# Step:  17579  Total Reward:  2375800.529999999
# price for reward: 6203.58
# Step:  17580  Total Reward:  2375800.529999999
# price for reward: 6201.54
# Step:  17581  Total Reward:  2375800.529999999
# price for reward: 6205.44
# Step:  17582  Total Reward:  2375800.529999999
# price for reward: 6205.44
# Step:  17583  Total Reward:  2375800.529999999
# price for reward: 6203.69
# Step:  17584  Total Reward:  2375800.529999999
# price for reward: 6200.7
# Step:  17585  Total Reward:  2375800.529999999
# price for reward: 6202.31
# Step:  17586  Total Reward:  2376676.369999999
# price for reward: 6200.4
# Step:  17587  Total Reward:  2375637.3299999987
# price for reward: 6202.16
# Step:  17588  Total Reward:  2376594.769999999
# price for reward: 6202.16
# Step:  17589  Total Reward:  2376594.769999999
# price for reward: 6199.96
# Step:  17590  Total Reward:  2375397.9699999993
# price for reward: 6191.69
# Step:  17591  Total Reward:  2370899.089999999
# price for reward: 6185.96
# Step:  17592  Total Reward:  2367781.9699999993
# price for reward: 6190.35
# Step:  17593  Total Reward:  2370170.1299999994
# price for reward: 6190.36
# Step:  17594  Total Reward:  2370175.569999999
# price for reward: 6189.61
# Step:  17595  Total Reward:  2369767.569999999
# price for reward: 6188.8
# Step:  17596  Total Reward:  2369326.9299999992
# price for reward: 6188.99
# Step:  17597  Total Reward:  2369430.289999999
# price for reward: 6188.99
# Step:  17598  Total Reward:  2369430.289999999
# price for reward: 6188.99
# Step:  17599  Total Reward:  2369430.289999999
# price for reward: 6195.71
# Step:  17600  Total Reward:  2373085.9699999993
# price for reward: 6245.22
# Step:  17601  Total Reward:  2400019.409999999
# price for reward: 6257.58
# Step:  17602  Total Reward:  2406743.249999999
# price for reward: 6247.19
# Step:  17603  Total Reward:  2401091.089999999
# price for reward: 6259.1
# Step:  17604  Total Reward:  2407570.1299999994
# price for reward: 6256.57
# Step:  17605  Total Reward:  2407570.1299999994
# price for reward: 6254.52
# Step:  17606  Total Reward:  2407570.1299999994
# price for reward: 6252.39
# Step:  17607  Total Reward:  2407570.1299999994
# price for reward: 6253.37
# Step:  17608  Total Reward:  2407570.1299999994
# price for reward: 6254.59
# Step:  17609  Total Reward:  2407570.1299999994
# price for reward: 6251.81
# Step:  17610  Total Reward:  2406057.8099999996
# price for reward: 6256.29
# Step:  17611  Total Reward:  2408494.9299999992
# price for reward: 6251.78
# Step:  17612  Total Reward:  2406041.4899999993
# price for reward: 6251.96
# Step:  17613  Total Reward:  2406139.4099999997
# price for reward: 6258.8
# Step:  17614  Total Reward:  2409860.3699999996
# price for reward: 6258.8
# Step:  17615  Total Reward:  2409860.3699999996
# price for reward: 6243.68
# Step:  17616  Total Reward:  2401635.0899999994
# price for reward: 6255.61
# Step:  17617  Total Reward:  2408125.0099999993
# price for reward: 6255.61
# Step:  17618  Total Reward:  2408125.0099999993
# price for reward: 6255.61
# Step:  17619  Total Reward:  2408125.0099999993
# price for reward: 6248.08
# Step:  17620  Total Reward:  2404028.6899999995
# price for reward: 6247.83
# Step:  17621  Total Reward:  2403892.6899999995
# price for reward: 6247.83
# Step:  17622  Total Reward:  2403892.6899999995
# price for reward: 6244.79
# Step:  17623  Total Reward:  2402238.9299999992
# price for reward: 6248.66
# Step:  17624  Total Reward:  2404344.2099999995
# price for reward: 6250.39
# Step:  17625  Total Reward:  2405285.3299999996
# price for reward: 6265.1
# Step:  17626  Total Reward:  2413287.57
# price for reward: 6259.99
# Step:  17627  Total Reward:  2410507.7299999995
# price for reward: 6261.03
# Step:  17628  Total Reward:  2411073.4899999993
# price for reward: 6262.77
# Step:  17629  Total Reward:  2412020.05
# price for reward: 6267.7
# Step:  17630  Total Reward:  2414701.9699999993
# price for reward: 6270.44
# Step:  17631  Total Reward:  2414701.9699999993
# price for reward: 6265.38
# Step:  17632  Total Reward:  2414701.9699999993
# price for reward: 6267.38
# Step:  17633  Total Reward:  2414701.9699999993
# price for reward: 6267.3
# Step:  17634  Total Reward:  2414701.9699999993
# price for reward: 6267.31
# Step:  17635  Total Reward:  2414701.9699999993
# price for reward: 6259.99
# Step:  17636  Total Reward:  2410719.889999999
# price for reward: 6258.28
# Step:  17637  Total Reward:  2409789.649999999
# price for reward: 6255.99
# Step:  17638  Total Reward:  2408543.889999999
# price for reward: 6261.82
# Step:  17639  Total Reward:  2411715.409999999
# price for reward: 6265.77
# Step:  17640  Total Reward:  2413864.2099999995
# price for reward: 6265.79
# Step:  17641  Total Reward:  2413875.089999999
# price for reward: 6265.79
# Step:  17642  Total Reward:  2413875.089999999
# price for reward: 6262.82
# Step:  17643  Total Reward:  2412259.409999999
# price for reward: 6251.2
# Step:  17644  Total Reward:  2405938.129999999
# price for reward: 6252.21
# Step:  17645  Total Reward:  2406487.5699999994
# price for reward: 6259.84
# Step:  17646  Total Reward:  2410638.289999999
# price for reward: 6264.47
# Step:  17647  Total Reward:  2413157.0099999993
# price for reward: 6273.29
# Step:  17648  Total Reward:  2417955.089999999
# price for reward: 6274.81
# Step:  17649  Total Reward:  2418781.9699999993
# price for reward: 6275.16
# Step:  17650  Total Reward:  2418972.369999999
# price for reward: 6271.89
# Step:  17651  Total Reward:  2417193.4899999993
# price for reward: 6269.21
# Step:  17652  Total Reward:  2415735.5699999994
# price for reward: 6274.0
# Step:  17653  Total Reward:  2418341.329999999
# price for reward: 6274.0
# Step:  17654  Total Reward:  2418341.329999999
# price for reward: 6274.0
# Step:  17655  Total Reward:  2418341.329999999
# price for reward: 6285.0
# Step:  17656  Total Reward:  2424325.329999999
# price for reward: 6292.46
# Step:  17657  Total Reward:  2428383.5699999994
# price for reward: 6299.18
# Step:  17658  Total Reward:  2432039.249999999
# price for reward: 6294.58
# Step:  17659  Total Reward:  2429536.849999999
# price for reward: 6298.0
# Step:  17660  Total Reward:  2429536.849999999
# price for reward: 6292.43
# Step:  17661  Total Reward:  2429536.849999999
# price for reward: 6292.43
# Step:  17662  Total Reward:  2429536.849999999
# price for reward: 6294.71
# Step:  17663  Total Reward:  2429536.849999999
# price for reward: 6294.71
# Step:  17664  Total Reward:  2429536.849999999
# price for reward: 6286.65
# Step:  17665  Total Reward:  2429536.849999999
# price for reward: 6290.08
# Step:  17666  Total Reward:  2431406.1999999993
# price for reward: 6285.55
# Step:  17667  Total Reward:  2428937.349999999
# price for reward: 6283.96
# Step:  17668  Total Reward:  2428070.7999999993
# price for reward: 6282.95
# Step:  17669  Total Reward:  2427520.349999999
# price for reward: 6282.53
# Step:  17670  Total Reward:  2427291.4499999993
# price for reward: 6281.51
# Step:  17671  Total Reward:  2426735.5499999993
# price for reward: 6279.77
# Step:  17672  Total Reward:  2425787.2499999995
# price for reward: 6276.7
# Step:  17673  Total Reward:  2424114.099999999
# price for reward: 6276.7
# Step:  17674  Total Reward:  2424114.099999999
# price for reward: 6279.25
# Step:  17675  Total Reward:  2425503.849999999
# price for reward: 6273.83
# Step:  17676  Total Reward:  2422549.9499999993
# price for reward: 6269.01
# Step:  17677  Total Reward:  2419923.0499999993
# price for reward: 6263.76
# Step:  17678  Total Reward:  2417061.7999999993
# price for reward: 6275.33
# Step:  17679  Total Reward:  2423367.4499999993
# price for reward: 6281.32
# Step:  17680  Total Reward:  2426631.999999999
# price for reward: 6275.29
# Step:  17681  Total Reward:  2423345.649999999
# price for reward: 6273.26
# Step:  17682  Total Reward:  2422239.2999999993
# price for reward: 6273.29
# Step:  17683  Total Reward:  2422255.649999999
# price for reward: 6286.12
# Step:  17684  Total Reward:  2429247.999999999
# price for reward: 6278.92
# Step:  17685  Total Reward:  2429247.999999999
# price for reward: 6282.91
# Step:  17686  Total Reward:  2429247.999999999
# price for reward: 6278.88
# Step:  17687  Total Reward:  2429247.999999999
# price for reward: 6278.89
# Step:  17688  Total Reward:  2429247.999999999
# price for reward: 6277.31
# Step:  17689  Total Reward:  2429247.999999999
# price for reward: 6278.91
# Step:  17690  Total Reward:  2429247.999999999
# price for reward: 6279.51
# Step:  17691  Total Reward:  2429247.999999999
# price for reward: 6282.62
# Step:  17692  Total Reward:  2429247.999999999
# price for reward: 6279.62
# Step:  17693  Total Reward:  2429247.999999999
# price for reward: 6265.82
# Step:  17694  Total Reward:  2421713.199999999
# price for reward: 6265.82
# Step:  17695  Total Reward:  2421713.199999999
# price for reward: 6270.61
# Step:  17696  Total Reward:  2424328.5399999986
# price for reward: 6270.61
# Step:  17697  Total Reward:  2424328.5399999986
# price for reward: 6253.54
# Step:  17698  Total Reward:  2415008.319999999
# price for reward: 6263.83
# Step:  17699  Total Reward:  2420626.659999999
# price for reward: 6263.83
# Step:  17700  Total Reward:  2420626.659999999
# price for reward: 6263.83
# Step:  17701  Total Reward:  2420626.659999999
# price for reward: 6263.83
# Step:  17702  Total Reward:  2420626.659999999
# price for reward: 6263.83
# Step:  17703  Total Reward:  2420626.659999999
# price for reward: 6272.87
# Step:  17704  Total Reward:  2425562.499999999
# price for reward: 6273.76
# Step:  17705  Total Reward:  2426048.439999999
# price for reward: 6276.72
# Step:  17706  Total Reward:  2427664.599999999
# price for reward: 6276.72
# Step:  17707  Total Reward:  2427664.599999999
# price for reward: 6268.24
# Step:  17708  Total Reward:  2423034.519999999
# price for reward: 6270.96
# Step:  17709  Total Reward:  2424519.639999999
# price for reward: 6277.77
# Step:  17710  Total Reward:  2428237.8999999994
# price for reward: 6277.49
# Step:  17711  Total Reward:  2428085.019999999
# price for reward: 6281.21
# Step:  17712  Total Reward:  2428085.019999999
# price for reward: 6275.86
# Step:  17713  Total Reward:  2428085.019999999
# price for reward: 6285.17
# Step:  17714  Total Reward:  2428085.019999999
# price for reward: 6288.12
# Step:  17715  Total Reward:  2428085.019999999
# price for reward: 6288.11
# Step:  17716  Total Reward:  2428085.019999999
# price for reward: 6288.11
# Step:  17717  Total Reward:  2428085.019999999
# price for reward: 6283.06
# Step:  17718  Total Reward:  2428085.019999999
# price for reward: 6285.55
# Step:  17719  Total Reward:  2428085.019999999
# price for reward: 6284.74
# Step:  17720  Total Reward:  2428085.019999999
# price for reward: 6270.69
# Step:  17721  Total Reward:  2420427.769999999
# price for reward: 6257.23
# Step:  17722  Total Reward:  2413092.069999999
# price for reward: 6239.45
# Step:  17723  Total Reward:  2403401.9699999993
# price for reward: 6239.29
# Step:  17724  Total Reward:  2403314.769999999
# price for reward: 6248.09
# Step:  17725  Total Reward:  2408110.7699999996
# price for reward: 6250.71
# Step:  17726  Total Reward:  2409538.6699999995
# price for reward: 6256.54
# Step:  17727  Total Reward:  2412716.019999999
# price for reward: 6250.29
# Step:  17728  Total Reward:  2409309.769999999
# price for reward: 6249.25
# Step:  17729  Total Reward:  2408742.9699999993
# price for reward: 6250.81
# Step:  17730  Total Reward:  2409593.1699999995
# price for reward: 6244.7
# Step:  17731  Total Reward:  2406263.2199999993
# price for reward: 6249.27
# Step:  17732  Total Reward:  2408753.8699999996
# price for reward: 6250.71
# Step:  17733  Total Reward:  2409538.6699999995
# price for reward: 6253.62
# Step:  17734  Total Reward:  2411124.619999999
# price for reward: 6247.44
# Step:  17735  Total Reward:  2407756.519999999
# price for reward: 6250.32
# Step:  17736  Total Reward:  2409326.119999999
# price for reward: 6258.26
# Step:  17737  Total Reward:  2413653.4199999995
# price for reward: 6262.13
# Step:  17738  Total Reward:  2415762.5699999994
# price for reward: 6264.72
# Step:  17739  Total Reward:  2417174.119999999
# price for reward: 6266.43
# Step:  17740  Total Reward:  2418106.0699999994
# price for reward: 6266.43
# Step:  17741  Total Reward:  2418106.0699999994
# price for reward: 6267.72
# Step:  17742  Total Reward:  2418809.119999999
# price for reward: 6260.89
# Step:  17743  Total Reward:  2415086.7699999996
# price for reward: 6249.07
# Step:  17744  Total Reward:  2408644.869999999
# price for reward: 6256.97
# Step:  17745  Total Reward:  2412950.369999999
# price for reward: 6263.7
# Step:  17746  Total Reward:  2416618.2199999993
# price for reward: 6260.68
# Step:  17747  Total Reward:  2414972.3199999994
# price for reward: 6257.51
# Step:  17748  Total Reward:  2413244.6699999995
# price for reward: 6256.27
# Step:  17749  Total Reward:  2412568.8699999996
# price for reward: 6262.98
# Step:  17750  Total Reward:  2416225.819999999
# price for reward: 6262.98
# Step:  17751  Total Reward:  2416225.819999999
# price for reward: 6254.3
# Step:  17752  Total Reward:  2411495.2199999993
# price for reward: 6251.58
# Step:  17753  Total Reward:  2410012.8199999994
# price for reward: 6257.41
# Step:  17754  Total Reward:  2413190.169999999
# price for reward: 6257.41
# Step:  17755  Total Reward:  2413190.169999999
# price for reward: 6255.1
# Step:  17756  Total Reward:  2411931.2199999993
# price for reward: 6253.79
# Step:  17757  Total Reward:  2411217.269999999
# price for reward: 6258.13
# Step:  17758  Total Reward:  2413582.5699999994
# price for reward: 6282.47
# Step:  17759  Total Reward:  2426847.869999999
# price for reward: 6276.91
# Step:  17760  Total Reward:  2423817.669999999
# price for reward: 6279.12
# Step:  17761  Total Reward:  2425022.119999999
# price for reward: 6274.97
# Step:  17762  Total Reward:  2422760.369999999
# price for reward: 6272.55
# Step:  17763  Total Reward:  2421441.4699999993
# price for reward: 6280.86
# Step:  17764  Total Reward:  2425970.419999999
# price for reward: 6277.86
# Step:  17765  Total Reward:  2424335.419999999
# price for reward: 6277.86
# Step:  17766  Total Reward:  2424335.419999999
# price for reward: 6277.87
# Step:  17767  Total Reward:  2424340.869999999
# price for reward: 6277.87
# Step:  17768  Total Reward:  2424340.869999999
# price for reward: 6277.55
# Step:  17769  Total Reward:  2424166.4699999993
# price for reward: 6302.2
# Step:  17770  Total Reward:  2437600.7199999993
# price for reward: 6334.28
# Step:  17771  Total Reward:  2455084.3199999994
# price for reward: 6326.31
# Step:  17772  Total Reward:  2450740.6699999995
# price for reward: 6307.44
# Step:  17773  Total Reward:  2440456.519999999
# price for reward: 6316.26
# Step:  17774  Total Reward:  2440456.519999999
# price for reward: 6309.88
# Step:  17775  Total Reward:  2440456.519999999
# price for reward: 6307.01
# Step:  17776  Total Reward:  2440456.519999999
# price for reward: 6304.73
# Step:  17777  Total Reward:  2440456.519999999
# price for reward: 6302.2
# Step:  17778  Total Reward:  2440456.519999999
# price for reward: 6299.18
# Step:  17779  Total Reward:  2440456.519999999
# price for reward: 6303.95
# Step:  17780  Total Reward:  2443060.9399999985
# price for reward: 6302.24
# Step:  17781  Total Reward:  2442127.279999999
# price for reward: 6292.05
# Step:  17782  Total Reward:  2436563.539999999
# price for reward: 6299.26
# Step:  17783  Total Reward:  2440500.199999999
# price for reward: 6297.99
# Step:  17784  Total Reward:  2439806.779999999
# price for reward: 6292.05
# Step:  17785  Total Reward:  2436563.539999999
# price for reward: 6291.81
# Step:  17786  Total Reward:  2436432.499999999
# price for reward: 6282.93
# Step:  17787  Total Reward:  2431584.019999999
# price for reward: 6290.31
# Step:  17788  Total Reward:  2435613.499999999
# price for reward: 6290.31
# Step:  17789  Total Reward:  2435613.499999999
# price for reward: 6290.31
# Step:  17790  Total Reward:  2435613.499999999
# price for reward: 6285.36
# Step:  17791  Total Reward:  2432910.7999999984
# price for reward: 6290.09
# Step:  17792  Total Reward:  2435493.379999999
# price for reward: 6290.79
# Step:  17793  Total Reward:  2435875.5799999987
# price for reward: 6293.08
# Step:  17794  Total Reward:  2437125.919999999
# price for reward: 6282.79
# Step:  17795  Total Reward:  2431507.5799999987
# price for reward: 6288.98
# Step:  17796  Total Reward:  2434887.3199999984
# price for reward: 6287.98
# Step:  17797  Total Reward:  2434341.3199999984
# price for reward: 6280.46
# Step:  17798  Total Reward:  2430235.399999999
# price for reward: 6286.58
# Step:  17799  Total Reward:  2433576.919999999
# price for reward: 6286.12
# Step:  17800  Total Reward:  2433325.759999999
# price for reward: 6286.12
# Step:  17801  Total Reward:  2433325.759999999
# price for reward: 6282.99
# Step:  17802  Total Reward:  2431616.779999999
# price for reward: 6267.62
# Step:  17803  Total Reward:  2423224.759999999
# price for reward: 6260.09
# Step:  17804  Total Reward:  2419113.379999999
# price for reward: 6253.29
# Step:  17805  Total Reward:  2415400.5799999987
# price for reward: 6245.03
# Step:  17806  Total Reward:  2410890.6199999987
# price for reward: 6264.05
# Step:  17807  Total Reward:  2421275.539999999
# price for reward: 6264.05
# Step:  17808  Total Reward:  2421275.539999999
# price for reward: 6264.32
# Step:  17809  Total Reward:  2421422.9599999986
# price for reward: 6268.1
# Step:  17810  Total Reward:  2423486.839999999
# price for reward: 6268.87
# Step:  17811  Total Reward:  2423907.259999999
# price for reward: 6270.54
# Step:  17812  Total Reward:  2424819.0799999987
# price for reward: 6270.54
# Step:  17813  Total Reward:  2424819.0799999987
# price for reward: 6252.97
# Step:  17814  Total Reward:  2424819.0799999987
# price for reward: 6252.71
# Step:  17815  Total Reward:  2424819.0799999987
# price for reward: 6249.46
# Step:  17816  Total Reward:  2424819.0799999987
# price for reward: 6252.68
# Step:  17817  Total Reward:  2426583.6399999987
# price for reward: 6252.68
# Step:  17818  Total Reward:  2426583.6399999987
# price for reward: 6250.75
# Step:  17819  Total Reward:  2425525.9999999986
# price for reward: 6250.75
# Step:  17820  Total Reward:  2425525.9999999986
# price for reward: 6251.65
# Step:  17821  Total Reward:  2426019.1999999983
# price for reward: 6250.71
# Step:  17822  Total Reward:  2425504.0799999987
# price for reward: 6260.43
# Step:  17823  Total Reward:  2430830.6399999987
# price for reward: 6259.78
# Step:  17824  Total Reward:  2430474.4399999985
# price for reward: 6252.25
# Step:  17825  Total Reward:  2426347.9999999986
# price for reward: 6252.25
# Step:  17826  Total Reward:  2426347.9999999986
# price for reward: 6257.49
# Step:  17827  Total Reward:  2426347.9999999986
# price for reward: 6251.21
# Step:  17828  Total Reward:  2426347.9999999986
# price for reward: 6246.26
# Step:  17829  Total Reward:  2426347.9999999986
# price for reward: 6240.04
# Step:  17830  Total Reward:  2422939.4399999985
# price for reward: 6238.59
# Step:  17831  Total Reward:  2422144.839999999
# price for reward: 6236.93
# Step:  17832  Total Reward:  2421235.1599999988
# price for reward: 6232.46
# Step:  17833  Total Reward:  2418785.5999999987
# price for reward: 6234.17
# Step:  17834  Total Reward:  2419722.679999999
# price for reward: 6231.78
# Step:  17835  Total Reward:  2418412.9599999986
# price for reward: 6235.69
# Step:  17836  Total Reward:  2420555.6399999983
# price for reward: 6238.58
# Step:  17837  Total Reward:  2422139.3599999985
# price for reward: 6243.51
# Step:  17838  Total Reward:  2424840.9999999986
# price for reward: 6238.27
# Step:  17839  Total Reward:  2421969.479999999
# price for reward: 6237.0
# Step:  17840  Total Reward:  2421273.5199999986
# price for reward: 6243.99
# Step:  17841  Total Reward:  2425104.0399999986
# price for reward: 6241.91
# Step:  17842  Total Reward:  2425104.0399999986
# price for reward: 6244.8
# Step:  17843  Total Reward:  2425104.0399999986
# price for reward: 6246.5
# Step:  17844  Total Reward:  2425104.0399999986
# price for reward: 6240.91
# Step:  17845  Total Reward:  2425104.0399999986
# price for reward: 6242.32
# Step:  17846  Total Reward:  2425876.719999999
# price for reward: 6241.84
# Step:  17847  Total Reward:  2425613.6799999992
# price for reward: 6239.61
# Step:  17848  Total Reward:  2424391.6399999987
# price for reward: 6241.84
# Step:  17849  Total Reward:  2425613.6799999992
# price for reward: 6241.84
# Step:  17850  Total Reward:  2425613.6799999992
# price for reward: 6244.5
# Step:  17851  Total Reward:  2427071.359999999
# price for reward: 6244.91
# Step:  17852  Total Reward:  2427296.0399999986
# price for reward: 6247.01
# Step:  17853  Total Reward:  2428446.839999999
# price for reward: 6255.17
# Step:  17854  Total Reward:  2432918.519999999
# price for reward: 6253.89
# Step:  17855  Total Reward:  2432217.079999999
# price for reward: 6257.01
# Step:  17856  Total Reward:  2433926.839999999
# price for reward: 6252.97
# Step:  17857  Total Reward:  2431712.919999999
# price for reward: 6255.05
# Step:  17858  Total Reward:  2432852.759999999
# price for reward: 6252.92
# Step:  17859  Total Reward:  2431685.519999999
# price for reward: 6254.68
# Step:  17860  Total Reward:  2432649.999999999
# price for reward: 6254.68
# Step:  17861  Total Reward:  2432649.999999999
# price for reward: 6251.9
# Step:  17862  Total Reward:  2431126.5599999987
# price for reward: 6262.59
# Step:  17863  Total Reward:  2436984.6799999992
# price for reward: 6266.44
# Step:  17864  Total Reward:  2439094.4799999986
# price for reward: 6267.59
# Step:  17865  Total Reward:  2439724.6799999992
# price for reward: 6267.59
# Step:  17866  Total Reward:  2439724.6799999992
# price for reward: 6260.91
# Step:  17867  Total Reward:  2439724.6799999992
# price for reward: 6258.18
# Step:  17868  Total Reward:  2439724.6799999992
# price for reward: 6258.18
# Step:  17869  Total Reward:  2439724.6799999992
# price for reward: 6254.89
# Step:  17870  Total Reward:  2437918.4699999993
# price for reward: 6254.89
# Step:  17871  Total Reward:  2437918.4699999993
# price for reward: 6254.89
# Step:  17872  Total Reward:  2437918.4699999993
# price for reward: 6250.89
# Step:  17873  Total Reward:  2435722.4699999993
# price for reward: 6250.89
# Step:  17874  Total Reward:  2435722.4699999993
# price for reward: 6252.24
# Step:  17875  Total Reward:  2436463.6199999987
# price for reward: 6250.17
# Step:  17876  Total Reward:  2435327.189999999
# price for reward: 6254.19
# Step:  17877  Total Reward:  2437534.1699999985
# price for reward: 6255.86
# Step:  17878  Total Reward:  2438450.9999999986
# price for reward: 6251.08
# Step:  17879  Total Reward:  2435826.779999999
# price for reward: 6249.26
# Step:  17880  Total Reward:  2434827.599999999
# price for reward: 6263.61
# Step:  17881  Total Reward:  2442705.7499999986
# price for reward: 6258.81
# Step:  17882  Total Reward:  2440070.5499999993
# price for reward: 6261.01
# Step:  17883  Total Reward:  2440070.5499999993
# price for reward: 6258.83
# Step:  17884  Total Reward:  2440070.5499999993
# price for reward: 6258.81
# Step:  17885  Total Reward:  2440070.5499999993
# price for reward: 6251.46
# Step:  17886  Total Reward:  2440070.5499999993
# price for reward: 6254.8
# Step:  17887  Total Reward:  2441907.5499999993
# price for reward: 6252.29
# Step:  17888  Total Reward:  2440527.0499999993
# price for reward: 6251.09
# Step:  17889  Total Reward:  2439867.0499999993
# price for reward: 6254.7
# Step:  17890  Total Reward:  2441852.5499999993
# price for reward: 6254.1
# Step:  17891  Total Reward:  2441522.5499999993
# price for reward: 6254.0
# Step:  17892  Total Reward:  2441467.5499999993
# price for reward: 6258.33
# Step:  17893  Total Reward:  2443849.0499999993
# price for reward: 6258.23
# Step:  17894  Total Reward:  2443794.049999999
# price for reward: 6258.23
# Step:  17895  Total Reward:  2443794.049999999
# price for reward: 6258.19
# Step:  17896  Total Reward:  2443772.0499999993
# price for reward: 6258.19
# Step:  17897  Total Reward:  2443772.0499999993
# price for reward: 6258.19
# Step:  17898  Total Reward:  2443772.0499999993
# price for reward: 6258.19
# Step:  17899  Total Reward:  2443772.0499999993
# price for reward: 6260.19
# Step:  17900  Total Reward:  2443772.0499999993
# price for reward: 6255.78
# Step:  17901  Total Reward:  2443772.0499999993
# price for reward: 6251.39
# Step:  17902  Total Reward:  2443772.0499999993
# price for reward: 6242.98
# Step:  17903  Total Reward:  2443772.0499999993
# price for reward: 6242.98
# Step:  17904  Total Reward:  2443772.0499999993
# price for reward: 6239.99
# Step:  17905  Total Reward:  2443772.0499999993
# price for reward: 6240.41
# Step:  17906  Total Reward:  2443772.0499999993
# price for reward: 6240.41
# Step:  17907  Total Reward:  2443772.0499999993
# price for reward: 6234.81
# Step:  17908  Total Reward:  2440686.4499999993
# price for reward: 6235.98
# Step:  17909  Total Reward:  2441331.119999999
# price for reward: 6229.93
# Step:  17910  Total Reward:  2437997.5699999994
# price for reward: 6195.76
# Step:  17911  Total Reward:  2419169.8999999994
# price for reward: 6205.98
# Step:  17912  Total Reward:  2424801.119999999
# price for reward: 6209.32
# Step:  17913  Total Reward:  2426641.459999999
# price for reward: 6199.48
# Step:  17914  Total Reward:  2421219.619999999
# price for reward: 6204.21
# Step:  17915  Total Reward:  2423825.849999999
# price for reward: 6200.38
# Step:  17916  Total Reward:  2421715.519999999
# price for reward: 6204.21
# Step:  17917  Total Reward:  2423825.849999999
# price for reward: 6223.16
# Step:  17918  Total Reward:  2434267.2999999993
# price for reward: 6223.0
# Step:  17919  Total Reward:  2434179.139999999
# price for reward: 6234.4
# Step:  17920  Total Reward:  2440460.539999999
# price for reward: 6223.24
# Step:  17921  Total Reward:  2434311.379999999
# price for reward: 6231.13
# Step:  17922  Total Reward:  2438658.769999999
# price for reward: 6228.9
# Step:  17923  Total Reward:  2438658.769999999
# price for reward: 6228.9
# Step:  17924  Total Reward:  2438658.769999999
# price for reward: 6235.39
# Step:  17925  Total Reward:  2438658.769999999
# price for reward: 6233.07
# Step:  17926  Total Reward:  2438658.769999999
# price for reward: 6230.69
# Step:  17927  Total Reward:  2438658.769999999
# price for reward: 6232.14
# Step:  17928  Total Reward:  2439457.7199999993
# price for reward: 6227.96
# Step:  17929  Total Reward:  2437154.539999999
# price for reward: 6223.85
# Step:  17930  Total Reward:  2434889.9299999992
# price for reward: 6233.1
# Step:  17931  Total Reward:  2439986.6799999992
# price for reward: 6233.1
# Step:  17932  Total Reward:  2439986.6799999992
# price for reward: 6227.29
# Step:  17933  Total Reward:  2436785.369999999
# price for reward: 6227.29
# Step:  17934  Total Reward:  2436785.369999999
# price for reward: 6239.88
# Step:  17935  Total Reward:  2436785.369999999
# price for reward: 6244.24
# Step:  17936  Total Reward:  2439183.369999999
# price for reward: 6243.66
# Step:  17937  Total Reward:  2438864.369999999
# price for reward: 6243.66
# Step:  17938  Total Reward:  2438864.369999999
# price for reward: 6241.15
# Step:  17939  Total Reward:  2437483.869999999
# price for reward: 6237.16
# Step:  17940  Total Reward:  2435289.369999999
# price for reward: 6239.63
# Step:  17941  Total Reward:  2436647.869999999
# price for reward: 6237.17
# Step:  17942  Total Reward:  2435294.869999999
# price for reward: 6226.49
# Step:  17943  Total Reward:  2429420.869999999
# price for reward: 6236.88
# Step:  17944  Total Reward:  2435135.369999999
# price for reward: 6239.69
# Step:  17945  Total Reward:  2436680.869999999
# price for reward: 6237.19
# Step:  17946  Total Reward:  2435305.869999999
# price for reward: 6239.15
# Step:  17947  Total Reward:  2436383.869999999
# price for reward: 6242.01
# Step:  17948  Total Reward:  2437956.869999999
# price for reward: 6242.01
# Step:  17949  Total Reward:  2437956.869999999
# price for reward: 6250.0
# Step:  17950  Total Reward:  2442351.369999999
# price for reward: 6255.05
# Step:  17951  Total Reward:  2445128.869999999
# price for reward: 6246.74
# Step:  17952  Total Reward:  2440558.369999999
# price for reward: 6258.8
# Step:  17953  Total Reward:  2447191.369999999
# price for reward: 6259.47
# Step:  17954  Total Reward:  2447559.869999999
# price for reward: 6259.47
# Step:  17955  Total Reward:  2447559.869999999
# price for reward: 6259.47
# Step:  17956  Total Reward:  2447559.869999999
# price for reward: 6257.01
# Step:  17957  Total Reward:  2447559.869999999
# price for reward: 6254.73
# Step:  17958  Total Reward:  2447559.869999999
# price for reward: 6259.97
# Step:  17959  Total Reward:  2450447.1099999994
# price for reward: 6259.97
# Step:  17960  Total Reward:  2450447.1099999994
# price for reward: 6253.24
# Step:  17961  Total Reward:  2446738.879999999
# price for reward: 6243.7
# Step:  17962  Total Reward:  2441482.339999999
# price for reward: 6243.01
# Step:  17963  Total Reward:  2441102.1499999994
# price for reward: 6247.73
# Step:  17964  Total Reward:  2443702.869999999
# price for reward: 6250.84
# Step:  17965  Total Reward:  2445416.479999999
# price for reward: 6245.51
# Step:  17966  Total Reward:  2442479.6499999994
# price for reward: 6247.07
# Step:  17967  Total Reward:  2443339.209999999
# price for reward: 6247.05
# Step:  17968  Total Reward:  2443328.1899999995
# price for reward: 6246.22
# Step:  17969  Total Reward:  2442870.8599999994
# price for reward: 6251.55
# Step:  17970  Total Reward:  2445807.6899999995
# price for reward: 6249.45
# Step:  17971  Total Reward:  2444650.589999999
# price for reward: 6247.64
# Step:  17972  Total Reward:  2443653.2799999993
# price for reward: 6253.07
# Step:  17973  Total Reward:  2446645.209999999
# price for reward: 6256.39
# Step:  17974  Total Reward:  2448474.5299999993
# price for reward: 6260.19
# Step:  17975  Total Reward:  2450568.329999999
# price for reward: 6260.19
# Step:  17976  Total Reward:  2450568.329999999
# price for reward: 6261.39
# Step:  17977  Total Reward:  2450568.329999999
# price for reward: 6264.17
# Step:  17978  Total Reward:  2450568.329999999
# price for reward: 6260.0
# Step:  17979  Total Reward:  2450568.329999999
# price for reward: 6262.87
# Step:  17980  Total Reward:  2450568.329999999
# price for reward: 6263.24
# Step:  17981  Total Reward:  2450568.329999999
# price for reward: 6261.13
# Step:  17982  Total Reward:  2450568.329999999
# price for reward: 6258.29
# Step:  17983  Total Reward:  2450568.329999999
# price for reward: 6258.11
# Step:  17984  Total Reward:  2450568.329999999
# price for reward: 6258.11
# Step:  17985  Total Reward:  2450568.329999999
# price for reward: 6249.99
# Step:  17986  Total Reward:  2446094.209999999
# price for reward: 6253.05
# Step:  17987  Total Reward:  2447780.2699999996
# price for reward: 6252.23
# Step:  17988  Total Reward:  2447328.4499999993
# price for reward: 6256.27
# Step:  17989  Total Reward:  2449554.4899999993
# price for reward: 6256.27
# Step:  17990  Total Reward:  2449554.4899999993
# price for reward: 6251.38
# Step:  17991  Total Reward:  2446860.099999999
# price for reward: 6239.53
# Step:  17992  Total Reward:  2440330.749999999
# price for reward: 6240.81
# Step:  17993  Total Reward:  2441036.0299999993
# price for reward: 6238.61
# Step:  17994  Total Reward:  2439823.829999999
# price for reward: 6238.61
# Step:  17995  Total Reward:  2439823.829999999
# price for reward: 6245.94
# Step:  17996  Total Reward:  2443862.659999999
# price for reward: 6247.53
# Step:  17997  Total Reward:  2444738.749999999
# price for reward: 6247.46
# Step:  17998  Total Reward:  2444700.1799999992
# price for reward: 6251.38
# Step:  17999  Total Reward:  2446860.099999999
# price for reward: 6249.29
# Step:  18000  Total Reward:  2445708.5099999993
# price for reward: 6252.93
# Step:  18001  Total Reward:  2447714.1499999994
# price for reward: 6252.93
# Step:  18002  Total Reward:  2447714.1499999994
# price for reward: 6248.61
# Step:  18003  Total Reward:  2445333.829999999
# price for reward: 6250.5
# Step:  18004  Total Reward:  2446375.2199999993
# price for reward: 6252.17
# Step:  18005  Total Reward:  2447295.389999999
# price for reward: 6252.17
# Step:  18006  Total Reward:  2447295.389999999
# price for reward: 6259.16
# Step:  18007  Total Reward:  2451146.8799999994
# price for reward: 6258.4
# Step:  18008  Total Reward:  2450728.119999999
# price for reward: 6257.87
# Step:  18009  Total Reward:  2450436.0899999994
# price for reward: 6261.18
# Step:  18010  Total Reward:  2452259.8999999994
# price for reward: 6258.11
# Step:  18011  Total Reward:  2450568.329999999
# price for reward: 6262.3
# Step:  18012  Total Reward:  2452877.0199999996
# price for reward: 6259.82
# Step:  18013  Total Reward:  2452877.0199999996
# price for reward: 6259.79
# Step:  18014  Total Reward:  2452877.0199999996
# price for reward: 6258.52
# Step:  18015  Total Reward:  2452877.0199999996
# price for reward: 6259.72
# Step:  18016  Total Reward:  2453538.2199999997
# price for reward: 6261.06
# Step:  18017  Total Reward:  2454276.5599999996
# price for reward: 6258.48
# Step:  18018  Total Reward:  2452854.9799999995
# price for reward: 6257.92
# Step:  18019  Total Reward:  2452546.4199999995
# price for reward: 6257.92
# Step:  18020  Total Reward:  2452546.4199999995
# price for reward: 6257.36
# Step:  18021  Total Reward:  2452237.8599999994
# price for reward: 6270.44
# Step:  18022  Total Reward:  2459444.9399999995
# price for reward: 6283.97
# Step:  18023  Total Reward:  2466899.9699999997
# price for reward: 6278.9
# Step:  18024  Total Reward:  2464106.3999999994
# price for reward: 6273.24
# Step:  18025  Total Reward:  2464106.3999999994
# price for reward: 6268.69
# Step:  18026  Total Reward:  2464106.3999999994
# price for reward: 6263.21
# Step:  18027  Total Reward:  2461081.4399999995
# price for reward: 6260.0
# Step:  18028  Total Reward:  2459309.5199999996
# price for reward: 6252.08
# Step:  18029  Total Reward:  2454937.6799999997
# price for reward: 6256.59
# Step:  18030  Total Reward:  2457427.1999999997
# price for reward: 6250.25
# Step:  18031  Total Reward:  2453927.5199999996
# price for reward: 6264.96
# Step:  18032  Total Reward:  2462047.4399999995
# price for reward: 6264.24
# Step:  18033  Total Reward:  2461649.9999999995
# price for reward: 6261.86
# Step:  18034  Total Reward:  2460336.2399999993
# price for reward: 6259.99
# Step:  18035  Total Reward:  2459303.9999999995
# price for reward: 6263.45
# Step:  18036  Total Reward:  2461213.9199999995
# price for reward: 6263.98
# Step:  18037  Total Reward:  2461506.4799999995
# price for reward: 6259.98
# Step:  18038  Total Reward:  2459298.4799999995
# price for reward: 6257.72
# Step:  18039  Total Reward:  2458050.9599999995
# price for reward: 6258.58
# Step:  18040  Total Reward:  2458050.9599999995
# price for reward: 6256.95
# Step:  18041  Total Reward:  2458050.9599999995
# price for reward: 6256.0
# Step:  18042  Total Reward:  2458050.9599999995
# price for reward: 6251.67
# Step:  18043  Total Reward:  2458050.9599999995
# price for reward: 6251.1
# Step:  18044  Total Reward:  2458050.9599999995
# price for reward: 6245.12
# Step:  18045  Total Reward:  2454744.019999999
# price for reward: 6240.49
# Step:  18046  Total Reward:  2452183.629999999
# price for reward: 6249.44
# Step:  18047  Total Reward:  2457132.979999999
# price for reward: 6245.17
# Step:  18048  Total Reward:  2454771.6699999995
# price for reward: 6241.65
# Step:  18049  Total Reward:  2452825.109999999
# price for reward: 6237.82
# Step:  18050  Total Reward:  2450707.119999999
# price for reward: 6233.06
# Step:  18051  Total Reward:  2448074.8399999994
# price for reward: 6237.55
# Step:  18052  Total Reward:  2450557.809999999
# price for reward: 6233.1
# Step:  18053  Total Reward:  2448096.9599999995
# price for reward: 6236.56
# Step:  18054  Total Reward:  2450010.3399999994
# price for reward: 6248.06
# Step:  18055  Total Reward:  2456369.8399999994
# price for reward: 6248.37
# Step:  18056  Total Reward:  2456541.269999999
# price for reward: 6246.12
# Step:  18057  Total Reward:  2455297.019999999
# price for reward: 6246.12
# Step:  18058  Total Reward:  2455297.019999999
# price for reward: 6246.12
# Step:  18059  Total Reward:  2455297.019999999
# price for reward: 6246.1
# Step:  18060  Total Reward:  2455297.019999999
# price for reward: 6251.78
# Step:  18061  Total Reward:  2455297.019999999
# price for reward: 6249.21
# Step:  18062  Total Reward:  2455297.019999999
# price for reward: 6249.63
# Step:  18063  Total Reward:  2455297.019999999
# price for reward: 6249.21
# Step:  18064  Total Reward:  2455297.019999999
# price for reward: 6246.34
# Step:  18065  Total Reward:  2455297.019999999
# price for reward: 6240.0
# Step:  18066  Total Reward:  2451790.999999999
# price for reward: 6240.0
# Step:  18067  Total Reward:  2451790.999999999
# price for reward: 6236.7
# Step:  18068  Total Reward:  2449966.099999999
# price for reward: 6231.23
# Step:  18069  Total Reward:  2446941.189999999
# price for reward: 6225.42
# Step:  18070  Total Reward:  2443728.2599999993
# price for reward: 6238.26
# Step:  18071  Total Reward:  2450828.7799999993
# price for reward: 6238.26
# Step:  18072  Total Reward:  2450828.7799999993
# price for reward: 6239.82
# Step:  18073  Total Reward:  2451691.459999999
# price for reward: 6236.71
# Step:  18074  Total Reward:  2449971.629999999
# price for reward: 6236.67
# Step:  18075  Total Reward:  2449949.5099999993
# price for reward: 6233.8
# Step:  18076  Total Reward:  2448362.399999999
# price for reward: 6224.34
# Step:  18077  Total Reward:  2443131.019999999
# price for reward: 6228.56
# Step:  18078  Total Reward:  2445464.6799999992
# price for reward: 6232.8
# Step:  18079  Total Reward:  2447809.399999999
# price for reward: 6229.94
# Step:  18080  Total Reward:  2446227.819999999
# price for reward: 6228.56
# Step:  18081  Total Reward:  2445464.6799999992
# price for reward: 6233.84
# Step:  18082  Total Reward:  2448384.519999999
# price for reward: 6230.66
# Step:  18083  Total Reward:  2446625.979999999
# price for reward: 6241.04
# Step:  18084  Total Reward:  2452366.119999999
# price for reward: 6238.63
# Step:  18085  Total Reward:  2451033.389999999
# price for reward: 6231.27
# Step:  18086  Total Reward:  2446963.309999999
# price for reward: 6232.49
# Step:  18087  Total Reward:  2447637.969999999
# price for reward: 6225.21
# Step:  18088  Total Reward:  2443612.129999999
# price for reward: 6232.09
# Step:  18089  Total Reward:  2447416.769999999
# price for reward: 6230.35
# Step:  18090  Total Reward:  2446454.5499999993
# price for reward: 6230.33
# Step:  18091  Total Reward:  2446443.489999999
# price for reward: 6239.57
# Step:  18092  Total Reward:  2451553.209999999
# price for reward: 6239.57
# Step:  18093  Total Reward:  2451553.209999999
# price for reward: 6237.05
# Step:  18094  Total Reward:  2450159.649999999
# price for reward: 6240.47
# Step:  18095  Total Reward:  2452050.909999999
# price for reward: 6241.53
# Step:  18096  Total Reward:  2452637.089999999
# price for reward: 6244.52
# Step:  18097  Total Reward:  2454290.559999999
# price for reward: 6244.52
# Step:  18098  Total Reward:  2454290.559999999
# price for reward: 6251.85
# Step:  18099  Total Reward:  2458344.0499999993
# price for reward: 6248.66
# Step:  18100  Total Reward:  2458344.0499999993
# price for reward: 6248.94
# Step:  18101  Total Reward:  2458344.0499999993
# price for reward: 6249.22
# Step:  18102  Total Reward:  2458344.0499999993
# price for reward: 6251.2
# Step:  18103  Total Reward:  2458344.0499999993
# price for reward: 6249.21
# Step:  18104  Total Reward:  2458344.0499999993
# price for reward: 6248.29
# Step:  18105  Total Reward:  2458344.0499999993
# price for reward: 6248.29
# Step:  18106  Total Reward:  2458344.0499999993
# price for reward: 6247.78
# Step:  18107  Total Reward:  2458344.0499999993
# price for reward: 6249.21
# Step:  18108  Total Reward:  2458344.0499999993
# price for reward: 6257.07
# Step:  18109  Total Reward:  2458344.0499999993
# price for reward: 6251.68
# Step:  18110  Total Reward:  2458344.0499999993
# price for reward: 6249.67
# Step:  18111  Total Reward:  2458344.0499999993
# price for reward: 6248.47
# Step:  18112  Total Reward:  2458344.0499999993
# price for reward: 6247.35
# Step:  18113  Total Reward:  2458344.0499999993
# price for reward: 6243.93
# Step:  18114  Total Reward:  2456452.789999999
# price for reward: 6243.48
# Step:  18115  Total Reward:  2456203.939999999
# price for reward: 6238.79
# Step:  18116  Total Reward:  2453610.369999999
# price for reward: 6238.77
# Step:  18117  Total Reward:  2453599.309999999
# price for reward: 6238.77
# Step:  18118  Total Reward:  2453599.309999999
# price for reward: 6239.09
# Step:  18119  Total Reward:  2453776.269999999
# price for reward: 6237.85
# Step:  18120  Total Reward:  2453090.5499999993
# price for reward: 6237.85
# Step:  18121  Total Reward:  2453090.5499999993
# price for reward: 6237.85
# Step:  18122  Total Reward:  2453090.5499999993
# price for reward: 6243.21
# Step:  18123  Total Reward:  2456054.629999999
# price for reward: 6245.13
# Step:  18124  Total Reward:  2457116.389999999
# price for reward: 6242.8
# Step:  18125  Total Reward:  2455827.899999999
# price for reward: 6240.56
# Step:  18126  Total Reward:  2454589.1799999992
# price for reward: 6247.2
# Step:  18127  Total Reward:  2458261.099999999
# price for reward: 6253.48
# Step:  18128  Total Reward:  2461733.939999999
# price for reward: 6250.29
# Step:  18129  Total Reward:  2461733.939999999
# price for reward: 6255.74
# Step:  18130  Total Reward:  2461733.939999999
# price for reward: 6250.64
# Step:  18131  Total Reward:  2461733.939999999
# price for reward: 6249.66
# Step:  18132  Total Reward:  2461733.939999999
# price for reward: 6249.66
# Step:  18133  Total Reward:  2461733.939999999
# price for reward: 6248.94
# Step:  18134  Total Reward:  2461733.939999999
# price for reward: 6248.94
# Step:  18135  Total Reward:  2461733.939999999
# price for reward: 6246.78
# Step:  18136  Total Reward:  2461733.939999999
# price for reward: 6244.18
# Step:  18137  Total Reward:  2461733.939999999
# price for reward: 6244.99
# Step:  18138  Total Reward:  2461733.939999999
# price for reward: 6246.75
# Step:  18139  Total Reward:  2461733.939999999
# price for reward: 6243.34
# Step:  18140  Total Reward:  2461733.939999999
# price for reward: 6244.6
# Step:  18141  Total Reward:  2461733.939999999
# price for reward: 6244.6
# Step:  18142  Total Reward:  2461733.939999999
# price for reward: 6244.6
# Step:  18143  Total Reward:  2461733.939999999
# price for reward: 6244.6
# Step:  18144  Total Reward:  2461733.939999999
# price for reward: 6243.45
# ...
# price for reward: 5936.67
# Step:  19877  Total Reward:  2666807.31
# price for reward: 5932.55
# Step:  19878  Total Reward:  2664265.27
# price for reward: 5930.99
# Step:  19879  Total Reward:  2664265.27
# price for reward: 5926.27
# Step:  19880  Total Reward:  2664265.27
# price for reward: 5923.0
# Step:  19881  Total Reward:  2664265.27
# price for reward: 5917.49
# Step:  19882  Total Reward:  2660860.09
# price for reward: 5915.82
# Step:  19883  Total Reward:  2659828.03
# price for reward: 5924.07
# Step:  19884  Total Reward:  2664926.53
# price for reward: 5926.5
# Step:  19885  Total Reward:  2666428.27
# price for reward: 5933.5
# Step:  19886  Total Reward:  2670754.27
# price for reward: 5930.15
# Step:  19887  Total Reward:  2668683.9699999997
# price for reward: 5932.49
# Step:  19888  Total Reward:  2670130.09
# price for reward: 5932.49
# Step:  19889  Total Reward:  2670130.09
# price for reward: 5929.99
# Step:  19890  Total Reward:  2668585.09
# price for reward: 5928.11
# Step:  19891  Total Reward:  2667423.25
# price for reward: 5935.9
# Step:  19892  Total Reward:  2672237.4699999997
# price for reward: 5933.02
# Step:  19893  Total Reward:  2670457.6300000004
# price for reward: 5924.56
# Step:  19894  Total Reward:  2665229.35
# price for reward: 5924.37
# Step:  19895  Total Reward:  2665111.93
# price for reward: 5922.05
# Step:  19896  Total Reward:  2663678.17
# price for reward: 5922.42
# Step:  19897  Total Reward:  2663906.83
# price for reward: 5926.7
# Step:  19898  Total Reward:  2666551.87
# price for reward: 5925.0
# Step:  19899  Total Reward:  2665501.27
# price for reward: 5937.4
# Step:  19900  Total Reward:  2673164.4699999997
# price for reward: 5943.11
# Step:  19901  Total Reward:  2676693.25
# price for reward: 5944.42
# Step:  19902  Total Reward:  2677502.83
# price for reward: 5943.47
# Step:  19903  Total Reward:  2677502.83
# price for reward: 5943.47
# Step:  19904  Total Reward:  2677502.83
# price for reward: 5939.56
# Step:  19905  Total Reward:  2677502.83
# price for reward: 5938.98
# Step:  19906  Total Reward:  2677502.83
# price for reward: 5933.34
# Step:  19907  Total Reward:  2677502.83
# price for reward: 5930.43
# Step:  19908  Total Reward:  2677502.83
# price for reward: 5927.87
# Step:  19909  Total Reward:  2677502.83
# price for reward: 5922.43
# Step:  19910  Total Reward:  2677502.83
# price for reward: 5925.48
# Step:  19911  Total Reward:  2677502.83
# price for reward: 5925.48
# Step:  19912  Total Reward:  2677502.83
# price for reward: 5928.16
# Step:  19913  Total Reward:  2677502.83
# price for reward: 5924.23
# Step:  19914  Total Reward:  2677502.83
# price for reward: 5928.17
# Step:  19915  Total Reward:  2677502.83
# price for reward: 5918.49
# Step:  19916  Total Reward:  2677502.83
# price for reward: 5916.19
# Step:  19917  Total Reward:  2677502.83
# price for reward: 5918.92
# Step:  19918  Total Reward:  2679198.16
# price for reward: 5909.02
# Step:  19919  Total Reward:  2673050.2600000007
# price for reward: 5909.4
# Step:  19920  Total Reward:  2673286.24
# price for reward: 5915.51
# Step:  19921  Total Reward:  2677080.5500000003
# price for reward: 5910.54
# Step:  19922  Total Reward:  2673994.18
# price for reward: 5907.01
# Step:  19923  Total Reward:  2671802.0500000003
# price for reward: 5903.19
# Step:  19924  Total Reward:  2669429.83
# price for reward: 5902.0
# Step:  19925  Total Reward:  2668690.8400000003
# price for reward: 5899.45
# Step:  19926  Total Reward:  2667107.29
# price for reward: 5901.52
# Step:  19927  Total Reward:  2668392.7600000007
# price for reward: 5918.92
# Step:  19928  Total Reward:  2679198.16
# price for reward: 5918.75
# Step:  19929  Total Reward:  2679092.5900000003
# price for reward: 5912.2
# Step:  19930  Total Reward:  2675025.04
# price for reward: 5909.74
# Step:  19931  Total Reward:  2673497.3800000004
# price for reward: 5912.49
# Step:  19932  Total Reward:  2675205.1300000004
# price for reward: 5913.64
# Step:  19933  Total Reward:  2675919.2800000007
# price for reward: 5921.3
# Step:  19934  Total Reward:  2680676.1400000006
# price for reward: 5930.16
# Step:  19935  Total Reward:  2686178.2
# price for reward: 5921.3
# Step:  19936  Total Reward:  2680676.1400000006
# price for reward: 5922.95
# Step:  19937  Total Reward:  2681700.79
# price for reward: 5923.53
# Step:  19938  Total Reward:  2682060.97
# price for reward: 5927.95
# Step:  19939  Total Reward:  2684805.79
# price for reward: 5924.03
# Step:  19940  Total Reward:  2682371.47
# price for reward: 5918.42
# Step:  19941  Total Reward:  2678887.66
# price for reward: 5911.29
# Step:  19942  Total Reward:  2674459.93
# price for reward: 5916.99
# Step:  19943  Total Reward:  2677999.6300000004
# price for reward: 5921.65
# Step:  19944  Total Reward:  2680893.49
# price for reward: 5928.4
# Step:  19945  Total Reward:  2685085.24
# price for reward: 5933.51
# Step:  19946  Total Reward:  2688258.5500000003
# price for reward: 5924.46
# Step:  19947  Total Reward:  2682638.5000000005
# price for reward: 5925.3
# Step:  19948  Total Reward:  2683160.1400000006
# price for reward: 5923.5
# Step:  19949  Total Reward:  2682042.3400000003
# price for reward: 5922.49
# Step:  19950  Total Reward:  2682042.3400000003
# price for reward: 5918.69
# Step:  19951  Total Reward:  2682042.3400000003
# price for reward: 5920.19
# Step:  19952  Total Reward:  2682042.3400000003
# price for reward: 5920.19
# Step:  19953  Total Reward:  2682042.3400000003
# price for reward: 5922.28
# Step:  19954  Total Reward:  2682042.3400000003
# price for reward: 5923.1
# Step:  19955  Total Reward:  2682042.3400000003
# price for reward: 5921.36
# Step:  19956  Total Reward:  2682042.3400000003
# price for reward: 5919.0
# Step:  19957  Total Reward:  2682042.3400000003
# price for reward: 5916.88
# Step:  19958  Total Reward:  2682042.3400000003
# price for reward: 5915.37
# Step:  19959  Total Reward:  2682042.3400000003
# price for reward: 5914.95
# Step:  19960  Total Reward:  2682042.3400000003
# price for reward: 5914.42
# Step:  19961  Total Reward:  2682042.3400000003
# price for reward: 5916.23
# Step:  19962  Total Reward:  2682042.3400000003
# price for reward: 5916.0
# Step:  19963  Total Reward:  2682042.3400000003
# price for reward: 5919.41
# Step:  19964  Total Reward:  2682042.3400000003
# price for reward: 5917.83
# Step:  19965  Total Reward:  2682042.3400000003
# price for reward: 5899.68
# Step:  19966  Total Reward:  2670753.0400000005
# price for reward: 5906.88
# Step:  19967  Total Reward:  2675231.4400000004
# price for reward: 5904.0
# Step:  19968  Total Reward:  2673440.0800000005
# price for reward: 5906.68
# Step:  19969  Total Reward:  2675107.0400000005
# price for reward: 5910.61
# Step:  19970  Total Reward:  2677551.5000000005
# price for reward: 5910.61
# Step:  19971  Total Reward:  2677551.5000000005
# price for reward: 5907.15
# Step:  19972  Total Reward:  2675399.3800000004
# price for reward: 5907.15
# Step:  19973  Total Reward:  2675399.3800000004
# price for reward: 5911.38
# Step:  19974  Total Reward:  2678030.4400000004
# price for reward: 5905.27
# Step:  19975  Total Reward:  2674230.020000001
# price for reward: 5913.65
# Step:  19976  Total Reward:  2674230.020000001
# price for reward: 5908.29
# Step:  19977  Total Reward:  2674230.020000001
# price for reward: 5906.26
# Step:  19978  Total Reward:  2674230.020000001
# price for reward: 5908.62
# Step:  19979  Total Reward:  2674230.020000001
# price for reward: 5910.5
# Step:  19980  Total Reward:  2674230.020000001
# price for reward: 5916.18
# Step:  19981  Total Reward:  2677757.300000001
# price for reward: 5918.92
# Step:  19982  Total Reward:  2679458.840000001
# price for reward: 5915.14
# Step:  19983  Total Reward:  2677111.4600000014
# price for reward: 5908.71
# Step:  19984  Total Reward:  2673118.430000001
# price for reward: 5902.78
# Step:  19985  Total Reward:  2669435.900000001
# price for reward: 5894.2
# Step:  19986  Total Reward:  2664107.7200000007
# price for reward: 5885.0
# Step:  19987  Total Reward:  2658394.520000001
# price for reward: 5882.47
# Step:  19988  Total Reward:  2656823.390000001
# price for reward: 5882.7
# Step:  19989  Total Reward:  2656966.2200000007
# Step:  19990  Total Reward:  2656966.2200000007
# [-2848.680000000051, -907.1000000002095, -847.270000000135, -895.520000000135, -787.4400000000605, 1738.9299999998184, 1449.4299999998184, 2047.729999999865, 1904.9099999999162, 1638.5699999999488, 2393.199999999837, 2613.219999999972, 4780.60999999987, 4234.4199999999255, 3313.8099999999395, 4049.1399999998976, 5212.929999999818, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 4890.619999999995, 3136.25, 2993.4299999998184, 5176.259999999893, 5506.289999999921, 2902.719999999972, 4332.849999999977, 2613.219999999972, 3335.039999999921, 2474.259999999893, 3800.1699999999255, 2561.1099999998696, 1491.8899999998976, 882.0099999998929, 1188.8799999998882, 457.4099999999162, 683.2199999999721, 658.1299999998882, 897.4499999999534, -1185.020000000135, -1076.9400000000605, -858.8499999999767, -858.8499999999767, -310.7300000000978, 600.229999999865, 1316.259999999893, 1331.6999999999534, 1599.969999999972, 2344.9499999999534, 2902.719999999972, 2611.289999999921, 2613.219999999972, 3250.1199999999953, 2611.289999999921, 1814.1999999999534, 1518.9099999999162, 1130.979999999865, 1341.3499999999767, 3914.039999999921, 6594.8099999999395, 6594.8099999999395, 5438.739999999874, 9684.739999999874, 8806.589999999967, 7075.379999999888, 6286.009999999893, 6774.299999999814, 5726.3099999999395, 4977.469999999972, 4927.289999999921, 6384.439999999944, 5321.009999999893, 7801.0599999999395, 7820.35999999987, 7058.009999999893, 7063.799999999814, 8146.530000000028, 5707.009999999893, 5707.009999999893, 6401.8099999999395, 4931.150000000023, 5579.629999999888, 5579.629999999888, 5587.349999999977, 7251.009999999893, 6552.349999999977, 6552.349999999977, 6552.349999999977, 7305.049999999814, 7349.439999999944, 6847.639999999898, 7222.0599999999395, 13733.879999999888, 14233.75, 12060.569999999949, 13948.10999999987, 12807.479999999865, 13957.759999999893, 15715.989999999874, 16225.509999999893, 14449.909999999916, 14588.869999999995, 17848.639999999898, 20156.919999999925, 17790.739999999874, 18184.459999999846, 17804.25, 18414.12999999989, 18485.53999999992, 16931.889999999898, 15221.909999999916, 14569.569999999949, 16613.439999999944, 15252.78999999992, 14843.629999999888, 15592.469999999972, 13430.869999999995, 16783.280000000028, 14527.10999999987, 14453.769999999902, 14915.03999999992, 13834.239999999874, 13836.169999999925, 13635.449999999953, 13197.339999999967, 13710.719999999972, 14901.530000000028, 15364.729999999865, 15947.589999999967, 14013.729999999865, 14015.659999999916, 14060.049999999814, 14042.679999999818, 10719.219999999972, 9792.819999999949, 8563.409999999916, 9700.179999999818, 10003.189999999944, 9987.75, 9989.679999999818, 10983.629999999888, 10339.009999999893, 10350.589999999967, 12463.939999999944, 12124.259999999893, 12763.089999999967, 12797.829999999842, 14021.449999999953, 14693.089999999967, 15382.099999999977, 13675.979999999865, 15318.409999999916, 15899.339999999967, 15235.419999999925, 15285.599999999977, 14309.019999999902, 14918.900000000023, 14307.089999999967, 14023.379999999888, 14143.03999999992, 14789.589999999967, 14253.049999999814, 15125.409999999916, 16694.5, 18506.769999999902, 19334.739999999874, 20413.60999999987, 20413.60999999987, 20413.60999999987, 20388.38999999978, 19045.9099999998, 19662.82999999984, 19660.88999999978, 20539.70999999973, 20287.509999999776, 19482.4099999998, 20729.82999999984, 18277.66999999981, 19201.10999999987, 20159.46999999974, 20159.46999999974, 20828.76999999967, 20828.76999999967, 23106.32999999984, 23694.14999999979, 25626.38999999978, 28070.78999999992, 28074.66999999981, 26668.16999999981, 26738.009999999776, 26194.809999999823, 25996.92999999982, 28423.86999999988, 28487.88999999978, 27199.72999999975, 28452.96999999974, 29859.46999999974, 28433 ...
# [tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([ ...
